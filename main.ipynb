# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.routes = []
        self.rate = None
        self.capacity = None

    def addRoute(self, route):
        self.routes.append(route)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.routes.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
        self.distance = None

    
    def getDistance(self):
        routes = self.vehicle.routes
        distance = 0

        for i in range (0, len(routes)):
            fromCity = routes[i]
            if i+1 < len(routes):
                toCity = routes[i+1]

            # return to depot
            else:
                toCity = routes[0]
            
            distance += fromCity.distance(toCity)

        return distance

    def getCost(self):
        self.distance = self.getDistance()
        return self.distance*(self.vehicle.rate)  
    
    def getDemand(self):
        routes = self.vehicle.routes
        totalDemand = 0

        for route in routes:
            totalDemand += route.demand

        return totalDemand

# %% [markdown]
# # Generate Population

# %%
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

oriRoutes = []
for i in li:
    oriRoutes.append(Customer(i[0], i[1], i[2], i[3]))

solutions = [] #array of vehicles

for s in range(1000):
    print('iteration'+ str(s+1))
    routes = oriRoutes.copy()

    vehicles = []

    while(len(routes) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(routes):
            selectedRoute = random.choice(routes)
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                routes.remove(selectedRoute)
                print('Route ' + str(selectedRoute.id) + ', demand ' + str(selectedRoute.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# 'iteration1'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration2'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration3'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration4'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration5'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration6'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration7'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration8'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration9'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration10'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration11'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration12'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration13'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration14'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration15'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration16'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration17'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration18'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration19'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration20'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration21'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration22'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration23'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration24'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration25'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration26'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration27'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration28'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration29'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration30'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'iteration31'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'iteration32'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration33'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration34'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration35'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration36'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration37'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'iteration38'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration39'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration40'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration41'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration42'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration43'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration44'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration45'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration46'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration47'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration48'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration49'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'iteration50'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration51'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'iteration52'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration53'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration54'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration55'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration56'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration57'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration58'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration59'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration60'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration61'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration62'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration63'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration64'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration65'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration66'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration67'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration68'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration69'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration70'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration71'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration72'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'iteration73'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration74'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration75'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration76'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration77'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration78'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration79'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration80'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration81'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration82'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration83'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration84'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration85'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration86'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration87'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration88'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration89'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration90'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration91'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration92'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration93'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration94'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration95'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration96'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration97'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration98'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration99'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration100'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration101'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration102'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration103'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration104'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration105'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration106'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration107'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration108'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration109'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration110'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration111'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration112'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration113'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration114'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration115'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration116'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration117'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration118'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration119'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration120'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration121'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration122'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration123'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration124'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration125'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration126'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration127'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration128'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration129'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration130'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration131'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration132'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration133'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration134'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration135'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration136'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration137'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration138'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration139'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration140'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration141'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration142'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration143'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration144'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration145'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration146'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration147'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'iteration148'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration149'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration150'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration151'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration152'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration153'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration154'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration155'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration156'
# ...
#   <__main__.Vehicle at 0x22cd5182180>],
#  [<__main__.Vehicle at 0x22cd5182240>,
#   <__main__.Vehicle at 0x22cd5182300>,
#   <__main__.Vehicle at 0x22cd51823c0>],
#  [<__main__.Vehicle at 0x22cd5182480>,
#   <__main__.Vehicle at 0x22cd5182540>,
#   <__main__.Vehicle at 0x22cd5182600>],
#  [<__main__.Vehicle at 0x22cd51826c0>,
#   <__main__.Vehicle at 0x22cd5182780>,
#   <__main__.Vehicle at 0x22cd5182840>],
#  [<__main__.Vehicle at 0x22cd5182900>,
#   <__main__.Vehicle at 0x22cd51829c0>,
#   <__main__.Vehicle at 0x22cd5182a80>],
#  [<__main__.Vehicle at 0x22cd5182b40>,
#   <__main__.Vehicle at 0x22cd5182c00>,
#   <__main__.Vehicle at 0x22cd5182cc0>],
#  [<__main__.Vehicle at 0x22cd5182d80>,
#   <__main__.Vehicle at 0x22cd5182e40>,
#   <__main__.Vehicle at 0x22cd5182f00>],
#  [<__main__.Vehicle at 0x22cd5182fc0>, <__main__.Vehicle at 0x22cd5183080>],
#  [<__main__.Vehicle at 0x22cd5183140>,
#   <__main__.Vehicle at 0x22cd5183200>,
#   <__main__.Vehicle at 0x22cd51832c0>],
#  [<__main__.Vehicle at 0x22cd5183380>,
#   <__main__.Vehicle at 0x22cd5183440>,
#   <__main__.Vehicle at 0x22cd5183500>],
#  [<__main__.Vehicle at 0x22cd51835c0>,
#   <__main__.Vehicle at 0x22cd5183680>,
#   <__main__.Vehicle at 0x22cd5183740>],
#  [<__main__.Vehicle at 0x22cd5183800>,
#   <__main__.Vehicle at 0x22cd51838c0>,
#   <__main__.Vehicle at 0x22cd5183980>],
#  [<__main__.Vehicle at 0x22cd5183a40>,
#   <__main__.Vehicle at 0x22cd5183b00>,
#   <__main__.Vehicle at 0x22cd5183bc0>],
#  [<__main__.Vehicle at 0x22cd5183c80>,
#   <__main__.Vehicle at 0x22cd5183d40>,
#   <__main__.Vehicle at 0x22cd5183e00>],
#  [<__main__.Vehicle at 0x22cd5183ec0>,
#   <__main__.Vehicle at 0x22cd5183f80>,
#   <__main__.Vehicle at 0x22cd5188080>],
#  [<__main__.Vehicle at 0x22cd5188140>,
#   <__main__.Vehicle at 0x22cd5188200>,
#   <__main__.Vehicle at 0x22cd51882c0>],
#  [<__main__.Vehicle at 0x22cd5188380>,
#   <__main__.Vehicle at 0x22cd5188440>,
#   <__main__.Vehicle at 0x22cd5188500>],
#  [<__main__.Vehicle at 0x22cd51885c0>,
#   <__main__.Vehicle at 0x22cd5188680>,
#   <__main__.Vehicle at 0x22cd5188740>],
#  [<__main__.Vehicle at 0x22cd5188800>, <__main__.Vehicle at 0x22cd51888c0>],
#  [<__main__.Vehicle at 0x22cd5188980>,
#   <__main__.Vehicle at 0x22cd5188a40>,
#   <__main__.Vehicle at 0x22cd5188b00>],
#  [<__main__.Vehicle at 0x22cd5188bc0>,
#   <__main__.Vehicle at 0x22cd5188c80>,
#   <__main__.Vehicle at 0x22cd5188d40>],
#  [<__main__.Vehicle at 0x22cd5188e00>,
#   <__main__.Vehicle at 0x22cd5188ec0>,
#   <__main__.Vehicle at 0x22cd5188f80>],
#  [<__main__.Vehicle at 0x22cd5189040>, <__main__.Vehicle at 0x22cd5189100>],
#  [<__main__.Vehicle at 0x22cd51891c0>,
#   <__main__.Vehicle at 0x22cd5189280>,
#   <__main__.Vehicle at 0x22cd5189340>],
#  [<__main__.Vehicle at 0x22cd5189400>, <__main__.Vehicle at 0x22cd51894c0>],
#  [<__main__.Vehicle at 0x22cd5189580>,
#   <__main__.Vehicle at 0x22cd5189640>,
#   <__main__.Vehicle at 0x22cd5189700>],
#  [<__main__.Vehicle at 0x22cd51897c0>,
#   <__main__.Vehicle at 0x22cd5189880>,
#   <__main__.Vehicle at 0x22cd5189940>],
#  [<__main__.Vehicle at 0x22cd5189a00>, <__main__.Vehicle at 0x22cd5189ac0>],
#  [<__main__.Vehicle at 0x22cd5189b80>, <__main__.Vehicle at 0x22cd5189c40>],
#  [<__main__.Vehicle at 0x22cd5189d00>,
#   <__main__.Vehicle at 0x22cd5189dc0>,
#   <__main__.Vehicle at 0x22cd5189e80>],
#  [<__main__.Vehicle at 0x22cd5189f40>, <__main__.Vehicle at 0x22cd518a000>],
#  [<__main__.Vehicle at 0x22cd518a0c0>, <__main__.Vehicle at 0x22cd518a180>],
#  [<__main__.Vehicle at 0x22cd518a240>, <__main__.Vehicle at 0x22cd518a300>],
#  [<__main__.Vehicle at 0x22cd518a3c0>,
#   <__main__.Vehicle at 0x22cd518a480>,
#   <__main__.Vehicle at 0x22cd518a540>],
#  [<__main__.Vehicle at 0x22cd518a600>,
#   <__main__.Vehicle at 0x22cd518a6c0>,
#   <__main__.Vehicle at 0x22cd518a780>],
#  [<__main__.Vehicle at 0x22cd518a840>, <__main__.Vehicle at 0x22cd518a900>],
#  [<__main__.Vehicle at 0x22cd518a9c0>,
#   <__main__.Vehicle at 0x22cd518aa80>,
#   <__main__.Vehicle at 0x22cd518ab40>],
#  [<__main__.Vehicle at 0x22cd518ac00>,
#   <__main__.Vehicle at 0x22cd518acc0>,
#   <__main__.Vehicle at 0x22cd518ad80>],
#  [<__main__.Vehicle at 0x22cd518ae40>,
#   <__main__.Vehicle at 0x22cd518af00>,
#   <__main__.Vehicle at 0x22cd518afc0>],
#  [<__main__.Vehicle at 0x22cd518b080>, <__main__.Vehicle at 0x22cd518b140>],
#  [<__main__.Vehicle at 0x22cd518b200>,
#   <__main__.Vehicle at 0x22cd518b2c0>,
#   <__main__.Vehicle at 0x22cd518b380>],
#  [<__main__.Vehicle at 0x22cd518b440>, <__main__.Vehicle at 0x22cd518b500>],
#  [<__main__.Vehicle at 0x22cd518b5c0>,
#   <__main__.Vehicle at 0x22cd518b680>,
#   <__main__.Vehicle at 0x22cd518b740>],
#  [<__main__.Vehicle at 0x22cd518b800>,
#   <__main__.Vehicle at 0x22cd518b8c0>,
#   <__main__.Vehicle at 0x22cd518b980>],
#  [<__main__.Vehicle at 0x22cd518ba40>,
#   <__main__.Vehicle at 0x22cd518bb00>,
#   <__main__.Vehicle at 0x22cd518bbc0>],
#  [<__main__.Vehicle at 0x22cd518bc80>,
#   <__main__.Vehicle at 0x22cd518bd40>,
#   <__main__.Vehicle at 0x22cd518be00>],
#  [<__main__.Vehicle at 0x22cd518bec0>,
#   <__main__.Vehicle at 0x22cd518bf80>,
#   <__main__.Vehicle at 0x22cd518c080>],
#  [<__main__.Vehicle at 0x22cd518c140>,
#   <__main__.Vehicle at 0x22cd518c200>,
#   <__main__.Vehicle at 0x22cd518c2c0>],
#  [<__main__.Vehicle at 0x22cd518c380>,
#   <__main__.Vehicle at 0x22cd518c440>,
#   <__main__.Vehicle at 0x22cd518c500>],
#  [<__main__.Vehicle at 0x22cd518c5c0>,
#   <__main__.Vehicle at 0x22cd518c680>,
#   <__main__.Vehicle at 0x22cd518c740>],
#  [<__main__.Vehicle at 0x22cd518c800>,
#   <__main__.Vehicle at 0x22cd518c8c0>,
#   <__main__.Vehicle at 0x22cd518c980>],
#  [<__main__.Vehicle at 0x22cd518ca40>,
#   <__main__.Vehicle at 0x22cd518cb00>,
#   <__main__.Vehicle at 0x22cd518cbc0>],
#  [<__main__.Vehicle at 0x22cd518cc80>, <__main__.Vehicle at 0x22cd518cd40>],
#  [<__main__.Vehicle at 0x22cd518ce00>,
#   <__main__.Vehicle at 0x22cd518cec0>,
#   <__main__.Vehicle at 0x22cd518cf80>],
#  [<__main__.Vehicle at 0x22cd518d040>,
#   <__main__.Vehicle at 0x22cd518d100>,
#   <__main__.Vehicle at 0x22cd518d1c0>],
#  [<__main__.Vehicle at 0x22cd518d280>, <__main__.Vehicle at 0x22cd518d340>],
#  [<__main__.Vehicle at 0x22cd518d400>, <__main__.Vehicle at 0x22cd518d4c0>],
#  [<__main__.Vehicle at 0x22cd518d580>,
#   <__main__.Vehicle at 0x22cd518d640>,
#   <__main__.Vehicle at 0x22cd518d700>],
#  [<__main__.Vehicle at 0x22cd518d7c0>,
#   <__main__.Vehicle at 0x22cd518d880>,
#   <__main__.Vehicle at 0x22cd518d940>],
#  [<__main__.Vehicle at 0x22cd518da00>,
#   <__main__.Vehicle at 0x22cd518dac0>,
#   <__main__.Vehicle at 0x22cd518db80>],
#  [<__main__.Vehicle at 0x22cd518dc40>,
#   <__main__.Vehicle at 0x22cd518dd00>,
#   <__main__.Vehicle at 0x22cd518ddc0>],
#  [<__main__.Vehicle at 0x22cd518de80>,
#   <__main__.Vehicle at 0x22cd518df40>,
#   <__main__.Vehicle at 0x22cd518e000>],
#  [<__main__.Vehicle at 0x22cd518e0c0>,
#   <__main__.Vehicle at 0x22cd518e180>,
#   <__main__.Vehicle at 0x22cd518e240>],
#  [<__main__.Vehicle at 0x22cd518e300>, <__main__.Vehicle at 0x22cd518e3c0>],
#  [<__main__.Vehicle at 0x22cd518e480>,
#   <__main__.Vehicle at 0x22cd518e540>,
#   <__main__.Vehicle at 0x22cd518e600>],
#  [<__main__.Vehicle at 0x22cd518e6c0>, <__main__.Vehicle at 0x22cd518e780>],
#  [<__main__.Vehicle at 0x22cd518e840>,
#   <__main__.Vehicle at 0x22cd518e900>,
#   <__main__.Vehicle at 0x22cd518e9c0>],
#  [<__main__.Vehicle at 0x22cd518ea80>, <__main__.Vehicle at 0x22cd518eb40>],
#  [<__main__.Vehicle at 0x22cd518ec00>,
#   <__main__.Vehicle at 0x22cd518ecc0>,
#   <__main__.Vehicle at 0x22cd518ed80>],
#  [<__main__.Vehicle at 0x22cd518ee40>,
#   <__main__.Vehicle at 0x22cd518ef00>,
#   <__main__.Vehicle at 0x22cd518efc0>],
#  [<__main__.Vehicle at 0x22cd518f080>,
#   <__main__.Vehicle at 0x22cd518f140>,
#   <__main__.Vehicle at 0x22cd518f200>],
#  [<__main__.Vehicle at 0x22cd518f2c0>,
#   <__main__.Vehicle at 0x22cd518f380>,
#   <__main__.Vehicle at 0x22cd518f440>],
#  [<__main__.Vehicle at 0x22cd518f500>,
#   <__main__.Vehicle at 0x22cd518f5c0>,
#   <__main__.Vehicle at 0x22cd518f680>],
#  [<__main__.Vehicle at 0x22cd518f740>,
#   <__main__.Vehicle at 0x22cd518f800>,
#   <__main__.Vehicle at 0x22cd518f8c0>],
#  [<__main__.Vehicle at 0x22cd518f980>, <__main__.Vehicle at 0x22cd518fa40>],
#  [<__main__.Vehicle at 0x22cd518fb00>,
#   <__main__.Vehicle at 0x22cd518fbc0>,
#   <__main__.Vehicle at 0x22cd518fc80>],
#  [<__main__.Vehicle at 0x22cd518fd40>,
#   <__main__.Vehicle at 0x22cd518fe00>,
#   <__main__.Vehicle at 0x22cd518fec0>],
#  [<__main__.Vehicle at 0x22cd518ff80>,
#   <__main__.Vehicle at 0x22cd5198080>,
#   <__main__.Vehicle at 0x22cd5198140>],
#  [<__main__.Vehicle at 0x22cd5198200>,
#   <__main__.Vehicle at 0x22cd51982c0>,
#   <__main__.Vehicle at 0x22cd5198380>],
#  [<__main__.Vehicle at 0x22cd5198440>,
#   <__main__.Vehicle at 0x22cd5198500>,
#   <__main__.Vehicle at 0x22cd51985c0>],
#  [<__main__.Vehicle at 0x22cd5198680>, <__main__.Vehicle at 0x22cd5198740>],
#  [<__main__.Vehicle at 0x22cd5198800>,
#   <__main__.Vehicle at 0x22cd51988c0>,
#   <__main__.Vehicle at 0x22cd5198980>],
#  [<__main__.Vehicle at 0x22cd5198a40>, <__main__.Vehicle at 0x22cd5198b00>],
#  [<__main__.Vehicle at 0x22cd5198bc0>,
#   <__main__.Vehicle at 0x22cd5198c80>,
#   <__main__.Vehicle at 0x22cd5198d40>],
#  [<__main__.Vehicle at 0x22cd5198e00>,
#   <__main__.Vehicle at 0x22cd5198ec0>,
#   <__main__.Vehicle at 0x22cd5198f80>],
#  [<__main__.Vehicle at 0x22cd5199040>, <__main__.Vehicle at 0x22cd5199100>],
#  [<__main__.Vehicle at 0x22cd51991c0>,
#   <__main__.Vehicle at 0x22cd5199280>,
#   <__main__.Vehicle at 0x22cd5199340>],
#  [<__main__.Vehicle at 0x22cd5199400>,
#   <__main__.Vehicle at 0x22cd51994c0>,
#   <__main__.Vehicle at 0x22cd5199580>],
#  [<__main__.Vehicle at 0x22cd5199640>,
#   <__main__.Vehicle at 0x22cd5199700>,
#   <__main__.Vehicle at 0x22cd51997c0>],
#  [<__main__.Vehicle at 0x22cd5199880>,
#   <__main__.Vehicle at 0x22cd5199940>,
#   <__main__.Vehicle at 0x22cd5199a00>],
#  [<__main__.Vehicle at 0x22cd5199ac0>,
#   <__main__.Vehicle at 0x22cd5199b80>,
#   <__main__.Vehicle at 0x22cd5199c40>],
#  [<__main__.Vehicle at 0x22cd5199d00>,
#   <__main__.Vehicle at 0x22cd5199dc0>,
#   <__main__.Vehicle at 0x22cd5199e80>],
#  [<__main__.Vehicle at 0x22cd5199f40>,
#   <__main__.Vehicle at 0x22cd519a000>,
#   <__main__.Vehicle at 0x22cd519a0c0>],
#  [<__main__.Vehicle at 0x22cd519a180>,
#   <__main__.Vehicle at 0x22cd519a240>,
#   <__main__.Vehicle at 0x22cd519a300>],
#  [<__main__.Vehicle at 0x22cd519a3c0>,
#   <__main__.Vehicle at 0x22cd519a480>,
#   <__main__.Vehicle at 0x22cd519a540>],
#  [<__main__.Vehicle at 0x22cd519a600>,
#   <__main__.Vehicle at 0x22cd519a6c0>,
#   <__main__.Vehicle at 0x22cd519a780>],
#  [<__main__.Vehicle at 0x22cd519a840>,
#   <__main__.Vehicle at 0x22cd519a900>,
#   <__main__.Vehicle at 0x22cd519a9c0>],
#  [<__main__.Vehicle at 0x22cd519aa80>,
#   <__main__.Vehicle at 0x22cd519ab40>,
#   <__main__.Vehicle at 0x22cd519ac00>],
#  [<__main__.Vehicle at 0x22cd519acc0>,
#   <__main__.Vehicle at 0x22cd519ad80>,
#   <__main__.Vehicle at 0x22cd519ae40>],
#  [<__main__.Vehicle at 0x22cd519af00>,
#   <__main__.Vehicle at 0x22cd519afc0>,
#   <__main__.Vehicle at 0x22cd519b080>],
#  [<__main__.Vehicle at 0x22cd519b140>,
#   <__main__.Vehicle at 0x22cd519b200>,
#   <__main__.Vehicle at 0x22cd519b2c0>],
#  [<__main__.Vehicle at 0x22cd519b380>,
#   <__main__.Vehicle at 0x22cd519b440>,
#   <__main__.Vehicle at 0x22cd519b500>],
#  [<__main__.Vehicle at 0x22cd519b5c0>,
#   <__main__.Vehicle at 0x22cd519b680>,
#   <__main__.Vehicle at 0x22cd519b740>],
#  [<__main__.Vehicle at 0x22cd519b800>,
#   <__main__.Vehicle at 0x22cd519b8c0>,
#   <__main__.Vehicle at 0x22cd519b980>],
#  [<__main__.Vehicle at 0x22cd519ba40>, <__main__.Vehicle at 0x22cd519bb00>],
#  [<__main__.Vehicle at 0x22cd519bbc0>,
#   <__main__.Vehicle at 0x22cd519bc80>,
#   <__main__.Vehicle at 0x22cd519bd40>],
#  [<__main__.Vehicle at 0x22cd519be00>,
#   <__main__.Vehicle at 0x22cd519bec0>,
#   <__main__.Vehicle at 0x22cd519bf80>],
#  [<__main__.Vehicle at 0x22cd51a0080>,
#   <__main__.Vehicle at 0x22cd51a0140>,
#   <__main__.Vehicle at 0x22cd51a0200>],
#  [<__main__.Vehicle at 0x22cd51a02c0>,
#   <__main__.Vehicle at 0x22cd51a0380>,
#   <__main__.Vehicle at 0x22cd51a0440>],
#  [<__main__.Vehicle at 0x22cd51a0500>,
#   <__main__.Vehicle at 0x22cd51a05c0>,
#   <__main__.Vehicle at 0x22cd51a0680>],
#  [<__main__.Vehicle at 0x22cd51a0740>,
#   <__main__.Vehicle at 0x22cd51a0800>,
#   <__main__.Vehicle at 0x22cd51a08c0>],
#  [<__main__.Vehicle at 0x22cd51a0980>,
#   <__main__.Vehicle at 0x22cd51a0a40>,
#   <__main__.Vehicle at 0x22cd51a0b00>],
#  [<__main__.Vehicle at 0x22cd51a0bc0>,
#   <__main__.Vehicle at 0x22cd51a0c80>,
#   <__main__.Vehicle at 0x22cd51a0d40>],
#  [<__main__.Vehicle at 0x22cd51a0e00>,
#   <__main__.Vehicle at 0x22cd51a0ec0>,
#   <__main__.Vehicle at 0x22cd51a0f80>],
#  [<__main__.Vehicle at 0x22cd51a1040>,
#   <__main__.Vehicle at 0x22cd51a1100>,
#   <__main__.Vehicle at 0x22cd51a11c0>],
#  [<__main__.Vehicle at 0x22cd51a1280>, <__main__.Vehicle at 0x22cd51a1340>],
#  [<__main__.Vehicle at 0x22cd51a1400>,
#   <__main__.Vehicle at 0x22cd51a14c0>,
#   <__main__.Vehicle at 0x22cd51a1580>],
#  [<__main__.Vehicle at 0x22cd51a1640>,
#   <__main__.Vehicle at 0x22cd51a1700>,
#   <__main__.Vehicle at 0x22cd51a42c0>,
#   <__main__.Vehicle at 0x22cd51a4380>],
#  [<__main__.Vehicle at 0x22cd51a4440>,
#   <__main__.Vehicle at 0x22cd51a4500>,
#   <__main__.Vehicle at 0x22cd51a45c0>],
#  [<__main__.Vehicle at 0x22cd51a4680>,
#   <__main__.Vehicle at 0x22cd51a4740>,
#   <__main__.Vehicle at 0x22cd51a4800>],
#  [<__main__.Vehicle at 0x22cd51a48c0>,
#   <__main__.Vehicle at 0x22cd51a4980>,
#   <__main__.Vehicle at 0x22cd51a4a40>],
#  [<__main__.Vehicle at 0x22cd51a4b00>,
#   <__main__.Vehicle at 0x22cd51a4bc0>,
#   <__main__.Vehicle at 0x22cd51a4c80>],
#  [<__main__.Vehicle at 0x22cd51a4d40>,
#   <__main__.Vehicle at 0x22cd51a4e00>,
#   <__main__.Vehicle at 0x22cd51a4ec0>],
#  [<__main__.Vehicle at 0x22cd51a4f80>,
#   <__main__.Vehicle at 0x22cd51a5040>,
#   <__main__.Vehicle at 0x22cd51a5100>],
#  [<__main__.Vehicle at 0x22cd51a51c0>,
#   <__main__.Vehicle at 0x22cd51a5280>,
#   <__main__.Vehicle at 0x22cd51a5340>]]

# %% [markdown]
# # Selection

# %%
def fitness(solution):
    solutionCost = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        cost = fitness.getCost()
        solutionCost += cost
    return solutionCost

def distance(solution):
    solutionDistance = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        distance = fitness.getDistance()
        solutionDistance += distance
    return solutionDistance


def getParents(population):
    choices = population.copy()

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = fitness(vehicles)
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minA = choices[minpos]
    chosenSolutionCost.pop(minpos)
    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minB = choices[minpos]

    return minA, minB

A, B = getParents(solutions)
A[0].routes
# Out:
# [(4.4184,114.0932),
#  (4.3818,114.2034),
#  (4.4935,114.1828),
#  (4.4932,114.1322),
#  (4.4804,114.0734)]

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

def getDuplicatedElements(li):
    duplicates = []
    for x in li:
        if x not in duplicates and li.count(x) >1:
            duplicates.append(x)
        
    return duplicates

# %%
def getCrossoverOffspring(firstParent, secondParent):
    childVehicles = []

    first = [[],[],[]]
    firstVehicles = []

    for i in range(len(firstParent)):
        #some solutions only have 2 vehicles
        if (firstParent[i].routes):
            firstParent[i].routes.pop(0)
        firstVehicles.append(firstParent[i].type)
        # for every route
        for j in range(len(firstParent[i].routes)):
            first[i].append(firstParent[i].routes[j].id)



    second = [[],[],[]]
    secondVehicles = []


    for i in range(len(secondParent)):
        #some solutions only have 2 vehicles
        if (secondParent[i].routes):
            secondParent[i].routes.pop(0)
        secondVehicles.append(secondParent[i].type)
        # for every route
        for j in range(len(secondParent[i].routes)):
            second[i].append(secondParent[i].routes[j].id)


    # Random Choice of 1,2,3,4
    choice = random.randint(1, 4)
    # Case 1 - first parent is  main, two vehicles remain, one vehicle changes
    if (choice == 1 or choice == 2):
        if (choice == 1):
            parent = first.copy()
            secondary = second.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = firstVehicles.copy()

        # Case 2 - second parent is main, two vehicles remain, one vehicle changes
        elif (choice == 2):
            parent = second.copy()
            secondary = first.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = secondVehicles.copy()

        missing = findMissing(parent)

        child = []
        for i in parent:
            if i not in child:
                child.append(i)
            else:
                if(missing):
                    child.append(missing[0])
                    missing.pop(0)

        if (missing):
            child += missing


    elif (choice == 3 or choice == 4):
        # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
        if (choice == 3):
            child = convertToOneDList(first)
            childVehicles = firstVehicles.copy()
        # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
        elif (choice == 4):
            child = convertToOneDList(second)
            childVehicles = secondVehicles.copy()

    return child, childVehicles

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation
def vehicleMutation(li):
    idx = random.randint(0, len(li)-1)
    if li[idx] == 'A':
        li[idx] = 'B'
    else:
        li[idx] = 'A'
    
    return li

# Routes Mutation - Swap
def routeMutation(li):
    if(len(li) >= 1):
        aIdx = random.randint(0, len(li)-1)
        bIdx = random.randint(0, len(li)-1)

        temp = li[aIdx]
        li[aIdx] = li[bIdx]
        li[bIdx] = temp

    return li

# %%
def getMutatedOffspring(first, second):

    child, childVehicles = getCrossoverOffspring(first, second)
    mutatedChild = routeMutation(child)
    mutatedVehicles = vehicleMutation(childVehicles)

    return mutatedChild, mutatedVehicles

# %% [markdown]
# # Convert back to class

# %%
# convert routes to Customer class
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()
print(li)

routes = []
for i in li:
    routes.append(Customer(i[0], i[1], i[2], i[3]))
# Out:
# [[1.0, 4.3555, 113.9777, 5.0],
#  [2.0, 4.3976, 114.0049, 8.0],
#  [3.0, 4.3163, 114.0764, 3.0],
#  [4.0, 4.3184, 113.9932, 6.0],
#  [5.0, 4.4024, 113.9896, 5.0],
#  [6.0, 4.4142, 114.0127, 8.0],
#  [7.0, 4.4804, 114.0734, 3.0],
#  [8.0, 4.3818, 114.2034, 6.0],
#  [9.0, 4.4935, 114.1828, 5.0],
#  [10.0, 4.4932, 114.1322, 8.0]]

# %%
def getOffspring(first, second):
    mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    while(len(mutatedChild) != 10):
        mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    # print(mutatedChild)
    # print(mutatedVehicles)

    offspring = []
    for i in mutatedVehicles:
        vehicle = Vehicle(i)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        filledCapacity = 0

        while(mutatedChild):
            idx = mutatedChild[0]
            selectedRoute = routes[idx-1]
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                mutatedChild.pop(0)
            else:
                break
        
        offspring.append(vehicle)

    return offspring

# %% [markdown]
# # Main Function

# %%
import copy

parent1, parent2 = getParents(solutions)


noIteration = 500
minScore = 1000

for i in range(noIteration):
    population = []
    # each parent will produce 1000 offspring, and two best are selected
    for j in range(500):
        offspringA = getOffspring(parent1, parent2)
        offspringB = getOffspring(parent1, parent2)

        population.append(offspringA)
        population.append(offspringB)
    

    parent1, parent2 = getParents(population)

    averageScore = fitness(parent1)

    print('Iteration: ' + str(i+1))
    print('Score: ' + str(averageScore))

    if(averageScore < minScore):
        minScore = averageScore
        minParent = copy.deepcopy(parent1)
# Out:
# 'Iteration: 1'
# 'Score: 150.98313686644053'
# 'Iteration: 2'
# 'Score: 143.42708299858427'
# 'Iteration: 3'
# 'Score: 150.98313686644053'
# 'Iteration: 4'
# 'Score: 143.42708299858427'
# 'Iteration: 5'
# 'Score: 150.98313686644053'
# 'Iteration: 6'
# 'Score: 143.42708299858427'
# 'Iteration: 7'
# 'Score: 150.98313686644053'
# 'Iteration: 8'
# 'Score: 143.42708299858427'
# 'Iteration: 9'
# 'Score: 150.98313686644053'
# 'Iteration: 10'
# 'Score: 143.42708299858427'
# 'Iteration: 11'
# 'Score: 147.08588901447848'
# 'Iteration: 12'
# 'Score: 143.42708299858427'
# 'Iteration: 13'
# 'Score: 150.98313686644053'
# 'Iteration: 14'
# 'Score: 143.42708299858427'
# 'Iteration: 15'
# 'Score: 150.98313686644053'
# 'Iteration: 16'
# 'Score: 143.42708299858427'
# 'Iteration: 17'
# 'Score: 150.98313686644053'
# 'Iteration: 18'
# 'Score: 143.42708299858427'
# 'Iteration: 19'
# 'Score: 150.98313686644053'
# 'Iteration: 20'
# 'Score: 143.42708299858427'
# 'Iteration: 21'
# 'Score: 150.98313686644053'
# 'Iteration: 22'
# 'Score: 143.42708299858427'
# 'Iteration: 23'
# 'Score: 150.98313686644053'
# 'Iteration: 24'
# 'Score: 143.42708299858427'
# 'Iteration: 25'
# 'Score: 148.32849834069887'
# 'Iteration: 26'
# 'Score: 143.42708299858427'
# 'Iteration: 27'
# 'Score: 150.98313686644053'
# 'Iteration: 28'
# 'Score: 143.42708299858427'
# 'Iteration: 29'
# 'Score: 150.98313686644053'
# 'Iteration: 30'
# 'Score: 143.42708299858427'
# 'Iteration: 31'
# 'Score: 150.98313686644053'
# 'Iteration: 32'
# 'Score: 143.42708299858427'
# 'Iteration: 33'
# 'Score: 150.98313686644053'
# 'Iteration: 34'
# 'Score: 143.42708299858427'
# 'Iteration: 35'
# 'Score: 150.98313686644053'
# 'Iteration: 36'
# 'Score: 143.42708299858427'
# 'Score: 150.98313686644053'
# 'Iteration: 478'
# 'Score: 143.42708299858427'
# 'Iteration: 479'
# 'Score: 150.98313686644053'
# 'Iteration: 480'
# 'Score: 143.42708299858427'
# 'Iteration: 481'
# 'Score: 150.98313686644053'
# 'Iteration: 482'
# 'Score: 143.42708299858427'
# 'Iteration: 483'
# 'Score: 150.98313686644053'
# 'Iteration: 484'
# 'Score: 143.42708299858427'
# 'Iteration: 485'
# 'Score: 150.98313686644053'
# 'Iteration: 486'
# 'Score: 143.42708299858427'
# 'Iteration: 487'
# 'Score: 150.98313686644053'
# 'Iteration: 488'
# 'Score: 143.42708299858427'
# 'Iteration: 489'
# 'Score: 150.98313686644053'
# 'Iteration: 490'
# 'Score: 143.42708299858427'
# 'Iteration: 491'
# 'Score: 150.98313686644053'
# 'Iteration: 492'
# 'Score: 143.42708299858427'
# 'Iteration: 493'
# 'Score: 150.98313686644053'
# 'Iteration: 494'
# 'Score: 136.24012600352341'
# 'Iteration: 495'
# 'Score: 150.98313686644053'
# 'Iteration: 496'
# 'Score: 143.42708299858427'
# 'Iteration: 497'
# 'Score: 150.98313686644053'
# 'Iteration: 498'
# 'Score: 143.42708299858427'
# 'Iteration: 499'
# 'Score: 150.98313686644053'
# 'Iteration: 500'
# 'Score: 143.42708299858427'

# %%
print("Total Distance: " + str(round(distance(minParent), 2)) + " km")
print("Total Cost: RM " + str(round(minScore, 2)))
print('')


for idx, vehicle in enumerate(minParent):
    if(vehicle):

        print(f"Vehicle {idx+1} (Type {vehicle.type})")
        vehicleFitness = Fitness(vehicle)
        print(f"Round Trip Distance: {round(vehicleFitness.getDistance(),3)} km, Cost: RM {round(vehicleFitness.getCost(),2)}, Demand: {vehicleFitness.getDemand()}")

        for idx, route in enumerate(vehicle.routes):
            
            if (route.id == -1):
                routeName = "Depot"
                print(f"{routeName} -> ")
            else:
                routeName = "C"+str(int(route.id))
                print(f"{routeName} ({round(route.distance(vehicle.routes[idx-1]),2)} km) -> ")

        backToDepotDistance = vehicle.routes[-1].distance(vehicle.routes[0])
        print(f"Depot ({round(backToDepotDistance, 2)} km)")
        print('')
# Out:
# 'Total Distance: 107.66 km'
# 'Total Cost: RM 129.19'
# ''
# 'Vehicle 1 (Type A)'
# 'Round Trip Distance: 60.488 km, Cost: RM 72.59, Demand: 23.0'
# 'Depot -> '
# 'C8 (11.61 km) -> '
# 'C3 (14.29 km) -> '
# 'C4 (8.32 km) -> '
# 'C1 (4.02 km) -> '
# 'C7 (15.73 km) -> '
# 'Depot (6.51 km)'
# ''
# 'Vehicle 2 (Type A)'
# 'Round Trip Distance: 21.981 km, Cost: RM 26.38, Demand: 21.0'
# 'Depot -> '
# 'C6 (8.06 km) -> '
# 'C2 (1.83 km) -> '
# 'C5 (1.6 km) -> '
# 'Depot (10.48 km)'
# ''
# 'Vehicle 3 (Type A)'
# 'Round Trip Distance: 25.187 km, Cost: RM 30.22, Demand: 13.0'
# 'Depot -> '
# 'C9 (11.69 km) -> '
# 'C10 (5.06 km) -> '
# 'Depot (8.44 km)'
# ''
