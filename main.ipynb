# %% [markdown]
# # Import Libraries

# %%
import random
import time
import csv

import numpy as np
import pandas as pd

from pprint import pprint as print

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.routes = []
        self.rate = None
        self.capacity = None

    def addRoute(self, route):
        self.routes.append(route)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.routes.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
    
    # fitness is based on cost, since distance is directly in correlation with cost,
    # taking cost can be a more accurate representation of the efficiency of the route

    # routes = customer
    def cost(self):
        routes = self.vehicle.routes
        distance = 0

        for i in range (0, len(routes)):
            fromCity = routes[i]
            if i+1 < len(routes):
                toCity = routes[i+1]

            # return to depot
            else:
                toCity = routes[0]
            
            distance += fromCity.distance(toCity)

        return distance*(self.vehicle.rate)
    
    # def fitness(self):
    #     cost = cost(self)

    #     # give higher ranking for lower cost
    #     return abs(1/cost)

# %%
# fill in routes - choose vehicle - ensure routes is selected based on demands

# %% [markdown]
# # Generate Population

# %%
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

oriRoutes = []
for i in li:
    oriRoutes.append(Customer(i[0], i[1], i[2], i[3]))

solutions = [] #array of vehicles

for s in range(1000):
    print('iteration'+ str(s+1))
    routes = oriRoutes.copy()

    vehicles = []

    while(len(routes) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(routes):
            selectedRoute = random.choice(routes)
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                routes.remove(selectedRoute)
                print('Route ' + str(selectedRoute.id) + ', demand ' + str(selectedRoute.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# 'iteration1'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration2'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration3'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration4'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration5'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration6'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration7'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration8'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration9'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration10'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration11'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration12'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration13'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration14'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration15'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration16'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration17'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'iteration18'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration19'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration20'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration21'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration22'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration23'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration24'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration25'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration26'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration27'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration28'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'iteration29'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration30'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration31'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration32'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration33'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration34'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration35'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration36'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration37'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration38'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration39'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration40'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration41'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration42'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration43'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration44'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration45'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration46'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration47'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration48'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration49'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration50'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration51'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration52'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration53'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration54'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration55'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration56'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration57'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration58'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration59'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration60'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration61'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration62'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration63'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration64'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration65'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration66'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration67'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration68'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration69'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration70'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration71'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration72'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration73'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration74'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration75'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration76'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration77'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'iteration78'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration79'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration80'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration81'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'iteration82'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration83'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration84'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration85'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration86'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration87'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration88'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration89'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration90'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration91'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration92'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration93'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration94'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration95'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration96'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration97'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration98'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration99'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration100'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration101'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration102'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration103'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration104'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'iteration105'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration106'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration107'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration108'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration109'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'iteration110'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration111'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration112'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration113'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration114'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration115'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration116'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration117'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration118'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration119'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration120'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration121'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration122'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration123'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration124'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration125'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration126'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration127'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration128'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration129'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'iteration130'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration131'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration132'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration133'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration134'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration135'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration136'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration137'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration138'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration139'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration140'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration141'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration142'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration143'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'iteration144'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration145'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration146'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration147'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration148'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration149'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration150'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration151'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration152'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration153'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration154'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration155'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration156'
# ...
#   <__main__.Vehicle at 0x13ecb28e060>],
#  [<__main__.Vehicle at 0x13ecb28e120>,
#   <__main__.Vehicle at 0x13ecb28e1e0>,
#   <__main__.Vehicle at 0x13ecb28e2a0>],
#  [<__main__.Vehicle at 0x13ecb28e360>, <__main__.Vehicle at 0x13ecb28e420>],
#  [<__main__.Vehicle at 0x13ecb28e4e0>, <__main__.Vehicle at 0x13ecb28e5a0>],
#  [<__main__.Vehicle at 0x13ecb28e660>,
#   <__main__.Vehicle at 0x13ecb28e720>,
#   <__main__.Vehicle at 0x13ecb28e7e0>],
#  [<__main__.Vehicle at 0x13ecb28e8a0>,
#   <__main__.Vehicle at 0x13ecb28e960>,
#   <__main__.Vehicle at 0x13ecb28ea20>],
#  [<__main__.Vehicle at 0x13ecb28eae0>,
#   <__main__.Vehicle at 0x13ecb28eba0>,
#   <__main__.Vehicle at 0x13ecb28ec60>],
#  [<__main__.Vehicle at 0x13ecb28ed20>,
#   <__main__.Vehicle at 0x13ecb28ede0>,
#   <__main__.Vehicle at 0x13ecb28eea0>],
#  [<__main__.Vehicle at 0x13ecb28ef60>, <__main__.Vehicle at 0x13ecb28f020>],
#  [<__main__.Vehicle at 0x13ecb28f0e0>,
#   <__main__.Vehicle at 0x13ecb28f1a0>,
#   <__main__.Vehicle at 0x13ecb28f260>],
#  [<__main__.Vehicle at 0x13ecb28f320>,
#   <__main__.Vehicle at 0x13ecb28f3e0>,
#   <__main__.Vehicle at 0x13ecb28f4a0>],
#  [<__main__.Vehicle at 0x13ecb28f560>,
#   <__main__.Vehicle at 0x13ecb28f620>,
#   <__main__.Vehicle at 0x13ecb28f6e0>],
#  [<__main__.Vehicle at 0x13ecb28f7a0>, <__main__.Vehicle at 0x13ecb28f860>],
#  [<__main__.Vehicle at 0x13ecb28f920>, <__main__.Vehicle at 0x13ecb28f9e0>],
#  [<__main__.Vehicle at 0x13ecb28faa0>,
#   <__main__.Vehicle at 0x13ecb28fb60>,
#   <__main__.Vehicle at 0x13ecb28fc20>],
#  [<__main__.Vehicle at 0x13ecb28fce0>,
#   <__main__.Vehicle at 0x13ecb28fda0>,
#   <__main__.Vehicle at 0x13ecb28fe60>],
#  [<__main__.Vehicle at 0x13ecb28ff20>,
#   <__main__.Vehicle at 0x13ecb28ffe0>,
#   <__main__.Vehicle at 0x13ecb2940e0>],
#  [<__main__.Vehicle at 0x13ecb2941a0>,
#   <__main__.Vehicle at 0x13ecb294260>,
#   <__main__.Vehicle at 0x13ecb294320>],
#  [<__main__.Vehicle at 0x13ecb2943e0>,
#   <__main__.Vehicle at 0x13ecb2944a0>,
#   <__main__.Vehicle at 0x13ecb294560>],
#  [<__main__.Vehicle at 0x13ecb294620>,
#   <__main__.Vehicle at 0x13ecb2946e0>,
#   <__main__.Vehicle at 0x13ecb2947a0>],
#  [<__main__.Vehicle at 0x13ecb294860>,
#   <__main__.Vehicle at 0x13ecb294920>,
#   <__main__.Vehicle at 0x13ecb2949e0>],
#  [<__main__.Vehicle at 0x13ecb294aa0>,
#   <__main__.Vehicle at 0x13ecb294b60>,
#   <__main__.Vehicle at 0x13ecb294c20>],
#  [<__main__.Vehicle at 0x13ecb294ce0>,
#   <__main__.Vehicle at 0x13ecb294da0>,
#   <__main__.Vehicle at 0x13ecb294e60>],
#  [<__main__.Vehicle at 0x13ecb294f20>,
#   <__main__.Vehicle at 0x13ecb294fe0>,
#   <__main__.Vehicle at 0x13ecb2950a0>],
#  [<__main__.Vehicle at 0x13ecb295160>,
#   <__main__.Vehicle at 0x13ecb295220>,
#   <__main__.Vehicle at 0x13ecb2952e0>],
#  [<__main__.Vehicle at 0x13ecb2953a0>,
#   <__main__.Vehicle at 0x13ecb295460>,
#   <__main__.Vehicle at 0x13ecb295520>],
#  [<__main__.Vehicle at 0x13ecb2955e0>,
#   <__main__.Vehicle at 0x13ecb2956a0>,
#   <__main__.Vehicle at 0x13ecb295760>],
#  [<__main__.Vehicle at 0x13ecb295820>, <__main__.Vehicle at 0x13ecb2958e0>],
#  [<__main__.Vehicle at 0x13ecb2959a0>,
#   <__main__.Vehicle at 0x13ecb295a60>,
#   <__main__.Vehicle at 0x13ecb295b20>],
#  [<__main__.Vehicle at 0x13ecb295be0>,
#   <__main__.Vehicle at 0x13ecb295ca0>,
#   <__main__.Vehicle at 0x13ecb295d60>],
#  [<__main__.Vehicle at 0x13ecb295e20>,
#   <__main__.Vehicle at 0x13ecb295ee0>,
#   <__main__.Vehicle at 0x13ecb295fa0>],
#  [<__main__.Vehicle at 0x13ecb296060>,
#   <__main__.Vehicle at 0x13ecb296120>,
#   <__main__.Vehicle at 0x13ecb2961e0>],
#  [<__main__.Vehicle at 0x13ecb2962a0>,
#   <__main__.Vehicle at 0x13ecb296360>,
#   <__main__.Vehicle at 0x13ecb296420>],
#  [<__main__.Vehicle at 0x13ecb2964e0>,
#   <__main__.Vehicle at 0x13ecb2965a0>,
#   <__main__.Vehicle at 0x13ecb296660>],
#  [<__main__.Vehicle at 0x13ecb296720>, <__main__.Vehicle at 0x13ecb2967e0>],
#  [<__main__.Vehicle at 0x13ecb2968a0>,
#   <__main__.Vehicle at 0x13ecb296960>,
#   <__main__.Vehicle at 0x13ecb296a20>],
#  [<__main__.Vehicle at 0x13ecb296ae0>,
#   <__main__.Vehicle at 0x13ecb296ba0>,
#   <__main__.Vehicle at 0x13ecb296c60>],
#  [<__main__.Vehicle at 0x13ecb296d20>,
#   <__main__.Vehicle at 0x13ecb296de0>,
#   <__main__.Vehicle at 0x13ecb296ea0>],
#  [<__main__.Vehicle at 0x13ecb296f60>,
#   <__main__.Vehicle at 0x13ecb297020>,
#   <__main__.Vehicle at 0x13ecb2970e0>],
#  [<__main__.Vehicle at 0x13ecb2971a0>,
#   <__main__.Vehicle at 0x13ecb297260>,
#   <__main__.Vehicle at 0x13ecb297320>],
#  [<__main__.Vehicle at 0x13ecb2973e0>,
#   <__main__.Vehicle at 0x13ecb2974a0>,
#   <__main__.Vehicle at 0x13ecb297560>],
#  [<__main__.Vehicle at 0x13ecb297620>,
#   <__main__.Vehicle at 0x13ecb2976e0>,
#   <__main__.Vehicle at 0x13ecb2977a0>],
#  [<__main__.Vehicle at 0x13ecb297860>, <__main__.Vehicle at 0x13ecb297920>],
#  [<__main__.Vehicle at 0x13ecb2979e0>,
#   <__main__.Vehicle at 0x13ecb297aa0>,
#   <__main__.Vehicle at 0x13ecb297b60>],
#  [<__main__.Vehicle at 0x13ecb297c20>, <__main__.Vehicle at 0x13ecb297ce0>],
#  [<__main__.Vehicle at 0x13ecb297da0>,
#   <__main__.Vehicle at 0x13ecb297e60>,
#   <__main__.Vehicle at 0x13ecb297f20>],
#  [<__main__.Vehicle at 0x13ecb297fe0>,
#   <__main__.Vehicle at 0x13ecb2980e0>,
#   <__main__.Vehicle at 0x13ecb2981a0>],
#  [<__main__.Vehicle at 0x13ecb298260>,
#   <__main__.Vehicle at 0x13ecb298320>,
#   <__main__.Vehicle at 0x13ecb2983e0>],
#  [<__main__.Vehicle at 0x13ecb2984a0>,
#   <__main__.Vehicle at 0x13ecb298560>,
#   <__main__.Vehicle at 0x13ecb298620>],
#  [<__main__.Vehicle at 0x13ecb2986e0>,
#   <__main__.Vehicle at 0x13ecb2987a0>,
#   <__main__.Vehicle at 0x13ecb298860>],
#  [<__main__.Vehicle at 0x13ecb298920>,
#   <__main__.Vehicle at 0x13ecb2989e0>,
#   <__main__.Vehicle at 0x13ecb298aa0>],
#  [<__main__.Vehicle at 0x13ecb298b60>, <__main__.Vehicle at 0x13ecb298c20>],
#  [<__main__.Vehicle at 0x13ecb298ce0>, <__main__.Vehicle at 0x13ecb298da0>],
#  [<__main__.Vehicle at 0x13ecb298e60>,
#   <__main__.Vehicle at 0x13ecb298f20>,
#   <__main__.Vehicle at 0x13ecb298fe0>],
#  [<__main__.Vehicle at 0x13ecb2990a0>,
#   <__main__.Vehicle at 0x13ecb299160>,
#   <__main__.Vehicle at 0x13ecb299220>],
#  [<__main__.Vehicle at 0x13ecb2992e0>,
#   <__main__.Vehicle at 0x13ecb2993a0>,
#   <__main__.Vehicle at 0x13ecb299460>],
#  [<__main__.Vehicle at 0x13ecb299520>, <__main__.Vehicle at 0x13ecb2995e0>],
#  [<__main__.Vehicle at 0x13ecb2996a0>,
#   <__main__.Vehicle at 0x13ecb299760>,
#   <__main__.Vehicle at 0x13ecb299820>],
#  [<__main__.Vehicle at 0x13ecb2998e0>, <__main__.Vehicle at 0x13ecb2999a0>],
#  [<__main__.Vehicle at 0x13ecb299a60>,
#   <__main__.Vehicle at 0x13ecb299b20>,
#   <__main__.Vehicle at 0x13ecb299be0>],
#  [<__main__.Vehicle at 0x13ecb299ca0>,
#   <__main__.Vehicle at 0x13ecb299d60>,
#   <__main__.Vehicle at 0x13ecb299e20>],
#  [<__main__.Vehicle at 0x13ecb299ee0>,
#   <__main__.Vehicle at 0x13ecb299fa0>,
#   <__main__.Vehicle at 0x13ecb29a060>],
#  [<__main__.Vehicle at 0x13ecb29a120>,
#   <__main__.Vehicle at 0x13ecb29a1e0>,
#   <__main__.Vehicle at 0x13ecb29a2a0>],
#  [<__main__.Vehicle at 0x13ecb29a360>, <__main__.Vehicle at 0x13ecb29a420>],
#  [<__main__.Vehicle at 0x13ecb29a4e0>,
#   <__main__.Vehicle at 0x13ecb29a5a0>,
#   <__main__.Vehicle at 0x13ecb29a660>],
#  [<__main__.Vehicle at 0x13ecb29a720>, <__main__.Vehicle at 0x13ecb29a7e0>],
#  [<__main__.Vehicle at 0x13ecb29a8a0>, <__main__.Vehicle at 0x13ecb29a960>],
#  [<__main__.Vehicle at 0x13ecb29aa20>,
#   <__main__.Vehicle at 0x13ecb29aae0>,
#   <__main__.Vehicle at 0x13ecb29aba0>],
#  [<__main__.Vehicle at 0x13ecb29ac60>,
#   <__main__.Vehicle at 0x13ecb29ad20>,
#   <__main__.Vehicle at 0x13ecb29ade0>],
#  [<__main__.Vehicle at 0x13ecb29aea0>,
#   <__main__.Vehicle at 0x13ecb29af60>,
#   <__main__.Vehicle at 0x13ecb29b020>],
#  [<__main__.Vehicle at 0x13ecb29b0e0>,
#   <__main__.Vehicle at 0x13ecb29b1a0>,
#   <__main__.Vehicle at 0x13ecb29b260>],
#  [<__main__.Vehicle at 0x13ecb29b320>, <__main__.Vehicle at 0x13ecb29b3e0>],
#  [<__main__.Vehicle at 0x13ecb29b4a0>,
#   <__main__.Vehicle at 0x13ecb29b560>,
#   <__main__.Vehicle at 0x13ecb29b620>],
#  [<__main__.Vehicle at 0x13ecb29b6e0>,
#   <__main__.Vehicle at 0x13ecb29b7a0>,
#   <__main__.Vehicle at 0x13ecb29b860>],
#  [<__main__.Vehicle at 0x13ecb29b920>, <__main__.Vehicle at 0x13ecb29b9e0>],
#  [<__main__.Vehicle at 0x13ecb29baa0>, <__main__.Vehicle at 0x13ecb29bb60>],
#  [<__main__.Vehicle at 0x13ecb29bc20>,
#   <__main__.Vehicle at 0x13ecb29bce0>,
#   <__main__.Vehicle at 0x13ecb29bda0>],
#  [<__main__.Vehicle at 0x13ecb29be60>,
#   <__main__.Vehicle at 0x13ecb29bf20>,
#   <__main__.Vehicle at 0x13ecb29bfe0>],
#  [<__main__.Vehicle at 0x13ecb2a00e0>,
#   <__main__.Vehicle at 0x13ecb2a01a0>,
#   <__main__.Vehicle at 0x13ecb2a0260>],
#  [<__main__.Vehicle at 0x13ecb2a0320>,
#   <__main__.Vehicle at 0x13ecb2a03e0>,
#   <__main__.Vehicle at 0x13ecb2a04a0>],
#  [<__main__.Vehicle at 0x13ecb2a0560>, <__main__.Vehicle at 0x13ecb2a0620>],
#  [<__main__.Vehicle at 0x13ecb2a06e0>,
#   <__main__.Vehicle at 0x13ecb2a07a0>,
#   <__main__.Vehicle at 0x13ecb2a0860>],
#  [<__main__.Vehicle at 0x13ecb2a0920>, <__main__.Vehicle at 0x13ecb2a09e0>],
#  [<__main__.Vehicle at 0x13ecb2a0aa0>,
#   <__main__.Vehicle at 0x13ecb2a0b60>,
#   <__main__.Vehicle at 0x13ecb2a0c20>],
#  [<__main__.Vehicle at 0x13ecb2a0ce0>,
#   <__main__.Vehicle at 0x13ecb2a0da0>,
#   <__main__.Vehicle at 0x13ecb2a0e60>],
#  [<__main__.Vehicle at 0x13ecb2a0f20>, <__main__.Vehicle at 0x13ecb2a0fe0>],
#  [<__main__.Vehicle at 0x13ecb2a10a0>, <__main__.Vehicle at 0x13ecb2a1160>],
#  [<__main__.Vehicle at 0x13ecb2a1220>, <__main__.Vehicle at 0x13ecb2a12e0>],
#  [<__main__.Vehicle at 0x13ecb2a13a0>, <__main__.Vehicle at 0x13ecb2a1460>],
#  [<__main__.Vehicle at 0x13ecb2a1520>,
#   <__main__.Vehicle at 0x13ecb2a15e0>,
#   <__main__.Vehicle at 0x13ecb2a16a0>],
#  [<__main__.Vehicle at 0x13ecb2a1760>,
#   <__main__.Vehicle at 0x13ecb2a1820>,
#   <__main__.Vehicle at 0x13ecb2a18e0>],
#  [<__main__.Vehicle at 0x13ecb2a19a0>,
#   <__main__.Vehicle at 0x13ecb2a1a60>,
#   <__main__.Vehicle at 0x13ecb2a1b20>],
#  [<__main__.Vehicle at 0x13ecb2a1be0>,
#   <__main__.Vehicle at 0x13ecb2a1ca0>,
#   <__main__.Vehicle at 0x13ecb2a1d60>],
#  [<__main__.Vehicle at 0x13ecb2a1e20>,
#   <__main__.Vehicle at 0x13ecb2a1ee0>,
#   <__main__.Vehicle at 0x13ecb2a1fa0>],
#  [<__main__.Vehicle at 0x13ecb2a2060>,
#   <__main__.Vehicle at 0x13ecb2a2120>,
#   <__main__.Vehicle at 0x13ecb2a21e0>],
#  [<__main__.Vehicle at 0x13ecb2a22a0>, <__main__.Vehicle at 0x13ecb2a2360>],
#  [<__main__.Vehicle at 0x13ecb2a2420>,
#   <__main__.Vehicle at 0x13ecb2a24e0>,
#   <__main__.Vehicle at 0x13ecb2a25a0>],
#  [<__main__.Vehicle at 0x13ecb2a2660>,
#   <__main__.Vehicle at 0x13ecb2a2720>,
#   <__main__.Vehicle at 0x13ecb2a27e0>],
#  [<__main__.Vehicle at 0x13ecb2a28a0>,
#   <__main__.Vehicle at 0x13ecb2a2960>,
#   <__main__.Vehicle at 0x13ecb2a2a20>],
#  [<__main__.Vehicle at 0x13ecb2a2ae0>,
#   <__main__.Vehicle at 0x13ecb2a2ba0>,
#   <__main__.Vehicle at 0x13ecb2a2c60>],
#  [<__main__.Vehicle at 0x13ecb2a2d20>,
#   <__main__.Vehicle at 0x13ecb2a2de0>,
#   <__main__.Vehicle at 0x13ecb2a2ea0>],
#  [<__main__.Vehicle at 0x13ecb2a2f60>,
#   <__main__.Vehicle at 0x13ecb2a3020>,
#   <__main__.Vehicle at 0x13ecb2a30e0>],
#  [<__main__.Vehicle at 0x13ecb2a31a0>,
#   <__main__.Vehicle at 0x13ecb2a3260>,
#   <__main__.Vehicle at 0x13ecb2a3320>],
#  [<__main__.Vehicle at 0x13ecb2a33e0>, <__main__.Vehicle at 0x13ecb2a34a0>],
#  [<__main__.Vehicle at 0x13ecb2a3560>, <__main__.Vehicle at 0x13ecb2a3620>],
#  [<__main__.Vehicle at 0x13ecb2a36e0>,
#   <__main__.Vehicle at 0x13ecb2a37a0>,
#   <__main__.Vehicle at 0x13ecb2a3860>],
#  [<__main__.Vehicle at 0x13ecb2a3920>,
#   <__main__.Vehicle at 0x13ecb2a39e0>,
#   <__main__.Vehicle at 0x13ecb2a3aa0>],
#  [<__main__.Vehicle at 0x13ecb2a3b60>,
#   <__main__.Vehicle at 0x13ecb2a3c20>,
#   <__main__.Vehicle at 0x13ecb2a3ce0>],
#  [<__main__.Vehicle at 0x13ecb2a3da0>,
#   <__main__.Vehicle at 0x13ecb2a3e60>,
#   <__main__.Vehicle at 0x13ecb2a3f20>],
#  [<__main__.Vehicle at 0x13ecb2a3fe0>,
#   <__main__.Vehicle at 0x13ecb2a80e0>,
#   <__main__.Vehicle at 0x13ecb2a81a0>],
#  [<__main__.Vehicle at 0x13ecb2a8260>,
#   <__main__.Vehicle at 0x13ecb2a8320>,
#   <__main__.Vehicle at 0x13ecb2a83e0>],
#  [<__main__.Vehicle at 0x13ecb2a84a0>,
#   <__main__.Vehicle at 0x13ecb2a8560>,
#   <__main__.Vehicle at 0x13ecb2a8620>],
#  [<__main__.Vehicle at 0x13ecb2a86e0>,
#   <__main__.Vehicle at 0x13ecb2a87a0>,
#   <__main__.Vehicle at 0x13ecb2a8860>],
#  [<__main__.Vehicle at 0x13ecb2a8920>, <__main__.Vehicle at 0x13ecb2a89e0>],
#  [<__main__.Vehicle at 0x13ecb2a8aa0>,
#   <__main__.Vehicle at 0x13ecb2a8b60>,
#   <__main__.Vehicle at 0x13ecb2a8c20>],
#  [<__main__.Vehicle at 0x13ecb2a8ce0>, <__main__.Vehicle at 0x13ecb2a8da0>],
#  [<__main__.Vehicle at 0x13ecb2a8e60>,
#   <__main__.Vehicle at 0x13ecb2a8f20>,
#   <__main__.Vehicle at 0x13ecb2a8fe0>],
#  [<__main__.Vehicle at 0x13ecb2a90a0>,
#   <__main__.Vehicle at 0x13ecb2a9160>,
#   <__main__.Vehicle at 0x13ecb2a9220>],
#  [<__main__.Vehicle at 0x13ecb2a92e0>,
#   <__main__.Vehicle at 0x13ecb2a93a0>,
#   <__main__.Vehicle at 0x13ecb2a9460>],
#  [<__main__.Vehicle at 0x13ecb2a9520>, <__main__.Vehicle at 0x13ecb2a95e0>],
#  [<__main__.Vehicle at 0x13ecb2a96a0>,
#   <__main__.Vehicle at 0x13ecb2a9760>,
#   <__main__.Vehicle at 0x13ecb2a9820>],
#  [<__main__.Vehicle at 0x13ecb2a98e0>,
#   <__main__.Vehicle at 0x13ecb2a99a0>,
#   <__main__.Vehicle at 0x13ecb2a9a60>],
#  [<__main__.Vehicle at 0x13ecb2a9b20>,
#   <__main__.Vehicle at 0x13ecb2a9be0>,
#   <__main__.Vehicle at 0x13ecb2a9ca0>],
#  [<__main__.Vehicle at 0x13ecb2a9d60>,
#   <__main__.Vehicle at 0x13ecb2a9e20>,
#   <__main__.Vehicle at 0x13ecb2a9ee0>],
#  [<__main__.Vehicle at 0x13ecb2a9fa0>,
#   <__main__.Vehicle at 0x13ecb2aa060>,
#   <__main__.Vehicle at 0x13ecb2aa120>],
#  [<__main__.Vehicle at 0x13ecb2aa1e0>,
#   <__main__.Vehicle at 0x13ecb2aa2a0>,
#   <__main__.Vehicle at 0x13ecb2aa360>],
#  [<__main__.Vehicle at 0x13ecb2aa420>,
#   <__main__.Vehicle at 0x13ecb2aa4e0>,
#   <__main__.Vehicle at 0x13ecb2aa5a0>],
#  [<__main__.Vehicle at 0x13ecb2aa660>,
#   <__main__.Vehicle at 0x13ecb2aa720>,
#   <__main__.Vehicle at 0x13ecb2aa7e0>],
#  [<__main__.Vehicle at 0x13ecb2aa8a0>,
#   <__main__.Vehicle at 0x13ecb2aa960>,
#   <__main__.Vehicle at 0x13ecb2aaa20>],
#  [<__main__.Vehicle at 0x13ecb2aaae0>,
#   <__main__.Vehicle at 0x13ecb2aaba0>,
#   <__main__.Vehicle at 0x13ecb2aac60>],
#  [<__main__.Vehicle at 0x13ecb2aad20>, <__main__.Vehicle at 0x13ecb2aade0>],
#  [<__main__.Vehicle at 0x13ecb2aaea0>,
#   <__main__.Vehicle at 0x13ecb2aaf60>,
#   <__main__.Vehicle at 0x13ecb2ab020>],
#  [<__main__.Vehicle at 0x13ecb2ab0e0>,
#   <__main__.Vehicle at 0x13ecb2ab1a0>,
#   <__main__.Vehicle at 0x13ecb2ab260>],
#  [<__main__.Vehicle at 0x13ecb2ab320>,
#   <__main__.Vehicle at 0x13ecb2ab3e0>,
#   <__main__.Vehicle at 0x13ecb2ab4a0>],
#  [<__main__.Vehicle at 0x13ecb2ab560>,
#   <__main__.Vehicle at 0x13ecb2ab620>,
#   <__main__.Vehicle at 0x13ecb2ab6e0>],
#  [<__main__.Vehicle at 0x13ecb2ab7a0>,
#   <__main__.Vehicle at 0x13ecb2ab860>,
#   <__main__.Vehicle at 0x13ecb2ab920>],
#  [<__main__.Vehicle at 0x13ecb2ab9e0>,
#   <__main__.Vehicle at 0x13ecb2abaa0>,
#   <__main__.Vehicle at 0x13ecb2abb60>],
#  [<__main__.Vehicle at 0x13ecb2abc20>,
#   <__main__.Vehicle at 0x13ecb2abce0>,
#   <__main__.Vehicle at 0x13ecb2abda0>],
#  [<__main__.Vehicle at 0x13ecb2abe60>,
#   <__main__.Vehicle at 0x13ecb2abf20>,
#   <__main__.Vehicle at 0x13ecb2abfe0>],
#  [<__main__.Vehicle at 0x13ecb2ac0e0>,
#   <__main__.Vehicle at 0x13ecb2ac1a0>,
#   <__main__.Vehicle at 0x13ecb2ac260>],
#  [<__main__.Vehicle at 0x13ecb2ac320>,
#   <__main__.Vehicle at 0x13ecb2ac3e0>,
#   <__main__.Vehicle at 0x13ecb2ac4a0>],
#  [<__main__.Vehicle at 0x13ecb2ac560>,
#   <__main__.Vehicle at 0x13ecb2ac620>,
#   <__main__.Vehicle at 0x13ecb2ac6e0>],
#  [<__main__.Vehicle at 0x13ecb2ac7a0>,
#   <__main__.Vehicle at 0x13ecb2ac860>,
#   <__main__.Vehicle at 0x13ecb2ac920>],
#  [<__main__.Vehicle at 0x13ecb2ac9e0>,
#   <__main__.Vehicle at 0x13ecb2acaa0>,
#   <__main__.Vehicle at 0x13ecb2acb60>],
#  [<__main__.Vehicle at 0x13ecb2acc20>,
#   <__main__.Vehicle at 0x13ecb2acce0>,
#   <__main__.Vehicle at 0x13ecb2acda0>],
#  [<__main__.Vehicle at 0x13ecb2ace60>,
#   <__main__.Vehicle at 0x13ecb2acf20>,
#   <__main__.Vehicle at 0x13ecb2acfe0>],
#  [<__main__.Vehicle at 0x13ecb2ad0a0>, <__main__.Vehicle at 0x13ecb2ad160>],
#  [<__main__.Vehicle at 0x13ecb2ad220>, <__main__.Vehicle at 0x13ecb2ad2e0>]]

# %%
# routes do not need to include depot at end, but shoudl include depot at start

# %% [markdown]
# # Tournament Selection

# %%
# Randomly choose 20 samples, get one parent
def getParent():
    choices = random.sample(solutions, 20)

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = 0
        for vehicle in vehicles:
            fitness = Fitness(vehicle)
            cost = fitness.cost()
            solutionCost += cost
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))

    return choices[minpos]

firstParent = getParent()
secondParent = getParent()

print(firstParent)
secondParent
# Out:
# [<__main__.Vehicle object at 0x0000013ECB1EB620>,
#  <__main__.Vehicle object at 0x0000013ECB1EB6E0>,
#  <__main__.Vehicle object at 0x0000013ECB1EB7A0>]
# [<__main__.Vehicle at 0x13ecb2571a0>,
#  <__main__.Vehicle at 0x13ecb257260>,
#  <__main__.Vehicle at 0x13ecb257320>]

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

def getDuplicatedElements(li):
    duplicates = []
    for x in li:
        if x not in duplicates and li.count(x) >1:
            duplicates.append(x)
        
    return duplicates

# %%
# drop start point when crossing over

first = [[3.0, 4.0, 2.0, 6.0], [7.0, 1.0, 5.0, 9.0], [8.0, 10.0]]
firstVehicles = ['B', 'A', 'B']
second = [[4.0, 6.0, 5.0], [3.0, 1.0, 2.0, 7.0, 10.0], [8.0, 9.0]]
secondVehicles = ['A', 'B', 'A']


selectedVehicleIdx = 1
selectedToSwapVehicle = [3.0, 1.0, 2.0, 7.0, 10.0]
selectedToSwapVehicleIdx = 1

# first = [[],[],[]]
# firstVehicles = []

# for i in range(len(firstParent)):
#     firstParent[i].routes.pop(0)
#     firstVehicles.append(firstParent[i].type)
#     # for every route
#     for j in range(len(firstParent[i].routes)):
#         first[i].append(firstParent[i].routes[j].id)



# second = [[],[],[]]
# secondVehicles = []


# for i in range(len(secondParent)):
#     secondParent[i].routes.pop(0)
#     secondVehicles.append(secondParent[i].type)
#     # for every route
#     for j in range(len(secondParent[i].routes)):
#         second[i].append(secondParent[i].routes[j].id)


# selectedFirstVehicle = random.choice(first)
# selectedFirstVehicleIdx = first.index(selectedFirstVehicle)

# selectedSecondVehicle = random.choice(second)
# selectedSecondVehicleIdx = second.index(selectedSecondVehicle)


first = convertToOneDList(first)
second = convertToOneDList(second)

# Random Choice of 1,2,3,4
choice = random.randInt(0, 2)
# Case 1 - first parent is  main, two vehicles remain, one vehicle changes

if (choice == 1 or choice == 2):
    if (choice == 1):
        parent = first
        # selectedVehicleIdx = random.randInt(0, len(parent)-1)
        # selectedToSwapVehicle = random.choice(secondary)
        parent[selectedVehicleIdx] = selectedToSwapVehicle
        
        

    # Case 2 - second parent is main, two vehicles remain, one vehicle changes
    elif (choice == 2):
        parent = second
        # selectedVehicleIdx = random.randInt(0, len(parent)-1)
        # selectedToSwapVehicle = random.choice(secondary)
        parent[selectedVehicleIdx] = selectedToSwapVehicle
        child = parent

    missing = findMissing(parent)
    duplicates = getDuplicatedElements(parent)

    child = []
    for i in first:
        if i not in child:
            child.append(i)
        else:
            if(missing):
                child.append(missing[0])
                missing.pop(0)

    if (missing):
        child += missing


elif (choice == 3 or choice == 4):
    # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
    if (choice == 3):
        child = first
    # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
    elif (choice == 4):
        child = second

# pending to be deleted
# missing = findMissing(parent)
# missingInSecond = findMissing(second)
# dupFirst = getDuplicatedElements(first)
# dupSecond = getDuplicatedElements(second)
# print(dupFirst)
# print(dupSecond)

# outFirst = []
# for i in first:
#     if i not in outFirst:
#         outFirst.append(i)
#     else:
#         if(missingInFirst):
#             outFirst.append(missingInFirst[0])
#             missingInFirst.pop(0)

# if (missingInFirst):
#     outFirst += missingInFirst

# print(outFirst)


# outSecond = []
# for i in second:
#     if i not in outSecond:
#         outSecond.append(i)
#     else:
#         if(missingInSecond):
#             outSecond.append(missingInSecond[0])
#             missingInSecond.pop(0)

# if (missingInSecond):
#     outSecond += missingInSecond


# print(outSecond)

# first = outFirst
# second = outSecond
# Out:
# [3, 2, 10]
# [5, 9]
# [3, 4, 2, 6, 5, 1, 9, 7, 10, 8]
# [4, 6, 5, 7, 1, 2, 9, 8, 3, 10]

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation
def vehicleMutation(li):
    idx = random.randint(0, len(li)-1)
    if li[idx] == 'A':
        li[idx] = 'B'
    else:
        li[idx] = 'A'
    
    return li

# Routes Mutation - Swap
def routeMutation(li):
    aIdx = random.randint(0, len(li)-1)
    bIdx = random.randint(0, len(li)-1)

    temp = li[aIdx]
    li[aIdx] = li[bIdx]
    li[bIdx] = temp

    return li

# %%
print(firstVehicles)
print(vehicleMutation(firstVehicles))
print(firstVehicles)

print(first)
print(routeMutation(first))
# Out:
# ['B', 'B', 'B']
# ['B', 'A', 'B']
# ['B', 'A', 'B']
# [3, 4, 7, 6, 5, 1, 9, 2, 10, 8]
# [3, 4, 7, 6, 5, 1, 9, 2, 10, 8]
