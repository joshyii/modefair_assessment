# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.customers = []
        self.rate = None
        self.capacity = None

    def addCustomer(self, customer):
        self.customers.append(customer)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.customers.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
        self.distance = None

    
    def getDistance(self):
        route = self.vehicle.customers
        distance = 0

        for i in range (0, len(route)):
            fromCity = route[i]
            if i+1 < len(route):
                toCity = route[i+1]

            # return to depot
            else:
                toCity = route[0]
            
            distance += fromCity.distance(toCity)

        return distance

    def getCost(self):
        self.distance = self.getDistance()
        return self.distance*(self.vehicle.rate)  
    
    def getDemand(self):
        route = self.vehicle.customers
        totalDemand = 0

        for customer in route:
            totalDemand += customer.demand

        return totalDemand

# %% [markdown]
# # Generate Population

# %%
# Read data
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

customers = []
for i in li:
    customers.append(Customer(i[0], i[1], i[2], i[3]))


# Generate population
solutions = [] #array of vehicles
populationSize = 1000
for s in range(populationSize):
    print('iteration'+ str(s+1))
    customersToFulfill = customers.copy()

    vehicles = []

    while(len(customersToFulfill) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(customersToFulfill):
            selectedCustomer = random.choice(customersToFulfill)
            if((filledCapacity+selectedCustomer.demand) <= vehicle.capacity):
                filledCapacity += selectedCustomer.demand
                vehicle.addCustomer(selectedCustomer)
                customersToFulfill.remove(selectedCustomer)
                print('Customer ' + str(selectedCustomer.id) + ', demand ' + str(selectedCustomer.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# iteration1
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# iteration2
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# iteration3
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# iteration4
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# iteration5
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration6
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# iteration7
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# iteration8
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# iteration9
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# iteration10
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# iteration11
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration12
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration13
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# iteration14
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# iteration15
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration16
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# iteration17
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# iteration18
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# iteration19
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# iteration20
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# iteration21
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# iteration22
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# iteration23
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# iteration24
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# iteration25
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration26
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# iteration27
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# iteration28
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration29
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# iteration30
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# iteration31
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# iteration32
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# iteration33
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration34
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# iteration35
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# iteration36
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# iteration37
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# iteration38
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# iteration39
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# iteration40
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# iteration41
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# iteration42
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# iteration43
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# iteration44
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# iteration45
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# iteration46
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# iteration47
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# iteration48
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# iteration49
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# iteration50
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# iteration51
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# iteration52
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# iteration53
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# iteration54
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# iteration55
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# iteration56
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# iteration57
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# iteration58
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# iteration59
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# iteration60
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# iteration61
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# iteration62
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# iteration63
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# iteration64
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# iteration65
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# iteration66
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration67
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# iteration68
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration69
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# iteration70
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# iteration71
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# iteration72
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration73
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration74
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# iteration75
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# iteration76
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration77
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# iteration78
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# iteration79
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# iteration80
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# iteration81
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration82
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# iteration83
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# iteration84
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# iteration85
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# iteration86
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# iteration87
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# iteration88
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# iteration89
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# iteration90
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# iteration91
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration92
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration93
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# iteration94
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# iteration95
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# iteration96
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# iteration97
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# iteration98
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# iteration99
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration100
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration101
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# iteration102
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# iteration103
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# iteration104
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration105
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# iteration106
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# iteration107
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# iteration108
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# iteration109
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# iteration110
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# iteration111
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# iteration112
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# iteration113
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# iteration114
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# iteration115
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# iteration116
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# iteration117
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration118
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# iteration119
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# iteration120
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# iteration121
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# iteration122
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# iteration123
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# iteration124
# Chosen vehicle B
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# iteration125
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# iteration126
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# iteration127
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# iteration128
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# iteration129
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration130
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 9.0, demand 5.0
# iteration131
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# iteration132
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# iteration133
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# iteration134
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# iteration135
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# iteration136
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# iteration137
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Chosen vehicle A
# Customer 5.0, demand 5.0
# iteration138
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# iteration139
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# iteration140
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# iteration141
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 1.0, demand 5.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 3.0, demand 3.0
# iteration142
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 2.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Customer 9.0, demand 5.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# iteration143
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 7.0, demand 3.0
# iteration144
# Chosen vehicle A
# Customer 4.0, demand 6.0
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 3.0, demand 3.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# iteration145
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# iteration146
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 10.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 2.0, demand 8.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# iteration147
# Chosen vehicle A
# Customer 3.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 2.0, demand 8.0
# Customer 5.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Chosen vehicle A
# Customer 9.0, demand 5.0
# Customer 7.0, demand 3.0
# iteration148
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 8.0, demand 6.0
# Chosen vehicle A
# Customer 7.0, demand 3.0
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 5.0, demand 5.0
# Chosen vehicle B
# Customer 9.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 4.0, demand 6.0
# iteration149
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle A
# Customer 6.0, demand 8.0
# Customer 3.0, demand 3.0
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 5.0, demand 5.0
# iteration150
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 3.0, demand 3.0
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 6.0, demand 8.0
# Customer 10.0, demand 8.0
# Customer 7.0, demand 3.0
# iteration151
# Chosen vehicle B
# Customer 7.0, demand 3.0
# Customer 8.0, demand 6.0
# Customer 1.0, demand 5.0
# Customer 4.0, demand 6.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 6.0, demand 8.0
# iteration152
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 2.0, demand 8.0
# Chosen vehicle B
# Customer 10.0, demand 8.0
# Customer 6.0, demand 8.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# iteration153
# Chosen vehicle A
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# Customer 3.0, demand 3.0
# Customer 7.0, demand 3.0
# Customer 6.0, demand 8.0
# Chosen vehicle A
# Customer 1.0, demand 5.0
# Customer 2.0, demand 8.0
# Customer 10.0, demand 8.0
# Chosen vehicle B
# Customer 4.0, demand 6.0
# Customer 9.0, demand 5.0
# iteration154
# Chosen vehicle B
# Customer 8.0, demand 6.0
# Customer 10.0, demand 8.0
# Customer 2.0, demand 8.0
# Customer 4.0, demand 6.0
# Chosen vehicle B
# Customer 6.0, demand 8.0
# Customer 1.0, demand 5.0
# Customer 3.0, demand 3.0
# Customer 9.0, demand 5.0
# Customer 5.0, demand 5.0
# Customer 7.0, demand 3.0
# iteration155
# Chosen vehicle B
# Customer 1.0, demand 5.0
# Customer 7.0, demand 3.0
# Customer 5.0, demand 5.0
# Customer 8.0, demand 6.0
# ...
#   <__main__.Vehicle at 0x173841905c0>],
#  [<__main__.Vehicle at 0x17384190680>,
#   <__main__.Vehicle at 0x17384190740>,
#   <__main__.Vehicle at 0x17384190800>],
#  [<__main__.Vehicle at 0x173841908c0>,
#   <__main__.Vehicle at 0x17384190980>,
#   <__main__.Vehicle at 0x17384190a40>],
#  [<__main__.Vehicle at 0x17384190b00>, <__main__.Vehicle at 0x17384190bc0>],
#  [<__main__.Vehicle at 0x17384190c80>, <__main__.Vehicle at 0x17384190d40>],
#  [<__main__.Vehicle at 0x17384190e00>, <__main__.Vehicle at 0x17384190ec0>],
#  [<__main__.Vehicle at 0x17384190f80>,
#   <__main__.Vehicle at 0x17384191040>,
#   <__main__.Vehicle at 0x17384191100>],
#  [<__main__.Vehicle at 0x173841911c0>, <__main__.Vehicle at 0x17384191280>],
#  [<__main__.Vehicle at 0x17384191340>,
#   <__main__.Vehicle at 0x17384191400>,
#   <__main__.Vehicle at 0x173841914c0>],
#  [<__main__.Vehicle at 0x17384191580>,
#   <__main__.Vehicle at 0x17384191640>,
#   <__main__.Vehicle at 0x17384191700>],
#  [<__main__.Vehicle at 0x173841917c0>,
#   <__main__.Vehicle at 0x17384191880>,
#   <__main__.Vehicle at 0x17384191940>],
#  [<__main__.Vehicle at 0x17384191a00>,
#   <__main__.Vehicle at 0x17384191ac0>,
#   <__main__.Vehicle at 0x17384191b80>],
#  [<__main__.Vehicle at 0x17384191c40>,
#   <__main__.Vehicle at 0x17384191d00>,
#   <__main__.Vehicle at 0x17384191dc0>],
#  [<__main__.Vehicle at 0x17384191e80>,
#   <__main__.Vehicle at 0x17384191f40>,
#   <__main__.Vehicle at 0x17384192000>],
#  [<__main__.Vehicle at 0x173841920c0>,
#   <__main__.Vehicle at 0x17384192180>,
#   <__main__.Vehicle at 0x17384192240>],
#  [<__main__.Vehicle at 0x17384192300>, <__main__.Vehicle at 0x173841923c0>],
#  [<__main__.Vehicle at 0x17384192480>,
#   <__main__.Vehicle at 0x17384192540>,
#   <__main__.Vehicle at 0x17384192600>],
#  [<__main__.Vehicle at 0x173841926c0>,
#   <__main__.Vehicle at 0x17384192780>,
#   <__main__.Vehicle at 0x17384192840>],
#  [<__main__.Vehicle at 0x17384192900>, <__main__.Vehicle at 0x173841929c0>],
#  [<__main__.Vehicle at 0x17384192a80>,
#   <__main__.Vehicle at 0x17384192b40>,
#   <__main__.Vehicle at 0x17384192c00>],
#  [<__main__.Vehicle at 0x17384192cc0>,
#   <__main__.Vehicle at 0x17384192d80>,
#   <__main__.Vehicle at 0x17384192e40>],
#  [<__main__.Vehicle at 0x17384192f00>,
#   <__main__.Vehicle at 0x17384192fc0>,
#   <__main__.Vehicle at 0x17384193080>],
#  [<__main__.Vehicle at 0x17384193140>,
#   <__main__.Vehicle at 0x17384193200>,
#   <__main__.Vehicle at 0x173841932c0>],
#  [<__main__.Vehicle at 0x17384193380>,
#   <__main__.Vehicle at 0x17384193440>,
#   <__main__.Vehicle at 0x17384193500>],
#  [<__main__.Vehicle at 0x173841935c0>,
#   <__main__.Vehicle at 0x17384193680>,
#   <__main__.Vehicle at 0x17384193740>],
#  [<__main__.Vehicle at 0x17384193800>,
#   <__main__.Vehicle at 0x173841938c0>,
#   <__main__.Vehicle at 0x17384193980>],
#  [<__main__.Vehicle at 0x17384193a40>,
#   <__main__.Vehicle at 0x17384193b00>,
#   <__main__.Vehicle at 0x17384193bc0>],
#  [<__main__.Vehicle at 0x17384193c80>, <__main__.Vehicle at 0x17384193d40>],
#  [<__main__.Vehicle at 0x17384193e00>,
#   <__main__.Vehicle at 0x17384193ec0>,
#   <__main__.Vehicle at 0x17384193f80>],
#  [<__main__.Vehicle at 0x17384194080>,
#   <__main__.Vehicle at 0x17384194140>,
#   <__main__.Vehicle at 0x17384194200>],
#  [<__main__.Vehicle at 0x173841942c0>,
#   <__main__.Vehicle at 0x17384194380>,
#   <__main__.Vehicle at 0x17384194440>],
#  [<__main__.Vehicle at 0x17384194500>,
#   <__main__.Vehicle at 0x173841945c0>,
#   <__main__.Vehicle at 0x17384194680>],
#  [<__main__.Vehicle at 0x17384194740>,
#   <__main__.Vehicle at 0x17384194800>,
#   <__main__.Vehicle at 0x173841948c0>],
#  [<__main__.Vehicle at 0x17384194980>,
#   <__main__.Vehicle at 0x17384194a40>,
#   <__main__.Vehicle at 0x17384194b00>],
#  [<__main__.Vehicle at 0x17384194bc0>, <__main__.Vehicle at 0x17384194c80>],
#  [<__main__.Vehicle at 0x17384194d40>,
#   <__main__.Vehicle at 0x17384194e00>,
#   <__main__.Vehicle at 0x17384194ec0>],
#  [<__main__.Vehicle at 0x17384194f80>,
#   <__main__.Vehicle at 0x17384195040>,
#   <__main__.Vehicle at 0x17384195100>],
#  [<__main__.Vehicle at 0x173841951c0>, <__main__.Vehicle at 0x17384195280>],
#  [<__main__.Vehicle at 0x17384195340>,
#   <__main__.Vehicle at 0x17384195400>,
#   <__main__.Vehicle at 0x173841954c0>],
#  [<__main__.Vehicle at 0x17384195580>,
#   <__main__.Vehicle at 0x17384195640>,
#   <__main__.Vehicle at 0x17384195700>],
#  [<__main__.Vehicle at 0x173841957c0>,
#   <__main__.Vehicle at 0x17384195880>,
#   <__main__.Vehicle at 0x17384195940>],
#  [<__main__.Vehicle at 0x17384195a00>,
#   <__main__.Vehicle at 0x17384195ac0>,
#   <__main__.Vehicle at 0x17384195b80>],
#  [<__main__.Vehicle at 0x17384195c40>,
#   <__main__.Vehicle at 0x17384195d00>,
#   <__main__.Vehicle at 0x17384195dc0>],
#  [<__main__.Vehicle at 0x17384195e80>,
#   <__main__.Vehicle at 0x17384195f40>,
#   <__main__.Vehicle at 0x17384196000>],
#  [<__main__.Vehicle at 0x173841960c0>,
#   <__main__.Vehicle at 0x17384196180>,
#   <__main__.Vehicle at 0x17384196240>],
#  [<__main__.Vehicle at 0x17384196300>,
#   <__main__.Vehicle at 0x173841963c0>,
#   <__main__.Vehicle at 0x17384196480>],
#  [<__main__.Vehicle at 0x17384196540>,
#   <__main__.Vehicle at 0x17384196600>,
#   <__main__.Vehicle at 0x173841966c0>],
#  [<__main__.Vehicle at 0x17384196780>,
#   <__main__.Vehicle at 0x17384196840>,
#   <__main__.Vehicle at 0x17384196900>],
#  [<__main__.Vehicle at 0x173841969c0>, <__main__.Vehicle at 0x17384196a80>],
#  [<__main__.Vehicle at 0x17384196b40>,
#   <__main__.Vehicle at 0x17384196c00>,
#   <__main__.Vehicle at 0x17384196cc0>],
#  [<__main__.Vehicle at 0x17384196d80>,
#   <__main__.Vehicle at 0x17384196e40>,
#   <__main__.Vehicle at 0x17384196f00>],
#  [<__main__.Vehicle at 0x17384196fc0>,
#   <__main__.Vehicle at 0x17384197080>,
#   <__main__.Vehicle at 0x17384197140>],
#  [<__main__.Vehicle at 0x17384197200>,
#   <__main__.Vehicle at 0x173841972c0>,
#   <__main__.Vehicle at 0x17384197380>],
#  [<__main__.Vehicle at 0x17384197440>,
#   <__main__.Vehicle at 0x17384197500>,
#   <__main__.Vehicle at 0x173841975c0>],
#  [<__main__.Vehicle at 0x17384197680>,
#   <__main__.Vehicle at 0x17384197740>,
#   <__main__.Vehicle at 0x17384197800>],
#  [<__main__.Vehicle at 0x173841978c0>,
#   <__main__.Vehicle at 0x17384197980>,
#   <__main__.Vehicle at 0x17384197a40>],
#  [<__main__.Vehicle at 0x17384197b00>, <__main__.Vehicle at 0x17384197bc0>],
#  [<__main__.Vehicle at 0x17384197c80>, <__main__.Vehicle at 0x17384197d40>],
#  [<__main__.Vehicle at 0x17384197e00>,
#   <__main__.Vehicle at 0x17384197ec0>,
#   <__main__.Vehicle at 0x17384197f80>],
#  [<__main__.Vehicle at 0x1738419c080>,
#   <__main__.Vehicle at 0x1738419c140>,
#   <__main__.Vehicle at 0x1738419c200>],
#  [<__main__.Vehicle at 0x1738419c2c0>, <__main__.Vehicle at 0x1738419c380>],
#  [<__main__.Vehicle at 0x1738419c440>,
#   <__main__.Vehicle at 0x1738419c500>,
#   <__main__.Vehicle at 0x1738419c5c0>],
#  [<__main__.Vehicle at 0x1738419c680>,
#   <__main__.Vehicle at 0x1738419c740>,
#   <__main__.Vehicle at 0x1738419c800>],
#  [<__main__.Vehicle at 0x1738419c8c0>,
#   <__main__.Vehicle at 0x1738419c980>,
#   <__main__.Vehicle at 0x1738419ca40>],
#  [<__main__.Vehicle at 0x1738419cb00>, <__main__.Vehicle at 0x1738419cbc0>],
#  [<__main__.Vehicle at 0x1738419cc80>,
#   <__main__.Vehicle at 0x1738419cd40>,
#   <__main__.Vehicle at 0x1738419ce00>],
#  [<__main__.Vehicle at 0x1738419cec0>,
#   <__main__.Vehicle at 0x1738419cf80>,
#   <__main__.Vehicle at 0x1738419d040>],
#  [<__main__.Vehicle at 0x1738419d100>,
#   <__main__.Vehicle at 0x1738419d1c0>,
#   <__main__.Vehicle at 0x1738419d280>],
#  [<__main__.Vehicle at 0x1738419d340>,
#   <__main__.Vehicle at 0x1738419d400>,
#   <__main__.Vehicle at 0x1738419d4c0>],
#  [<__main__.Vehicle at 0x1738419d580>,
#   <__main__.Vehicle at 0x1738419d640>,
#   <__main__.Vehicle at 0x1738419d700>],
#  [<__main__.Vehicle at 0x1738419d7c0>,
#   <__main__.Vehicle at 0x1738419d880>,
#   <__main__.Vehicle at 0x1738419d940>],
#  [<__main__.Vehicle at 0x1738419da00>, <__main__.Vehicle at 0x1738419dac0>],
#  [<__main__.Vehicle at 0x1738419db80>,
#   <__main__.Vehicle at 0x1738419dc40>,
#   <__main__.Vehicle at 0x1738419dd00>],
#  [<__main__.Vehicle at 0x1738419ddc0>,
#   <__main__.Vehicle at 0x1738419de80>,
#   <__main__.Vehicle at 0x1738419df40>],
#  [<__main__.Vehicle at 0x1738419e000>, <__main__.Vehicle at 0x1738419e0c0>],
#  [<__main__.Vehicle at 0x1738419e180>, <__main__.Vehicle at 0x1738419e240>],
#  [<__main__.Vehicle at 0x1738419e300>,
#   <__main__.Vehicle at 0x1738419e3c0>,
#   <__main__.Vehicle at 0x1738419e480>],
#  [<__main__.Vehicle at 0x1738419e540>,
#   <__main__.Vehicle at 0x1738419e600>,
#   <__main__.Vehicle at 0x1738419e6c0>],
#  [<__main__.Vehicle at 0x1738419e780>,
#   <__main__.Vehicle at 0x1738419e840>,
#   <__main__.Vehicle at 0x1738419e900>],
#  [<__main__.Vehicle at 0x1738419e9c0>,
#   <__main__.Vehicle at 0x1738419ea80>,
#   <__main__.Vehicle at 0x1738419eb40>],
#  [<__main__.Vehicle at 0x1738419ec00>, <__main__.Vehicle at 0x1738419ecc0>],
#  [<__main__.Vehicle at 0x1738419ed80>,
#   <__main__.Vehicle at 0x1738419ee40>,
#   <__main__.Vehicle at 0x1738419ef00>],
#  [<__main__.Vehicle at 0x1738419efc0>,
#   <__main__.Vehicle at 0x1738419f080>,
#   <__main__.Vehicle at 0x1738419f140>],
#  [<__main__.Vehicle at 0x1738419f200>,
#   <__main__.Vehicle at 0x1738419f2c0>,
#   <__main__.Vehicle at 0x1738419f380>],
#  [<__main__.Vehicle at 0x1738419f440>, <__main__.Vehicle at 0x1738419f500>],
#  [<__main__.Vehicle at 0x1738419f5c0>, <__main__.Vehicle at 0x1738419f680>],
#  [<__main__.Vehicle at 0x1738419f740>,
#   <__main__.Vehicle at 0x1738419f800>,
#   <__main__.Vehicle at 0x1738419f8c0>],
#  [<__main__.Vehicle at 0x1738419f980>, <__main__.Vehicle at 0x1738419fa40>],
#  [<__main__.Vehicle at 0x1738419fb00>,
#   <__main__.Vehicle at 0x1738419fbc0>,
#   <__main__.Vehicle at 0x1738419fc80>],
#  [<__main__.Vehicle at 0x1738419fd40>,
#   <__main__.Vehicle at 0x1738419fe00>,
#   <__main__.Vehicle at 0x1738419fec0>],
#  [<__main__.Vehicle at 0x1738419ff80>, <__main__.Vehicle at 0x173841a4080>],
#  [<__main__.Vehicle at 0x173841a4140>, <__main__.Vehicle at 0x173841a4200>],
#  [<__main__.Vehicle at 0x173841a42c0>,
#   <__main__.Vehicle at 0x173841a4380>,
#   <__main__.Vehicle at 0x173841a4440>],
#  [<__main__.Vehicle at 0x173841a4500>,
#   <__main__.Vehicle at 0x173841a45c0>,
#   <__main__.Vehicle at 0x173841a4680>],
#  [<__main__.Vehicle at 0x173841a4740>,
#   <__main__.Vehicle at 0x173841a4800>,
#   <__main__.Vehicle at 0x173841a48c0>],
#  [<__main__.Vehicle at 0x173841a4980>,
#   <__main__.Vehicle at 0x173841a4a40>,
#   <__main__.Vehicle at 0x173841a4b00>],
#  [<__main__.Vehicle at 0x173841a4bc0>,
#   <__main__.Vehicle at 0x173841a4c80>,
#   <__main__.Vehicle at 0x173841a4d40>],
#  [<__main__.Vehicle at 0x173841a4e00>, <__main__.Vehicle at 0x173841a4ec0>],
#  [<__main__.Vehicle at 0x173841a4f80>, <__main__.Vehicle at 0x173841a5040>],
#  [<__main__.Vehicle at 0x173841a5100>,
#   <__main__.Vehicle at 0x173841a51c0>,
#   <__main__.Vehicle at 0x173841a5280>],
#  [<__main__.Vehicle at 0x173841a5340>,
#   <__main__.Vehicle at 0x173841a5400>,
#   <__main__.Vehicle at 0x173841a54c0>],
#  [<__main__.Vehicle at 0x173841a5580>,
#   <__main__.Vehicle at 0x173841a5640>,
#   <__main__.Vehicle at 0x173841a5700>],
#  [<__main__.Vehicle at 0x173841a57c0>,
#   <__main__.Vehicle at 0x173841a5880>,
#   <__main__.Vehicle at 0x173841a5940>],
#  [<__main__.Vehicle at 0x173841a5a00>,
#   <__main__.Vehicle at 0x173841a5ac0>,
#   <__main__.Vehicle at 0x173841a5b80>],
#  [<__main__.Vehicle at 0x173841a5c40>,
#   <__main__.Vehicle at 0x173841a5d00>,
#   <__main__.Vehicle at 0x173841a5dc0>],
#  [<__main__.Vehicle at 0x173841a5e80>,
#   <__main__.Vehicle at 0x173841a5f40>,
#   <__main__.Vehicle at 0x173841a6000>],
#  [<__main__.Vehicle at 0x173841a60c0>,
#   <__main__.Vehicle at 0x173841a6180>,
#   <__main__.Vehicle at 0x173841a6240>],
#  [<__main__.Vehicle at 0x173841a6300>, <__main__.Vehicle at 0x173841a63c0>],
#  [<__main__.Vehicle at 0x173841a6480>,
#   <__main__.Vehicle at 0x173841a6540>,
#   <__main__.Vehicle at 0x173841a6600>],
#  [<__main__.Vehicle at 0x173841a66c0>, <__main__.Vehicle at 0x173841a6780>],
#  [<__main__.Vehicle at 0x173841a6840>, <__main__.Vehicle at 0x173841a6900>],
#  [<__main__.Vehicle at 0x173841a69c0>,
#   <__main__.Vehicle at 0x173841a6a80>,
#   <__main__.Vehicle at 0x173841a6b40>],
#  [<__main__.Vehicle at 0x173841a6c00>,
#   <__main__.Vehicle at 0x173841a6cc0>,
#   <__main__.Vehicle at 0x173841a6d80>],
#  [<__main__.Vehicle at 0x173841a6e40>,
#   <__main__.Vehicle at 0x173841a6f00>,
#   <__main__.Vehicle at 0x173841a6fc0>],
#  [<__main__.Vehicle at 0x173841a7080>,
#   <__main__.Vehicle at 0x173841a7140>,
#   <__main__.Vehicle at 0x173841a7200>],
#  [<__main__.Vehicle at 0x173841a72c0>, <__main__.Vehicle at 0x173841a7380>],
#  [<__main__.Vehicle at 0x173841a7440>,
#   <__main__.Vehicle at 0x173841a7500>,
#   <__main__.Vehicle at 0x173841a75c0>],
#  [<__main__.Vehicle at 0x173841a7680>,
#   <__main__.Vehicle at 0x173841a7740>,
#   <__main__.Vehicle at 0x173841a7800>],
#  [<__main__.Vehicle at 0x173841a78c0>,
#   <__main__.Vehicle at 0x173841a7980>,
#   <__main__.Vehicle at 0x173841a7a40>],
#  [<__main__.Vehicle at 0x173841a7b00>,
#   <__main__.Vehicle at 0x173841a7bc0>,
#   <__main__.Vehicle at 0x173841a7c80>],
#  [<__main__.Vehicle at 0x173841a7d40>, <__main__.Vehicle at 0x173841a7e00>],
#  [<__main__.Vehicle at 0x173841a7ec0>, <__main__.Vehicle at 0x173841a7f80>],
#  [<__main__.Vehicle at 0x173841ac080>, <__main__.Vehicle at 0x173841ac140>],
#  [<__main__.Vehicle at 0x173841ac200>,
#   <__main__.Vehicle at 0x173841ac2c0>,
#   <__main__.Vehicle at 0x173841ac380>],
#  [<__main__.Vehicle at 0x173841ac440>,
#   <__main__.Vehicle at 0x173841ac500>,
#   <__main__.Vehicle at 0x173841ac5c0>],
#  [<__main__.Vehicle at 0x173841ac680>,
#   <__main__.Vehicle at 0x173841ac740>,
#   <__main__.Vehicle at 0x173841ac800>],
#  [<__main__.Vehicle at 0x173841ac8c0>,
#   <__main__.Vehicle at 0x173841ac980>,
#   <__main__.Vehicle at 0x173841aca40>],
#  [<__main__.Vehicle at 0x173841acb00>,
#   <__main__.Vehicle at 0x173841acbc0>,
#   <__main__.Vehicle at 0x173841acc80>],
#  [<__main__.Vehicle at 0x173841acd40>, <__main__.Vehicle at 0x173841ace00>],
#  [<__main__.Vehicle at 0x173841acec0>,
#   <__main__.Vehicle at 0x173841acf80>,
#   <__main__.Vehicle at 0x173841ad040>],
#  [<__main__.Vehicle at 0x173841ad100>,
#   <__main__.Vehicle at 0x173841ad1c0>,
#   <__main__.Vehicle at 0x173841ad280>],
#  [<__main__.Vehicle at 0x173841ad340>,
#   <__main__.Vehicle at 0x173841ad400>,
#   <__main__.Vehicle at 0x173841ad4c0>],
#  [<__main__.Vehicle at 0x173841ad580>, <__main__.Vehicle at 0x173841ad640>],
#  [<__main__.Vehicle at 0x173841ad700>,
#   <__main__.Vehicle at 0x173841ad7c0>,
#   <__main__.Vehicle at 0x173841ad880>],
#  [<__main__.Vehicle at 0x173841ad940>,
#   <__main__.Vehicle at 0x173841ada00>,
#   <__main__.Vehicle at 0x173841adac0>],
#  [<__main__.Vehicle at 0x173841adb80>,
#   <__main__.Vehicle at 0x173841adc40>,
#   <__main__.Vehicle at 0x173841add00>],
#  [<__main__.Vehicle at 0x173841addc0>,
#   <__main__.Vehicle at 0x173841ade80>,
#   <__main__.Vehicle at 0x173841adf40>],
#  [<__main__.Vehicle at 0x173841ae000>,
#   <__main__.Vehicle at 0x173841ae0c0>,
#   <__main__.Vehicle at 0x173841ae180>],
#  [<__main__.Vehicle at 0x173841ae240>,
#   <__main__.Vehicle at 0x173841ae300>,
#   <__main__.Vehicle at 0x173841ae3c0>],
#  [<__main__.Vehicle at 0x173841ae480>,
#   <__main__.Vehicle at 0x173841ae540>,
#   <__main__.Vehicle at 0x173841ae600>],
#  [<__main__.Vehicle at 0x173841ae6c0>,
#   <__main__.Vehicle at 0x173841ae780>,
#   <__main__.Vehicle at 0x173841ae840>],
#  [<__main__.Vehicle at 0x173841ae900>,
#   <__main__.Vehicle at 0x173841ae9c0>,
#   <__main__.Vehicle at 0x173841aea80>],
#  [<__main__.Vehicle at 0x173841aeb40>, <__main__.Vehicle at 0x173841aec00>],
#  [<__main__.Vehicle at 0x173841aecc0>,
#   <__main__.Vehicle at 0x173841aed80>,
#   <__main__.Vehicle at 0x173841aee40>],
#  [<__main__.Vehicle at 0x173841aef00>,
#   <__main__.Vehicle at 0x173841aefc0>,
#   <__main__.Vehicle at 0x173841af080>],
#  [<__main__.Vehicle at 0x173841af140>,
#   <__main__.Vehicle at 0x173841af200>,
#   <__main__.Vehicle at 0x173841af2c0>],
#  [<__main__.Vehicle at 0x173841af380>, <__main__.Vehicle at 0x173841af440>],
#  [<__main__.Vehicle at 0x173841af500>, <__main__.Vehicle at 0x173841af5c0>],
#  [<__main__.Vehicle at 0x173841af680>,
#   <__main__.Vehicle at 0x173841af740>,
#   <__main__.Vehicle at 0x173841af800>]]

# %% [markdown]
# # Selection

# %%
def fitness(solution):
    solutionCost = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        cost = fitness.getCost()
        solutionCost += cost
    return solutionCost

def distance(solution):
    solutionDistance = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        distance = fitness.getDistance()
        solutionDistance += distance
    return solutionDistance


def getParents(population):
    choices = population.copy()

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = fitness(vehicles)
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minA = choices[minpos]
    chosenSolutionCost.pop(minpos)
    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minB = choices[minpos]

    return minA, minB

A, B = getParents(solutions)
A[0].customers
# Out:
# [(4.4184,114.0932),
#  (4.3163,114.0764),
#  (4.3555,113.9777),
#  (4.3184,113.9932),
#  (4.3976,114.0049)]

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))

def convertToTwoDList(parent):
    output = [[],[],[]]
    outputVehicles = []
    for i, vehicle in enumerate(parent):
        if (vehicle.customers):
            # remove depot
            vehicle.customers.pop(0)
        outputVehicles.append(vehicle.type)
        # for every route
        for j in range(len(vehicle.customers)):
            output[i].append(parent[i].customers[j].id)
    return output, outputVehicles


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

# %%
def getCrossoverOffspring(firstParent, secondParent):
    childVehicles = []

    first, firstVehicles = convertToTwoDList(firstParent)
    second, secondVehicles = convertToTwoDList(secondParent)


    # Random Choice of 1,2,3,4
    choice = random.randint(1, 4)
    # Case 1 - first parent is  main, two vehicles remain, one vehicle changes
    if (choice == 1 or choice == 2):
        if (choice == 1):
            parent = first.copy()
            secondary = second.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = firstVehicles.copy()

        # Case 2 - second parent is main, two vehicles remain, one vehicle changes
        elif (choice == 2):
            parent = second.copy()
            secondary = first.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = secondVehicles.copy()

        missing = findMissing(parent)

        child = []
        for i in parent:
            if i not in child:
                child.append(i)
            else:
                if(missing):
                    child.append(missing[0])
                    missing.pop(0)

        if (missing):
            child += missing


    elif (choice == 3 or choice == 4):
        # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
        if (choice == 3):
            child = convertToOneDList(first)
            childVehicles = firstVehicles.copy()
        # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
        elif (choice == 4):
            child = convertToOneDList(second)
            childVehicles = secondVehicles.copy()

    return child, childVehicles

print(A[0].customers)
child = getCrossoverOffspring(A, B)
child
# Out:
# [(4.4184,114.0932), (4.3163,114.0764), (4.3555,113.9777), (4.3184,113.9932), (4.3976,114.0049)]
# ([3, 1, 4, 2, 5, 10, 9, 6, 7, 8], ['A', 'A', 'A'])

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation - Bit Flip - Rate: 0.5
def vehicleMutation(li):
    prob = random.randint(0, 100)
    if prob <= 50:
        idx = random.randint(0, len(li)-1)
        if li[idx] == 'A':
            li[idx] = 'B'
        else:
            li[idx] = 'A'
    
    return li

# Routes Mutation - Swap - Rate: 0.7
def routeMutation(li):
    prob = random.randint(0, 100)
    if prob <= 70:
        if(len(li) >= 1):
            aIdx = random.randint(0, len(li)-1)
            bIdx = random.randint(0, len(li)-1)

            temp = li[aIdx]
            li[aIdx] = li[bIdx]
            li[bIdx] = temp

    return li

# %%
def getMutatedOffspring(first, second):

    child, childVehicles = getCrossoverOffspring(first, second)
    mutatedChild = routeMutation(child)
    mutatedVehicles = vehicleMutation(childVehicles)

    return mutatedChild, mutatedVehicles

# %% [markdown]
# # Convert back to class

# %%
# convert routes to Customer class
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()
print(li)

customers = []
for i in li:
    customers.append(Customer(i[0], i[1], i[2], i[3]))
# Out:
# [[1.0, 4.3555, 113.9777, 5.0], [2.0, 4.3976, 114.0049, 8.0], [3.0, 4.3163, 114.0764, 3.0], [4.0, 4.3184, 113.9932, 6.0], [5.0, 4.4024, 113.9896, 5.0], [6.0, 4.4142, 114.0127, 8.0], [7.0, 4.4804, 114.0734, 3.0], [8.0, 4.3818, 114.2034, 6.0], [9.0, 4.4935, 114.1828, 5.0], [10.0, 4.4932, 114.1322, 8.0]]

# %%
def getOffspring(first, second):
    mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    while(len(mutatedChild) != 10):
        mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    # print(mutatedChild)
    # print(mutatedVehicles)

    offspring = []
    for i in mutatedVehicles:
        vehicle = Vehicle(i)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        filledCapacity = 0

        while(mutatedChild):
            idx = mutatedChild[0]
            selectedCustomer = customers[idx-1]
            if((filledCapacity+selectedCustomer.demand) <= vehicle.capacity):
                filledCapacity += selectedCustomer.demand
                vehicle.addCustomer(selectedCustomer)
                mutatedChild.pop(0)
            else:
                break
        
        offspring.append(vehicle)

    return offspring

# %% [markdown]
# # Main function

# %%
import copy

parent1, parent2 = getParents(solutions)


noIteration = 500
minScore = 1000

for i in range(noIteration):
    population = []
    # each parent will produce 1000 offspring, and two best are selected
    for j in range(500):
        offspringA = getOffspring(parent1, parent2)
        offspringB = getOffspring(parent1, parent2)

        population.append(offspringA)
        population.append(offspringB)
    

    parent1, parent2 = getParents(population)

    averageScore = fitness(parent1)

    print('Iteration: ' + str(i+1))
    print('Score: ' + str(averageScore))

    if(averageScore < minScore):
        minScore = averageScore
        minParent = copy.deepcopy(parent1)
# Out:
# Iteration: 1
# Score: 143.42708299858427
# Iteration: 2
# Score: 143.42708299858427
# Iteration: 3
# Score: 143.42708299858427
# Iteration: 4
# Score: 143.42708299858427
# Iteration: 5
# Score: 143.42708299858427
# Iteration: 6
# Score: 143.42708299858427
# Iteration: 7
# Score: 143.42708299858427
# Iteration: 8
# Score: 143.42708299858427
# Iteration: 9
# Score: 143.42708299858427
# Iteration: 10
# Score: 143.42708299858427
# Iteration: 11
# Score: 143.42708299858427
# Iteration: 12
# Score: 143.42708299858427
# Iteration: 13
# Score: 143.42708299858427
# Iteration: 14
# Score: 143.42708299858427
# Iteration: 15
# Score: 143.42708299858427
# Iteration: 16
# Score: 143.42708299858427
# Iteration: 17
# Score: 143.42708299858427
# Iteration: 18
# Score: 143.42708299858427
# Iteration: 19
# Score: 143.42708299858427
# Iteration: 20
# Score: 143.42708299858427
# Iteration: 21
# Score: 143.42708299858427
# Iteration: 22
# Score: 143.42708299858427
# Iteration: 23
# Score: 143.42708299858427
# Iteration: 24
# Score: 143.42708299858427
# Iteration: 25
# Score: 143.42708299858427
# Iteration: 26
# Score: 143.42708299858427
# Iteration: 27
# Score: 143.42708299858427
# Iteration: 28
# Score: 143.42708299858427
# Iteration: 29
# Score: 143.42708299858427
# Iteration: 30
# Score: 143.42708299858427
# Iteration: 31
# Score: 143.42708299858427
# Iteration: 32
# Score: 143.42708299858427
# Iteration: 33
# Score: 143.42708299858427
# Iteration: 34
# Score: 137.70610608489773
# Iteration: 35
# Score: 143.42708299858427
# Iteration: 36
# Score: 143.42708299858427
# Iteration: 37
# Score: 143.42708299858427
# Iteration: 38
# Score: 143.42708299858427
# Iteration: 39
# Score: 143.42708299858427
# Iteration: 40
# Score: 143.42708299858427
# Iteration: 41
# Score: 143.42708299858427
# Iteration: 42
# Score: 143.42708299858427
# Iteration: 43
# Score: 143.42708299858427
# Iteration: 44
# Score: 143.42708299858427
# Iteration: 45
# Score: 143.42708299858427
# Iteration: 46
# Score: 143.42708299858427
# Iteration: 47
# Score: 143.42708299858427
# Iteration: 48
# Score: 143.42708299858427
# Iteration: 49
# Score: 143.42708299858427
# Iteration: 50
# Score: 143.42708299858427
# Iteration: 51
# Score: 143.42708299858427
# Iteration: 52
# Score: 135.06138883931436
# Iteration: 53
# Score: 143.42708299858427
# Iteration: 54
# Score: 143.42708299858427
# Iteration: 55
# Score: 143.42708299858427
# Iteration: 56
# Score: 143.42708299858427
# Iteration: 57
# Score: 143.42708299858427
# Iteration: 58
# Score: 143.42708299858427
# Iteration: 59
# Score: 143.42708299858427
# Iteration: 60
# Score: 143.42708299858427
# Iteration: 61
# Score: 143.42708299858427
# Iteration: 62
# Score: 143.42708299858427
# Iteration: 63
# Score: 143.42708299858427
# Iteration: 64
# Score: 143.42708299858427
# Iteration: 65
# Score: 143.42708299858427
# Iteration: 66
# Score: 143.42708299858427
# Iteration: 67
# Score: 143.42708299858427
# Iteration: 68
# Score: 143.42708299858427
# Iteration: 69
# Score: 143.42708299858427
# Iteration: 70
# Score: 142.29260723935738
# Iteration: 71
# Score: 143.42708299858427
# Iteration: 72
# Score: 143.42708299858427
# Iteration: 73
# Score: 143.42708299858427
# Iteration: 74
# Score: 143.42708299858427
# Iteration: 75
# Score: 143.42708299858427
# Iteration: 76
# Score: 143.42708299858427
# Iteration: 77
# Score: 143.42708299858427
# Iteration: 78
# Score: 143.42708299858427
# Iteration: 79
# Score: 143.42708299858427
# Iteration: 80
# Score: 143.42708299858427
# Iteration: 81
# Score: 143.42708299858427
# Iteration: 82
# Score: 143.42708299858427
# Iteration: 83
# Score: 143.42708299858427
# Iteration: 84
# Score: 143.42708299858427
# Iteration: 85
# Score: 143.42708299858427
# Iteration: 86
# Score: 143.42708299858427
# Iteration: 87
# Score: 143.42708299858427
# Iteration: 88
# Score: 143.42708299858427
# Iteration: 89
# Score: 143.42708299858427
# Iteration: 90
# Score: 143.42708299858427
# Iteration: 91
# Score: 143.42708299858427
# Iteration: 92
# Score: 143.42708299858427
# Iteration: 93
# Score: 143.42708299858427
# Iteration: 94
# Score: 143.42708299858427
# Iteration: 95
# Score: 143.42708299858427
# Iteration: 96
# Score: 143.42708299858427
# Iteration: 97
# Score: 143.42708299858427
# Iteration: 98
# Score: 143.42708299858427
# Iteration: 99
# Score: 143.42708299858427
# Iteration: 100
# Score: 143.42708299858427
# Iteration: 101
# Score: 143.42708299858427
# Iteration: 102
# Score: 143.42708299858427
# Iteration: 103
# Score: 143.42708299858427
# Iteration: 104
# Score: 143.42708299858427
# Iteration: 105
# Score: 143.42708299858427
# Iteration: 106
# Score: 144.01578261412692
# Iteration: 107
# Score: 143.42708299858427
# Iteration: 108
# Score: 143.42708299858427
# Iteration: 109
# Score: 143.42708299858427
# Iteration: 110
# Score: 143.42708299858427
# Iteration: 111
# Score: 143.42708299858427
# Iteration: 112
# Score: 143.42708299858427
# Iteration: 113
# Score: 143.42708299858427
# Iteration: 114
# Score: 143.42708299858427
# Iteration: 115
# Score: 143.42708299858427
# Iteration: 116
# Score: 143.42708299858427
# Iteration: 117
# Score: 143.42708299858427
# Iteration: 118
# Score: 143.42708299858427
# Iteration: 119
# Score: 143.42708299858427
# Iteration: 120
# Score: 143.42708299858427
# Iteration: 121
# Score: 143.42708299858427
# Iteration: 122
# Score: 143.42708299858427
# Iteration: 123
# Score: 143.42708299858427
# Iteration: 124
# Score: 143.42708299858427
# Iteration: 125
# Score: 143.42708299858427
# Iteration: 126
# Score: 143.42708299858427
# Iteration: 127
# Score: 143.42708299858427
# Iteration: 128
# Score: 134.337561857889
# Iteration: 129
# Score: 143.42708299858427
# Iteration: 130
# Score: 143.42708299858427
# Iteration: 131
# Score: 143.42708299858427
# Iteration: 132
# Score: 143.42708299858427
# Iteration: 133
# Score: 143.42708299858427
# Iteration: 134
# Score: 143.42708299858427
# Iteration: 135
# Score: 143.42708299858427
# Iteration: 136
# Score: 144.01578261412692
# Iteration: 137
# Score: 143.42708299858427
# Iteration: 138
# Score: 143.42708299858427
# Iteration: 139
# Score: 143.42708299858427
# Iteration: 140
# Score: 143.42708299858427
# Iteration: 141
# Score: 143.42708299858427
# Iteration: 142
# Score: 143.42708299858427
# Iteration: 143
# Score: 143.42708299858427
# Iteration: 144
# Score: 134.33756185788897
# Iteration: 145
# Score: 143.42708299858427
# Iteration: 146
# Score: 143.42708299858427
# Iteration: 147
# Score: 143.42708299858427
# Iteration: 148
# Score: 143.42708299858427
# Iteration: 149
# Score: 143.42708299858427
# Iteration: 150
# Score: 143.42708299858427
# Iteration: 151
# Score: 143.42708299858427
# Iteration: 152
# Score: 143.42708299858427
# Iteration: 153
# Score: 143.42708299858427
# Iteration: 154
# Score: 143.42708299858427
# Iteration: 155
# Score: 143.42708299858427
# Iteration: 156
# Score: 143.42708299858427
# Iteration: 157
# Score: 143.42708299858427
# Iteration: 158
# Score: 138.62678050413942
# Iteration: 159
# Score: 143.42708299858427
# Iteration: 160
# Score: 143.42708299858427
# Iteration: 161
# Score: 143.42708299858427
# Iteration: 162
# Score: 143.42708299858427
# Iteration: 163
# Score: 143.42708299858427
# Iteration: 164
# Score: 144.01578261412692
# Iteration: 165
# Score: 143.42708299858427
# Iteration: 166
# Score: 143.42708299858427
# Iteration: 167
# Score: 143.42708299858427
# Iteration: 168
# Score: 143.42708299858427
# Iteration: 169
# Score: 140.64748322920934
# Iteration: 170
# Score: 143.42708299858427
# Iteration: 171
# Score: 143.42708299858427
# Iteration: 172
# Score: 143.42708299858427
# Iteration: 173
# Score: 143.42708299858427
# Iteration: 174
# Score: 143.42708299858427
# Iteration: 175
# Score: 143.42708299858427
# Iteration: 176
# Score: 143.42708299858427
# Iteration: 177
# Score: 143.42708299858427
# Iteration: 178
# Score: 143.42708299858427
# Iteration: 179
# Score: 143.42708299858427
# Iteration: 180
# Score: 143.42708299858427
# Iteration: 181
# Score: 143.42708299858427
# Iteration: 182
# Score: 141.03069259941617
# Iteration: 183
# Score: 143.42708299858427
# Iteration: 184
# Score: 143.42708299858427
# Iteration: 185
# Score: 143.42708299858427
# Iteration: 186
# Score: 143.42708299858427
# Iteration: 187
# Score: 143.42708299858427
# Iteration: 188
# Score: 143.42708299858427
# Iteration: 189
# Score: 143.42708299858427
# Iteration: 190
# Score: 143.42708299858427
# Iteration: 191
# Score: 143.42708299858427
# Iteration: 192
# Score: 143.42708299858427
# Iteration: 193
# Score: 143.42708299858427
# Iteration: 194
# Score: 143.42708299858427
# Iteration: 195
# Score: 143.42708299858427
# Iteration: 196
# Score: 143.42708299858427
# Iteration: 197
# Score: 143.42708299858427
# Iteration: 198
# Score: 143.42708299858427
# Iteration: 199
# Score: 143.42708299858427
# Iteration: 200
# Score: 143.42708299858427
# Iteration: 201
# Score: 143.42708299858427
# Iteration: 202
# Score: 143.42708299858427
# Iteration: 203
# Score: 143.42708299858427
# Iteration: 204
# Score: 143.42708299858427
# Iteration: 205
# Score: 143.42708299858427
# Iteration: 206
# Score: 143.42708299858427
# Iteration: 207
# Score: 143.42708299858427
# Iteration: 208
# Score: 143.42708299858427
# Iteration: 209
# Score: 143.42708299858427
# Iteration: 210
# Score: 143.42708299858427
# Iteration: 211
# Score: 143.42708299858427
# Iteration: 212
# Score: 143.42708299858427
# Iteration: 213
# Score: 143.42708299858427
# Iteration: 214
# Score: 143.42708299858427
# Iteration: 215
# Score: 143.42708299858427
# Iteration: 216
# Score: 143.42708299858427
# Iteration: 217
# Score: 143.42708299858427
# Iteration: 218
# Score: 143.42708299858427
# Iteration: 219
# Score: 143.42708299858427
# Iteration: 220
# Score: 143.42708299858427
# Iteration: 221
# Score: 139.52983514662222
# Iteration: 222
# Score: 143.42708299858427
# Iteration: 223
# Score: 143.42708299858427
# Iteration: 224
# Score: 143.42708299858427
# Iteration: 225
# Score: 143.42708299858427
# Iteration: 226
# Score: 143.42708299858427
# Iteration: 227
# Score: 143.42708299858427
# Iteration: 228
# Score: 143.42708299858427
# Iteration: 229
# Score: 143.42708299858427
# Iteration: 230
# Score: 143.42708299858427
# Iteration: 231
# Score: 143.42708299858427
# Iteration: 232
# Score: 143.42708299858427
# Iteration: 233
# Score: 143.42708299858427
# Iteration: 234
# Score: 143.42708299858427
# Iteration: 235
# Score: 143.42708299858427
# Iteration: 236
# Score: 143.42708299858427
# Iteration: 237
# Score: 143.42708299858427
# Iteration: 238
# Score: 143.42708299858427
# Iteration: 239
# Score: 143.42708299858427
# Iteration: 240
# Score: 143.42708299858427
# Iteration: 241
# Score: 143.42708299858427
# Iteration: 242
# Score: 143.42708299858427
# Iteration: 243
# Score: 143.42708299858427
# Iteration: 244
# Score: 143.42708299858427
# Iteration: 245
# Score: 143.42708299858427
# Iteration: 246
# Score: 143.42708299858427
# Iteration: 247
# Score: 143.42708299858427
# Iteration: 248
# Score: 138.62678050413942
# Iteration: 249
# Score: 143.42708299858427
# Iteration: 250
# Score: 143.42708299858427
# Iteration: 251
# Score: 143.42708299858427
# Iteration: 252
# Score: 143.42708299858427
# Iteration: 253
# Score: 143.42708299858427
# Iteration: 254
# Score: 143.42708299858427
# Iteration: 255
# Score: 144.01578261412692
# Iteration: 256
# Score: 143.42708299858427
# Iteration: 257
# Score: 143.42708299858427
# Iteration: 258
# Score: 143.42708299858427
# Iteration: 259
# Score: 143.42708299858427
# Iteration: 260
# Score: 143.42708299858427
# Iteration: 261
# Score: 143.42708299858427
# Iteration: 262
# Score: 143.42708299858427
# Iteration: 263
# Score: 143.42708299858427
# Iteration: 264
# Score: 143.42708299858427
# Iteration: 265
# Score: 143.42708299858427
# Iteration: 266
# Score: 143.42708299858427
# Iteration: 267
# Score: 143.42708299858427
# Iteration: 268
# Score: 143.42708299858427
# Iteration: 269
# Score: 143.42708299858427
# Iteration: 270
# Score: 143.42708299858427
# Iteration: 271
# Score: 143.42708299858427
# Iteration: 272
# Score: 143.42708299858427
# Iteration: 273
# Score: 143.42708299858427
# Iteration: 274
# Score: 143.42708299858427
# Iteration: 275
# Score: 143.42708299858427
# Iteration: 276
# Score: 143.42708299858427
# Iteration: 277
# Score: 143.42708299858427
# Iteration: 278
# Score: 143.42708299858427
# Iteration: 279
# Score: 143.42708299858427
# Iteration: 280
# Score: 143.42708299858427
# Iteration: 281
# Score: 143.42708299858427
# Iteration: 282
# Score: 143.42708299858427
# Iteration: 283
# Score: 143.42708299858427
# Iteration: 284
# Score: 143.42708299858427
# Iteration: 285
# Score: 143.42708299858427
# Iteration: 286
# Score: 143.42708299858427
# Iteration: 287
# Score: 143.42708299858427
# Iteration: 288
# Score: 143.42708299858427
# Iteration: 289
# Score: 143.42708299858427
# Iteration: 290
# Score: 143.42708299858427
# Iteration: 291
# Score: 143.42708299858427
# Iteration: 292
# Score: 143.42708299858427
# Iteration: 293
# Score: 143.42708299858427
# Iteration: 294
# Score: 143.42708299858427
# Iteration: 295
# Score: 143.42708299858427
# Iteration: 296
# Score: 143.42708299858427
# Iteration: 297
# Score: 143.42708299858427
# Iteration: 298
# Score: 143.42708299858427
# Iteration: 299
# Score: 138.62678050413942
# Iteration: 300
# Score: 143.42708299858427
# Iteration: 301
# Score: 143.42708299858427
# Iteration: 302
# Score: 143.42708299858427
# Iteration: 303
# Score: 143.42708299858427
# Iteration: 304
# Score: 143.42708299858427
# Iteration: 305
# Score: 143.42708299858427
# Iteration: 306
# Score: 143.42708299858427
# Iteration: 307
# Score: 143.42708299858427
# Iteration: 308
# Score: 143.42708299858427
# Iteration: 309
# Score: 143.42708299858427
# Iteration: 310
# Score: 143.42708299858427
# Iteration: 311
# Score: 143.42708299858427
# Iteration: 312
# Score: 143.42708299858427
# Iteration: 313
# Score: 143.42708299858427
# Iteration: 314
# Score: 143.42708299858427
# Iteration: 315
# Score: 143.42708299858427
# Iteration: 316
# Score: 143.42708299858427
# Iteration: 317
# Score: 143.42708299858427
# Iteration: 318
# Score: 143.42708299858427
# Iteration: 319
# Score: 143.42708299858427
# Iteration: 320
# Score: 143.42708299858427
# Iteration: 321
# Score: 143.42708299858427
# Iteration: 322
# Score: 143.42708299858427
# Iteration: 323
# Score: 143.42708299858427
# Iteration: 324
# Score: 143.42708299858427
# Iteration: 325
# Score: 143.42708299858427
# Iteration: 326
# Score: 143.42708299858427
# Iteration: 327
# Score: 143.42708299858427
# Iteration: 328
# Score: 143.42708299858427
# Iteration: 329
# Score: 143.42708299858427
# Iteration: 330
# Score: 143.42708299858427
# Iteration: 331
# Score: 143.42708299858427
# Iteration: 332
# Score: 143.42708299858427
# Iteration: 333
# Score: 143.42708299858427
# Iteration: 334
# Score: 143.42708299858427
# Iteration: 335
# Score: 143.42708299858427
# Iteration: 336
# Score: 143.42708299858427
# Iteration: 337
# Score: 143.42708299858427
# Iteration: 338
# Score: 143.42708299858427
# Iteration: 339
# Score: 143.42708299858427
# Iteration: 340
# Score: 143.42708299858427
# Iteration: 341
# Score: 143.42708299858427
# Iteration: 342
# Score: 143.42708299858427
# Iteration: 343
# Score: 143.42708299858427
# Iteration: 344
# Score: 143.42708299858427
# Iteration: 345
# Score: 143.42708299858427
# Iteration: 346
# Score: 143.42708299858427
# Iteration: 347
# Score: 143.42708299858427
# Iteration: 348
# Score: 143.42708299858427
# Iteration: 349
# Score: 143.42708299858427
# Iteration: 350
# Score: 143.42708299858427
# Iteration: 351
# Score: 143.42708299858427
# Iteration: 352
# Score: 143.42708299858427
# Iteration: 353
# Score: 143.42708299858427
# Iteration: 354
# Score: 143.42708299858427
# Iteration: 355
# Score: 143.42708299858427
# Iteration: 356
# Score: 143.42708299858427
# Iteration: 357
# Score: 143.42708299858427
# Iteration: 358
# Score: 143.42708299858427
# Iteration: 359
# Score: 143.42708299858427
# Iteration: 360
# Score: 143.42708299858427
# Iteration: 361
# Score: 143.42708299858427
# Iteration: 362
# Score: 143.42708299858427
# Iteration: 363
# Score: 143.42708299858427
# Iteration: 364
# Score: 143.42708299858427
# Iteration: 365
# Score: 143.42708299858427
# Iteration: 366
# Score: 143.42708299858427
# Iteration: 367
# Score: 143.42708299858427
# Iteration: 368
# Score: 143.42708299858427
# Iteration: 369
# Score: 143.42708299858427
# Iteration: 370
# Score: 143.42708299858427
# Iteration: 371
# Score: 143.42708299858427
# Iteration: 372
# Score: 143.42708299858427
# Iteration: 373
# Score: 143.42708299858427
# Iteration: 374
# Score: 143.42708299858427
# Iteration: 375
# Score: 143.42708299858427
# Iteration: 376
# Score: 143.42708299858427
# Iteration: 377
# Score: 143.42708299858427
# Iteration: 378
# Score: 143.42708299858427
# Iteration: 379
# Score: 143.42708299858427
# Iteration: 380
# Score: 143.42708299858427
# Iteration: 381
# Score: 143.42708299858427
# Iteration: 382
# Score: 143.42708299858427
# Iteration: 383
# Score: 143.42708299858427
# Iteration: 384
# Score: 143.42708299858427
# Iteration: 385
# Score: 143.42708299858427
# Iteration: 386
# Score: 143.42708299858427
# Iteration: 387
# Score: 143.42708299858427
# Iteration: 388
# Score: 143.42708299858427
# Iteration: 389
# Score: 143.42708299858427
# Iteration: 390
# Score: 143.42708299858427
# Iteration: 391
# Score: 134.337561857889
# Iteration: 392
# Score: 143.42708299858427
# Iteration: 393
# Score: 143.42708299858427
# Iteration: 394
# Score: 143.42708299858427
# Iteration: 395
# Score: 143.42708299858427
# Iteration: 396
# Score: 143.42708299858427
# Iteration: 397
# Score: 143.42708299858427
# Iteration: 398
# Score: 143.42708299858427
# Iteration: 399
# Score: 143.42708299858427
# Iteration: 400
# Score: 143.42708299858427
# Iteration: 401
# Score: 143.42708299858427
# Iteration: 402
# Score: 143.42708299858427
# Iteration: 403
# Score: 143.42708299858427
# Iteration: 404
# Score: 143.42708299858427
# Iteration: 405
# Score: 143.42708299858427
# Iteration: 406
# Score: 143.42708299858427
# Iteration: 407
# Score: 143.42708299858427
# Iteration: 408
# Score: 143.42708299858427
# Iteration: 409
# Score: 143.42708299858427
# Iteration: 410
# Score: 143.42708299858427
# Iteration: 411
# Score: 143.42708299858427
# Iteration: 412
# Score: 143.42708299858427
# Iteration: 413
# Score: 143.42708299858427
# Iteration: 414
# Score: 143.42708299858427
# Iteration: 415
# Score: 143.42708299858427
# Iteration: 416
# Score: 143.42708299858427
# Iteration: 417
# Score: 143.42708299858427
# Iteration: 418
# Score: 143.42708299858427
# Iteration: 419
# Score: 143.42708299858427
# Iteration: 420
# Score: 143.42708299858427
# Iteration: 421
# Score: 143.42708299858427
# Iteration: 422
# Score: 143.42708299858427
# Iteration: 423
# Score: 143.42708299858427
# Iteration: 424
# Score: 143.42708299858427
# Iteration: 425
# Score: 144.68028767555205
# Iteration: 426
# Score: 143.42708299858427
# Iteration: 427
# Score: 143.42708299858427
# Iteration: 428
# Score: 143.42708299858427
# Iteration: 429
# Score: 143.42708299858427
# Iteration: 430
# Score: 143.42708299858427
# Iteration: 431
# Score: 143.42708299858427
# Iteration: 432
# Score: 143.42708299858427
# Iteration: 433
# Score: 143.42708299858427
# Iteration: 434
# Score: 143.42708299858427
# Iteration: 435
# Score: 143.42708299858427
# Iteration: 436
# Score: 143.42708299858427
# Iteration: 437
# Score: 143.42708299858427
# Iteration: 438
# Score: 143.42708299858427
# Iteration: 439
# Score: 143.42708299858427
# Iteration: 440
# Score: 143.42708299858427
# Iteration: 441
# Score: 143.42708299858427
# Iteration: 442
# Score: 143.42708299858427
# Iteration: 443
# Score: 143.42708299858427
# Iteration: 444
# Score: 143.42708299858427
# Iteration: 445
# Score: 143.42708299858427
# Iteration: 446
# Score: 143.42708299858427
# Iteration: 447
# Score: 143.42708299858427
# Iteration: 448
# Score: 143.42708299858427
# Iteration: 449
# Score: 143.42708299858427
# Iteration: 450
# Score: 143.42708299858427
# Iteration: 451
# Score: 143.42708299858427
# Iteration: 452
# Score: 143.42708299858427
# Iteration: 453
# Score: 143.42708299858427
# Iteration: 454
# Score: 143.42708299858427
# Iteration: 455
# Score: 143.42708299858427
# Iteration: 456
# Score: 143.42708299858427
# Iteration: 457
# Score: 143.42708299858427
# Iteration: 458
# Score: 143.42708299858427
# Iteration: 459
# Score: 143.42708299858427
# Iteration: 460
# Score: 143.42708299858427
# Iteration: 461
# Score: 143.42708299858427
# Iteration: 462
# Score: 143.42708299858427
# Iteration: 463
# Score: 143.42708299858427
# Iteration: 464
# Score: 143.42708299858427
# Iteration: 465
# Score: 143.42708299858427
# Iteration: 466
# Score: 143.42708299858427
# Iteration: 467
# Score: 143.42708299858427
# Iteration: 468
# Score: 143.42708299858427
# Iteration: 469
# Score: 143.42708299858427
# Iteration: 470
# Score: 143.42708299858427
# Iteration: 471
# Score: 143.42708299858427
# Iteration: 472
# Score: 143.42708299858427
# Iteration: 473
# Score: 143.42708299858427
# Iteration: 474
# Score: 143.42708299858427
# Iteration: 475
# Score: 143.42708299858427
# Iteration: 476
# Score: 143.42708299858427
# Iteration: 477
# Score: 143.42708299858427
# Iteration: 478
# Score: 143.42708299858427
# Iteration: 479
# Score: 143.42708299858427
# Iteration: 480
# Score: 143.42708299858427
# Iteration: 481
# Score: 143.42708299858427
# Iteration: 482
# Score: 143.42708299858427
# Iteration: 483
# Score: 143.42708299858427
# Iteration: 484
# Score: 143.42708299858427
# Iteration: 485
# Score: 143.42708299858427
# Iteration: 486
# Score: 143.42708299858427
# Iteration: 487
# Score: 143.42708299858427
# Iteration: 488
# Score: 143.42708299858427
# Iteration: 489
# Score: 143.42708299858427
# Iteration: 490
# Score: 143.42708299858427
# Iteration: 491
# Score: 143.42708299858427
# Iteration: 492
# Score: 143.42708299858427
# Iteration: 493
# Score: 143.42708299858427
# Iteration: 494
# Score: 143.42708299858427
# Iteration: 495
# Score: 143.42708299858427
# Iteration: 496
# Score: 143.42708299858427
# Iteration: 497
# Score: 143.42708299858427
# Iteration: 498
# Score: 143.42708299858427
# Iteration: 499
# Score: 143.42708299858427
# Iteration: 500
# Score: 143.42708299858427

# %%
print("Total Distance: " + str(round(distance(minParent), 2)) + " km")
print("Total Cost: RM " + str(round(minScore, 2)))
print('')


for idx, vehicle in enumerate(minParent):
    if(vehicle):

        print(f"Vehicle {idx+1} (Type {vehicle.type})")
        vehicleFitness = Fitness(vehicle)
        print(f"Round Trip Distance: {round(vehicleFitness.getDistance(),3)} km, Cost: RM {round(vehicleFitness.getCost(),2)}, Demand: {vehicleFitness.getDemand()}")

        for idx, route in enumerate(vehicle.customers):
            
            if (route.id == -1):
                routeName = "Depot"
                print(f"{routeName} -> ")
            else:
                routeName = "C"+str(int(route.id))
                print(f"{routeName} ({round(route.distance(vehicle.customers[idx-1]),2)} km) -> ")

        backToDepotDistance = vehicle.customers[-1].distance(vehicle.customers[0])
        print(f"Depot ({round(backToDepotDistance, 2)} km)")
        print('')
# Out:
# Total Distance: 111.95 km
# Total Cost: RM 134.34
#
# Vehicle 1 (Type A)
# Round Trip Distance: 49.986 km, Cost: RM 59.98, Demand: 22.0
# Depot ->
# C5 (10.48 km) ->
# C6 (2.59 km) ->
# C7 (8.98 km) ->
# C8 (16.32 km) ->
# Depot (11.61 km)
#
# Vehicle 2 (Type A)
# Round Trip Distance: 36.775 km, Cost: RM 44.13, Demand: 22.0
# Depot ->
# C2 (9.07 km) ->
# C1 (5.01 km) ->
# C4 (4.02 km) ->
# C3 (8.32 km) ->
# Depot (10.35 km)
#
# Vehicle 3 (Type A)
# Round Trip Distance: 25.187 km, Cost: RM 30.22, Demand: 13.0
# Depot ->
# C9 (11.69 km) ->
# C10 (5.06 km) ->
# Depot (8.44 km)
