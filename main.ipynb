# %% [markdown]
# # Import Libraries

# %%
import random
import time
import csv

import numpy as np
import pandas as pd

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.routes = []
        self.rate = None
        self.capacity = None

    def addRoute(self, route):
        self.routes.append(route)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.routes.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
        self.distance = None
    
    # fitness is based on cost, since distance is directly in correlation with cost,
    # taking cost can be a more accurate representation of the efficiency of the route

    # routes = customer
    
    
    def getDistance(self):
        routes = self.vehicle.routes
        distance = 0

        for i in range (0, len(routes)):
            fromCity = routes[i]
            if i+1 < len(routes):
                toCity = routes[i+1]

            # return to depot
            else:
                toCity = routes[0]
            
            distance += fromCity.distance(toCity)

        return distance

    def getCost(self):
        self.distance = self.getDistance()
        return self.distance*(self.vehicle.rate)  
    
    def getDemand(self):
        routes = self.vehicle.routes
        totalDemand = 0

        for route in routes:
            totalDemand += route.demand

        return totalDemand

# %%
# fill in routes - choose vehicle - ensure routes is selected based on demands

# %% [markdown]
# # Generate Population

# %%
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

oriRoutes = []
for i in li:
    oriRoutes.append(Customer(i[0], i[1], i[2], i[3]))

solutions = [] #array of vehicles

for s in range(1000):
    print('iteration'+ str(s+1))
    routes = oriRoutes.copy()

    vehicles = []

    while(len(routes) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(routes):
            selectedRoute = random.choice(routes)
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                routes.remove(selectedRoute)
                print('Route ' + str(selectedRoute.id) + ', demand ' + str(selectedRoute.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# 'iteration1'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration2'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration3'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration4'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration5'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'iteration6'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration7'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration8'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration9'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration10'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration11'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration12'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration13'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration14'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration15'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration16'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration17'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration18'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration19'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration20'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 
#  [<__main__.Vehicle at 0x22cd4829a60>,
#   <__main__.Vehicle at 0x22cd4829b20>,
#   <__main__.Vehicle at 0x22cd4829be0>],
#  [<__main__.Vehicle at 0x22cd4829ca0>,
#   <__main__.Vehicle at 0x22cd4829d60>,
#   <__main__.Vehicle at 0x22cd4829e20>],
#  [<__main__.Vehicle at 0x22cd4829ee0>,
#   <__main__.Vehicle at 0x22cd4829fa0>,
#   <__main__.Vehicle at 0x22cd482a060>],
#  [<__main__.Vehicle at 0x22cd482a120>,
#   <__main__.Vehicle at 0x22cd482a1e0>,
#   <__main__.Vehicle at 0x22cd482a2a0>],
#  [<__main__.Vehicle at 0x22cd482a360>,
#   <__main__.Vehicle at 0x22cd482a420>,
#   <__main__.Vehicle at 0x22cd482a4e0>],
#  [<__main__.Vehicle at 0x22cd482a5a0>,
#   <__main__.Vehicle at 0x22cd482a660>,
#   <__main__.Vehicle at 0x22cd482a720>],
#  [<__main__.Vehicle at 0x22cd482a7e0>,
#   <__main__.Vehicle at 0x22cd482a8a0>,
#   <__main__.Vehicle at 0x22cd482a960>],
#  [<__main__.Vehicle at 0x22cd482aa20>, <__main__.Vehicle at 0x22cd482aae0>],
#  [<__main__.Vehicle at 0x22cd482aba0>, <__main__.Vehicle at 0x22cd482ac60>],
#  [<__main__.Vehicle at 0x22cd482ad20>,
#   <__main__.Vehicle at 0x22cd482ade0>,
#   <__main__.Vehicle at 0x22cd482aea0>],
#  [<__main__.Vehicle at 0x22cd482af60>,
#   <__main__.Vehicle at 0x22cd482b020>,
#   <__main__.Vehicle at 0x22cd482b0e0>],
#  [<__main__.Vehicle at 0x22cd482b1a0>, <__main__.Vehicle at 0x22cd482b260>],
#  [<__main__.Vehicle at 0x22cd482b320>,
#   <__main__.Vehicle at 0x22cd482b3e0>,
#   <__main__.Vehicle at 0x22cd482b4a0>],
#  [<__main__.Vehicle at 0x22cd482b560>, <__main__.Vehicle at 0x22cd482b620>],
#  [<__main__.Vehicle at 0x22cd482b6e0>,
#   <__main__.Vehicle at 0x22cd482b7a0>,
#   <__main__.Vehicle at 0x22cd482b860>],
#  [<__main__.Vehicle at 0x22cd482b920>,
#   <__main__.Vehicle at 0x22cd482b9e0>,
#   <__main__.Vehicle at 0x22cd482baa0>],
#  [<__main__.Vehicle at 0x22cd482bb60>,
#   <__main__.Vehicle at 0x22cd482bc20>,
#   <__main__.Vehicle at 0x22cd482bce0>],
#  [<__main__.Vehicle at 0x22cd482bda0>,
#   <__main__.Vehicle at 0x22cd482be60>,
#   <__main__.Vehicle at 0x22cd482bf20>],
#  [<__main__.Vehicle at 0x22cd482bfe0>,
#   <__main__.Vehicle at 0x22cd48300e0>,
#   <__main__.Vehicle at 0x22cd48301a0>],
#  [<__main__.Vehicle at 0x22cd4830260>,
#   <__main__.Vehicle at 0x22cd4830320>,
#   <__main__.Vehicle at 0x22cd48303e0>],
#  [<__main__.Vehicle at 0x22cd48304a0>, <__main__.Vehicle at 0x22cd4830560>],
#  [<__main__.Vehicle at 0x22cd4830620>,
#   <__main__.Vehicle at 0x22cd48306e0>,
#   <__main__.Vehicle at 0x22cd48307a0>],
#  [<__main__.Vehicle at 0x22cd4830860>,
#   <__main__.Vehicle at 0x22cd4830920>,
#   <__main__.Vehicle at 0x22cd48309e0>],
#  [<__main__.Vehicle at 0x22cd4830aa0>,
#   <__main__.Vehicle at 0x22cd4830b60>,
#   <__main__.Vehicle at 0x22cd4830c20>],
#  [<__main__.Vehicle at 0x22cd4830ce0>, <__main__.Vehicle at 0x22cd4830da0>],
#  [<__main__.Vehicle at 0x22cd4830e60>,
#   <__main__.Vehicle at 0x22cd4830f20>,
#   <__main__.Vehicle at 0x22cd4830fe0>],
#  [<__main__.Vehicle at 0x22cd48310a0>, <__main__.Vehicle at 0x22cd4831160>],
#  [<__main__.Vehicle at 0x22cd4831220>,
#   <__main__.Vehicle at 0x22cd48312e0>,
#   <__main__.Vehicle at 0x22cd48313a0>],
#  [<__main__.Vehicle at 0x22cd4831460>,
#   <__main__.Vehicle at 0x22cd4831520>,
#   <__main__.Vehicle at 0x22cd48315e0>],
#  [<__main__.Vehicle at 0x22cd48316a0>,
#   <__main__.Vehicle at 0x22cd4831760>,
#   <__main__.Vehicle at 0x22cd4831820>],
#  [<__main__.Vehicle at 0x22cd48318e0>,
#   <__main__.Vehicle at 0x22cd48319a0>,
#   <__main__.Vehicle at 0x22cd4831a60>],
#  [<__main__.Vehicle at 0x22cd4831b20>, <__main__.Vehicle at 0x22cd4831be0>],
#  [<__main__.Vehicle at 0x22cd4831ca0>,
#   <__main__.Vehicle at 0x22cd4831d60>,
#   <__main__.Vehicle at 0x22cd4831e20>],
#  [<__main__.Vehicle at 0x22cd4831ee0>,
#   <__main__.Vehicle at 0x22cd4831fa0>,
#   <__main__.Vehicle at 0x22cd4832060>],
#  [<__main__.Vehicle at 0x22cd4832120>,
#   <__main__.Vehicle at 0x22cd48321e0>,
#   <__main__.Vehicle at 0x22cd48322a0>],
#  [<__main__.Vehicle at 0x22cd4832360>,
#   <__main__.Vehicle at 0x22cd4832420>,
#   <__main__.Vehicle at 0x22cd48324e0>],
#  [<__main__.Vehicle at 0x22cd48325a0>, <__main__.Vehicle at 0x22cd4832660>],
#  [<__main__.Vehicle at 0x22cd4832720>, <__main__.Vehicle at 0x22cd48327e0>],
#  [<__main__.Vehicle at 0x22cd48328a0>,
#   <__main__.Vehicle at 0x22cd4832960>,
#   <__main__.Vehicle at 0x22cd4832a20>],
#  [<__main__.Vehicle at 0x22cd4832ae0>,
#   <__main__.Vehicle at 0x22cd4832ba0>,
#   <__main__.Vehicle at 0x22cd4832c60>],
#  [<__main__.Vehicle at 0x22cd4832d20>,
#   <__main__.Vehicle at 0x22cd4832de0>,
#   <__main__.Vehicle at 0x22cd4832ea0>],
#  [<__main__.Vehicle at 0x22cd4832f60>,
#   <__main__.Vehicle at 0x22cd4833020>,
#   <__main__.Vehicle at 0x22cd48330e0>],
#  [<__main__.Vehicle at 0x22cd48331a0>,
#   <__main__.Vehicle at 0x22cd4833260>,
#   <__main__.Vehicle at 0x22cd4833320>],
#  [<__main__.Vehicle at 0x22cd48333e0>, <__main__.Vehicle at 0x22cd48334a0>],
#  [<__main__.Vehicle at 0x22cd4833560>,
#   <__main__.Vehicle at 0x22cd4833620>,
#   <__main__.Vehicle at 0x22cd48336e0>],
#  [<__main__.Vehicle at 0x22cd48337a0>,
#   <__main__.Vehicle at 0x22cd4833860>,
#   <__main__.Vehicle at 0x22cd4833920>],
#  [<__main__.Vehicle at 0x22cd48339e0>,
#   <__main__.Vehicle at 0x22cd4833aa0>,
#   <__main__.Vehicle at 0x22cd4833b60>],
#  [<__main__.Vehicle at 0x22cd4833c20>,
#   <__main__.Vehicle at 0x22cd4833ce0>,
#   <__main__.Vehicle at 0x22cd4833da0>],
#  [<__main__.Vehicle at 0x22cd4833e60>,
#   <__main__.Vehicle at 0x22cd4833f20>,
#   <__main__.Vehicle at 0x22cd4833fe0>],
#  [<__main__.Vehicle at 0x22cd48380e0>,
#   <__main__.Vehicle at 0x22cd48381a0>,
#   <__main__.Vehicle at 0x22cd4838260>],
#  [<__main__.Vehicle at 0x22cd4838320>,
#   <__main__.Vehicle at 0x22cd48383e0>,
#   <__main__.Vehicle at 0x22cd48384a0>],
#  [<__main__.Vehicle at 0x22cd4838560>,
#   <__main__.Vehicle at 0x22cd4838620>,
#   <__main__.Vehicle at 0x22cd48386e0>],
#  [<__main__.Vehicle at 0x22cd48387a0>, <__main__.Vehicle at 0x22cd4838860>],
#  [<__main__.Vehicle at 0x22cd4838920>,
#   <__main__.Vehicle at 0x22cd48389e0>,
#   <__main__.Vehicle at 0x22cd4838aa0>],
#  [<__main__.Vehicle at 0x22cd4838b60>,
#   <__main__.Vehicle at 0x22cd4838c20>,
#   <__main__.Vehicle at 0x22cd4838ce0>],
#  [<__main__.Vehicle at 0x22cd4838da0>,
#   <__main__.Vehicle at 0x22cd4838e60>,
#   <__main__.Vehicle at 0x22cd4838f20>],
#  [<__main__.Vehicle at 0x22cd4838fe0>,
#   <__main__.Vehicle at 0x22cd48390a0>,
#   <__main__.Vehicle at 0x22cd4839160>],
#  [<__main__.Vehicle at 0x22cd4839220>,
#   <__main__.Vehicle at 0x22cd48392e0>,
#   <__main__.Vehicle at 0x22cd48393a0>],
#  [<__main__.Vehicle at 0x22cd4839460>,
#   <__main__.Vehicle at 0x22cd4839520>,
#   <__main__.Vehicle at 0x22cd48395e0>],
#  [<__main__.Vehicle at 0x22cd48396a0>,
#   <__main__.Vehicle at 0x22cd4839760>,
#   <__main__.Vehicle at 0x22cd4839820>],
#  [<__main__.Vehicle at 0x22cd48398e0>,
#   <__main__.Vehicle at 0x22cd48399a0>,
#   <__main__.Vehicle at 0x22cd4839a60>],
#  [<__main__.Vehicle at 0x22cd4839b20>,
#   <__main__.Vehicle at 0x22cd4839be0>,
#   <__main__.Vehicle at 0x22cd4839ca0>],
#  [<__main__.Vehicle at 0x22cd4839d60>,
#   <__main__.Vehicle at 0x22cd4839e20>,
#   <__main__.Vehicle at 0x22cd4839ee0>],
#  [<__main__.Vehicle at 0x22cd4839fa0>,
#   <__main__.Vehicle at 0x22cd483a060>,
#   <__main__.Vehicle at 0x22cd483a120>],
#  [<__main__.Vehicle at 0x22cd483a1e0>,
#   <__main__.Vehicle at 0x22cd483a2a0>,
#   <__main__.Vehicle at 0x22cd483a360>],
#  [<__main__.Vehicle at 0x22cd483a420>,
#   <__main__.Vehicle at 0x22cd483a4e0>,
#   <__main__.Vehicle at 0x22cd483a5a0>],
#  [<__main__.Vehicle at 0x22cd483a660>,
#   <__main__.Vehicle at 0x22cd483a720>,
#   <__main__.Vehicle at 0x22cd483a7e0>],
#  [<__main__.Vehicle at 0x22cd483a8a0>, <__main__.Vehicle at 0x22cd483a960>],
#  [<__main__.Vehicle at 0x22cd483aa20>,
#   <__main__.Vehicle at 0x22cd483aae0>,
#   <__main__.Vehicle at 0x22cd483aba0>],
#  [<__main__.Vehicle at 0x22cd483ac60>,
#   <__main__.Vehicle at 0x22cd483ad20>,
#   <__main__.Vehicle at 0x22cd483ade0>],
#  [<__main__.Vehicle at 0x22cd483aea0>,
#   <__main__.Vehicle at 0x22cd483af60>,
#   <__main__.Vehicle at 0x22cd483b020>],
#  [<__main__.Vehicle at 0x22cd483b0e0>,
#   <__main__.Vehicle at 0x22cd483b1a0>,
#   <__main__.Vehicle at 0x22cd483b260>],
#  [<__main__.Vehicle at 0x22cd483b320>,
#   <__main__.Vehicle at 0x22cd483b3e0>,
#   <__main__.Vehicle at 0x22cd483b4a0>],
#  [<__main__.Vehicle at 0x22cd483b560>, <__main__.Vehicle at 0x22cd483b620>],
#  [<__main__.Vehicle at 0x22cd483b6e0>,
#   <__main__.Vehicle at 0x22cd483b7a0>,
#   <__main__.Vehicle at 0x22cd483b860>],
#  [<__main__.Vehicle at 0x22cd483b920>, <__main__.Vehicle at 0x22cd483b9e0>],
#  [<__main__.Vehicle at 0x22cd483baa0>,
#   <__main__.Vehicle at 0x22cd483bb60>,
#   <__main__.Vehicle at 0x22cd483bc20>],
#  [<__main__.Vehicle at 0x22cd483bce0>,
#   <__main__.Vehicle at 0x22cd483bda0>,
#   <__main__.Vehicle at 0x22cd483be60>],
#  [<__main__.Vehicle at 0x22cd483bf20>,
#   <__main__.Vehicle at 0x22cd483bfe0>,
#   <__main__.Vehicle at 0x22cd483c0e0>],
#  [<__main__.Vehicle at 0x22cd483c1a0>,
#   <__main__.Vehicle at 0x22cd483c260>,
#   <__main__.Vehicle at 0x22cd483c320>],
#  [<__main__.Vehicle at 0x22cd483c3e0>,
#   <__main__.Vehicle at 0x22cd483c4a0>,
#   <__main__.Vehicle at 0x22cd483c560>],
#  [<__main__.Vehicle at 0x22cd483c620>,
#   <__main__.Vehicle at 0x22cd483c6e0>,
#   <__main__.Vehicle at 0x22cd483c7a0>],
#  [<__main__.Vehicle at 0x22cd483c860>,
#   <__main__.Vehicle at 0x22cd483c920>,
#   <__main__.Vehicle at 0x22cd483c9e0>],
#  [<__main__.Vehicle at 0x22cd483caa0>,
#   <__main__.Vehicle at 0x22cd483cb60>,
#   <__main__.Vehicle at 0x22cd483cc20>],
#  [<__main__.Vehicle at 0x22cd483cce0>,
#   <__main__.Vehicle at 0x22cd483cda0>,
#   <__main__.Vehicle at 0x22cd483ce60>],
#  [<__main__.Vehicle at 0x22cd483cf20>, <__main__.Vehicle at 0x22cd483cfe0>],
#  [<__main__.Vehicle at 0x22cd483d0a0>,
#   <__main__.Vehicle at 0x22cd483d160>,
#   <__main__.Vehicle at 0x22cd483d220>],
#  [<__main__.Vehicle at 0x22cd483d2e0>,
#   <__main__.Vehicle at 0x22cd483d3a0>,
#   <__main__.Vehicle at 0x22cd483d460>],
#  [<__main__.Vehicle at 0x22cd483d520>,
#   <__main__.Vehicle at 0x22cd483d5e0>,
#   <__main__.Vehicle at 0x22cd483d6a0>],
#  [<__main__.Vehicle at 0x22cd483d760>,
#   <__main__.Vehicle at 0x22cd483d820>,
#   <__main__.Vehicle at 0x22cd483d8e0>],
#  [<__main__.Vehicle at 0x22cd483d9a0>,
#   <__main__.Vehicle at 0x22cd483da60>,
#   <__main__.Vehicle at 0x22cd483db20>],
#  [<__main__.Vehicle at 0x22cd483dbe0>, <__main__.Vehicle at 0x22cd483dca0>],
#  [<__main__.Vehicle at 0x22cd483dd60>,
#   <__main__.Vehicle at 0x22cd483de20>,
#   <__main__.Vehicle at 0x22cd483dee0>],
#  [<__main__.Vehicle at 0x22cd483dfa0>,
#   <__main__.Vehicle at 0x22cd483e060>,
#   <__main__.Vehicle at 0x22cd483e120>],
#  [<__main__.Vehicle at 0x22cd483e1e0>,
#   <__main__.Vehicle at 0x22cd483e2a0>,
#   <__main__.Vehicle at 0x22cd483e360>],
#  [<__main__.Vehicle at 0x22cd483e420>,
#   <__main__.Vehicle at 0x22cd483e4e0>,
#   <__main__.Vehicle at 0x22cd483e5a0>],
#  [<__main__.Vehicle at 0x22cd483e660>,
#   <__main__.Vehicle at 0x22cd483e720>,
#   <__main__.Vehicle at 0x22cd483e7e0>],
#  [<__main__.Vehicle at 0x22cd483e8a0>,
#   <__main__.Vehicle at 0x22cd483e960>,
#   <__main__.Vehicle at 0x22cd483ea20>],
#  [<__main__.Vehicle at 0x22cd483eae0>,
#   <__main__.Vehicle at 0x22cd483eba0>,
#   <__main__.Vehicle at 0x22cd483ec60>],
#  [<__main__.Vehicle at 0x22cd483ed20>,
#   <__main__.Vehicle at 0x22cd483ede0>,
#   <__main__.Vehicle at 0x22cd483eea0>],
#  [<__main__.Vehicle at 0x22cd483ef60>,
#   <__main__.Vehicle at 0x22cd483f020>,
#   <__main__.Vehicle at 0x22cd483f0e0>],
#  [<__main__.Vehicle at 0x22cd483f1a0>,
#   <__main__.Vehicle at 0x22cd483f260>,
#   <__main__.Vehicle at 0x22cd483f320>],
#  [<__main__.Vehicle at 0x22cd483f3e0>, <__main__.Vehicle at 0x22cd483f4a0>],
#  [<__main__.Vehicle at 0x22cd483f560>,
#   <__main__.Vehicle at 0x22cd483f620>,
#   <__main__.Vehicle at 0x22cd483f6e0>],
#  [<__main__.Vehicle at 0x22cd483f7a0>,
#   <__main__.Vehicle at 0x22cd483f860>,
#   <__main__.Vehicle at 0x22cd483f920>],
#  [<__main__.Vehicle at 0x22cd483f9e0>, <__main__.Vehicle at 0x22cd483faa0>],
#  [<__main__.Vehicle at 0x22cd483fb60>,
#   <__main__.Vehicle at 0x22cd483fc20>,
#   <__main__.Vehicle at 0x22cd483fce0>],
#  [<__main__.Vehicle at 0x22cd483fda0>, <__main__.Vehicle at 0x22cd483fe60>],
#  [<__main__.Vehicle at 0x22cd483ff20>,
#   <__main__.Vehicle at 0x22cd483ffe0>,
#   <__main__.Vehicle at 0x22cd48480e0>],
#  [<__main__.Vehicle at 0x22cd48481a0>, <__main__.Vehicle at 0x22cd4848260>],
#  [<__main__.Vehicle at 0x22cd4848320>,
#   <__main__.Vehicle at 0x22cd48483e0>,
#   <__main__.Vehicle at 0x22cd48484a0>],
#  [<__main__.Vehicle at 0x22cd4848560>,
#   <__main__.Vehicle at 0x22cd4848620>,
#   <__main__.Vehicle at 0x22cd48486e0>],
#  [<__main__.Vehicle at 0x22cd48487a0>, <__main__.Vehicle at 0x22cd4848860>],
#  [<__main__.Vehicle at 0x22cd4848920>,
#   <__main__.Vehicle at 0x22cd48489e0>,
#   <__main__.Vehicle at 0x22cd4848aa0>],
#  [<__main__.Vehicle at 0x22cd4848b60>,
#   <__main__.Vehicle at 0x22cd4848c20>,
#   <__main__.Vehicle at 0x22cd4848ce0>],
#  [<__main__.Vehicle at 0x22cd4848da0>,
#   <__main__.Vehicle at 0x22cd4848e60>,
#   <__main__.Vehicle at 0x22cd4848f20>],
#  [<__main__.Vehicle at 0x22cd4848fe0>,
#   <__main__.Vehicle at 0x22cd48490a0>,
#   <__main__.Vehicle at 0x22cd4849160>],
#  [<__main__.Vehicle at 0x22cd4849220>,
#   <__main__.Vehicle at 0x22cd48492e0>,
#   <__main__.Vehicle at 0x22cd48493a0>],
#  [<__main__.Vehicle at 0x22cd4849460>,
#   <__main__.Vehicle at 0x22cd4849520>,
#   <__main__.Vehicle at 0x22cd48495e0>],
#  [<__main__.Vehicle at 0x22cd48496a0>,
#   <__main__.Vehicle at 0x22cd4849760>,
#   <__main__.Vehicle at 0x22cd4849820>],
#  [<__main__.Vehicle at 0x22cd48498e0>, <__main__.Vehicle at 0x22cd48499a0>],
#  [<__main__.Vehicle at 0x22cd4849a60>,
#   <__main__.Vehicle at 0x22cd4849b20>,
#   <__main__.Vehicle at 0x22cd4849be0>],
#  [<__main__.Vehicle at 0x22cd4849ca0>,
#   <__main__.Vehicle at 0x22cd4849d60>,
#   <__main__.Vehicle at 0x22cd4849e20>],
#  [<__main__.Vehicle at 0x22cd4849ee0>,
#   <__main__.Vehicle at 0x22cd4849fa0>,
#   <__main__.Vehicle at 0x22cd484a060>],
#  [<__main__.Vehicle at 0x22cd484a120>,
#   <__main__.Vehicle at 0x22cd484a1e0>,
#   <__main__.Vehicle at 0x22cd484a2a0>],
#  [<__main__.Vehicle at 0x22cd484a360>, <__main__.Vehicle at 0x22cd484a420>],
#  [<__main__.Vehicle at 0x22cd484a4e0>,
#   <__main__.Vehicle at 0x22cd484a5a0>,
#   <__main__.Vehicle at 0x22cd484a660>],
#  [<__main__.Vehicle at 0x22cd484a720>,
#   <__main__.Vehicle at 0x22cd484a7e0>,
#   <__main__.Vehicle at 0x22cd484a8a0>],
#  [<__main__.Vehicle at 0x22cd484a960>,
#   <__main__.Vehicle at 0x22cd484aa20>,
#   <__main__.Vehicle at 0x22cd484aae0>],
#  [<__main__.Vehicle at 0x22cd484aba0>,
#   <__main__.Vehicle at 0x22cd484ac60>,
#   <__main__.Vehicle at 0x22cd484ad20>],
#  [<__main__.Vehicle at 0x22cd484ade0>,
#   <__main__.Vehicle at 0x22cd484aea0>,
#   <__main__.Vehicle at 0x22cd484af60>],
#  [<__main__.Vehicle at 0x22cd484b020>,
#   <__main__.Vehicle at 0x22cd484b0e0>,
#   <__main__.Vehicle at 0x22cd484b1a0>],
#  [<__main__.Vehicle at 0x22cd484b260>, <__main__.Vehicle at 0x22cd484b320>],
#  [<__main__.Vehicle at 0x22cd484b3e0>,
#   <__main__.Vehicle at 0x22cd484b4a0>,
#   <__main__.Vehicle at 0x22cd484b560>],
#  [<__main__.Vehicle at 0x22cd484b620>, <__main__.Vehicle at 0x22cd484b6e0>],
#  [<__main__.Vehicle at 0x22cd484b7a0>,
#   <__main__.Vehicle at 0x22cd484b860>,
#   <__main__.Vehicle at 0x22cd484b920>],
#  [<__main__.Vehicle at 0x22cd484b9e0>, <__main__.Vehicle at 0x22cd484baa0>],
#  [<__main__.Vehicle at 0x22cd484bb60>,
#   <__main__.Vehicle at 0x22cd484bc20>,
#   <__main__.Vehicle at 0x22cd484bce0>]]

# %%
# routes do not need to include depot at end, but shoudl include depot at start

# %% [markdown]
# # Tournament Selection

# %%
def fitness(solution):
    solutionCost = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        cost = fitness.getCost()
        solutionCost += cost
    return solutionCost

def distance(solution):
    solutionDistance = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        distance = fitness.getDistance()
        solutionDistance += distance
    return solutionDistance

# Randomly choose 20 samples, get one parent
def getParents(population):
    # choices = random.sample(population, 20)
    choices = population.copy()

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = fitness(vehicles)
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minA = choices[minpos]
    chosenSolutionCost.pop(minpos)
    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minB = choices[minpos]

    return minA, minB

A, B = getParents(solutions)
A[0].routes
# Out:
# [(4.4184,114.0932), (4.4932,114.1322), (4.4935,114.1828), (4.3818,114.2034)]

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

def getDuplicatedElements(li):
    duplicates = []
    for x in li:
        if x not in duplicates and li.count(x) >1:
            duplicates.append(x)
        
    return duplicates

# %%
def getCrossoverOffspring(firstParent, secondParent):
    childVehicles = []

    first = [[],[],[]]
    firstVehicles = []

    for i in range(len(firstParent)):
        #some solutions only have 2 vehicles
        if (firstParent[i].routes):
            firstParent[i].routes.pop(0)
        firstVehicles.append(firstParent[i].type)
        # for every route
        for j in range(len(firstParent[i].routes)):
            first[i].append(firstParent[i].routes[j].id)



    second = [[],[],[]]
    secondVehicles = []


    for i in range(len(secondParent)):
        #some solutions only have 2 vehicles
        if (secondParent[i].routes):
            secondParent[i].routes.pop(0)
        secondVehicles.append(secondParent[i].type)
        # for every route
        for j in range(len(secondParent[i].routes)):
            second[i].append(secondParent[i].routes[j].id)


    # Random Choice of 1,2,3,4
    choice = random.randint(1, 4)
    # Case 1 - first parent is  main, two vehicles remain, one vehicle changes
    if (choice == 1 or choice == 2):
        if (choice == 1):
            parent = first.copy()
            secondary = second.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = firstVehicles.copy()

        # Case 2 - second parent is main, two vehicles remain, one vehicle changes
        elif (choice == 2):
            parent = second.copy()
            secondary = first.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = secondVehicles.copy()

        missing = findMissing(parent)
        duplicates = getDuplicatedElements(parent)

        child = []
        for i in parent:
            if i not in child:
                child.append(i)
            else:
                if(missing):
                    child.append(missing[0])
                    missing.pop(0)

        if (missing):
            child += missing


    elif (choice == 3 or choice == 4):
        # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
        if (choice == 3):
            child = convertToOneDList(first)
            childVehicles = firstVehicles.copy()
        # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
        elif (choice == 4):
            child = convertToOneDList(second)
            childVehicles = secondVehicles.copy()

    return child, childVehicles

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation
def vehicleMutation(li):
    idx = random.randint(0, len(li)-1)
    if li[idx] == 'A':
        li[idx] = 'B'
    else:
        li[idx] = 'A'
    
    return li

# Routes Mutation - Swap
def routeMutation(li):
    if(len(li) >= 1):
        aIdx = random.randint(0, len(li)-1)
        bIdx = random.randint(0, len(li)-1)

        temp = li[aIdx]
        li[aIdx] = li[bIdx]
        li[bIdx] = temp

    return li

# %%
# print(childVehicles)
# print(vehicleMutation(childVehicles))

# print(child)
# print(routeMutation(child))

def getMutatedOffspring(first, second):

    child, childVehicles = getCrossoverOffspring(first, second)
    mutatedChild = routeMutation(child)
    mutatedVehicles = vehicleMutation(childVehicles)

    return mutatedChild, mutatedVehicles

# %% [markdown]
# # Convert back to class

# %%
# convert routes to Customer class
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()
print(li)

routes = []
for i in li:
    routes.append(Customer(i[0], i[1], i[2], i[3]))
# Out:
# [[1.0, 4.3555, 113.9777, 5.0],
#  [2.0, 4.3976, 114.0049, 8.0],
#  [3.0, 4.3163, 114.0764, 3.0],
#  [4.0, 4.3184, 113.9932, 6.0],
#  [5.0, 4.4024, 113.9896, 5.0],
#  [6.0, 4.4142, 114.0127, 8.0],
#  [7.0, 4.4804, 114.0734, 3.0],
#  [8.0, 4.3818, 114.2034, 6.0],
#  [9.0, 4.4935, 114.1828, 5.0],
#  [10.0, 4.4932, 114.1322, 8.0]]

# %%
def getOffspring(first, second):
    mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    while(len(mutatedChild) != 10):
        mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    # print(mutatedChild)
    # print(mutatedVehicles)

    offspring = []
    for i in mutatedVehicles:
        vehicle = Vehicle(i)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        filledCapacity = 0

        while(mutatedChild):
            idx = mutatedChild[0]
            selectedRoute = routes[idx-1]
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                mutatedChild.pop(0)
            else:
                break
        
        offspring.append(vehicle)

    return offspring

# %%
import copy
# Generate two offspring
parent1, parent2 = getParents(solutions)


noIteration = 250
minScore = 1000

for i in range(noIteration):
    population = []
    # each parent will produce 1000 offspring, and two best are selected
    for j in range(500):
        offspringA = getOffspring(parent1, parent2)
        offspringB = getOffspring(parent1, parent2)

        population.append(offspringA)
        population.append(offspringB)
    

    parent1, parent2 = getParents(population)

    averageScore = fitness(parent1)

    print('Iteration: ' + str(i+1))
    print('Score: ' + str(averageScore))

    if(averageScore < minScore):
        minScore = averageScore
        minParent = copy.deepcopy(parent1)
# Out:
# 'Iteration: 1'
# 'Score: 143.42708299858427'
# 'Iteration: 2'
# 'Score: 150.98313686644053'
# 'Iteration: 3'
# 'Score: 143.42708299858427'
# 'Iteration: 4'
# 'Score: 150.98313686644053'
# 'Iteration: 5'
# 'Score: 143.42708299858427'
# 'Iteration: 6'
# 'Score: 150.98313686644053'
# 'Iteration: 7'
# 'Score: 143.42708299858427'
# 'Iteration: 8'
# 'Score: 150.98313686644053'
# 'Iteration: 9'
# 'Score: 143.42708299858427'
# 'Iteration: 10'
# 'Score: 150.98313686644053'
# 'Iteration: 11'
# 'Score: 143.42708299858427'
# 'Iteration: 12'
# 'Score: 150.98313686644053'
# 'Iteration: 13'
# 'Score: 143.42708299858427'
# 'Iteration: 229'
# 'Score: 143.42708299858427'
# 'Iteration: 230'
# 'Score: 150.98313686644053'
# 'Iteration: 231'
# 'Score: 143.42708299858427'
# 'Iteration: 232'
# 'Score: 150.98313686644053'
# 'Iteration: 233'
# 'Score: 143.42708299858427'
# 'Iteration: 234'
# 'Score: 150.98313686644053'
# 'Iteration: 235'
# 'Score: 143.42708299858427'
# 'Iteration: 236'
# 'Score: 150.98313686644053'
# 'Iteration: 237'
# 'Score: 138.62678050413942'
# 'Iteration: 238'
# 'Score: 150.98313686644053'
# 'Iteration: 239'
# 'Score: 143.42708299858427'
# 'Iteration: 240'
# 'Score: 150.98313686644053'
# 'Iteration: 241'
# 'Score: 143.42708299858427'
# 'Iteration: 242'
# 'Score: 150.98313686644053'
# 'Iteration: 243'
# 'Score: 143.42708299858427'
# 'Iteration: 244'
# 'Score: 150.98313686644053'
# 'Iteration: 245'
# 'Score: 143.42708299858427'
# 'Iteration: 246'
# 'Score: 150.98313686644053'
# 'Iteration: 247'
# 'Score: 143.42708299858427'
# 'Iteration: 248'
# 'Score: 150.98313686644053'
# 'Iteration: 249'
# 'Score: 143.42708299858427'
# 'Iteration: 250'
# 'Score: 150.98313686644053'

# %%
print("Total Distance: " + str(round(distance(minParent), 2)) + " km")
print("Total Cost: RM " + str(round(minScore, 2)))
print('')


for idx, vehicle in enumerate(minParent):
    if(vehicle):

        print(f"Vehicle {idx+1} (Type {vehicle.type})")
        vehicleFitness = Fitness(vehicle)
        print(f"Round Trip Distance: {round(vehicleFitness.getDistance(),3)} km, Cost: RM {round(vehicleFitness.getCost(),2)}, Demand: {vehicleFitness.getDemand()}")

        for idx, route in enumerate(vehicle.routes):
            
            if (route.id == -1):
                routeName = "Depot"
                print(f"{routeName} -> ")
            else:
                routeName = "C"+str(int(route.id))
                print(f"{routeName} ({round(route.distance(vehicle.routes[idx-1]),2)} km) -> ")

        backToDepotDistance = vehicle.routes[-1].distance(vehicle.routes[0])
        print(f"Depot ({round(backToDepotDistance, 2)} km)")
        print('')
# Out:
# 'Total Distance: 107.95 km'
# 'Total Cost: RM 129.54'
# ''
# 'Vehicle 1 (Type A)'
# 'Round Trip Distance: 36.775 km, Cost: RM 44.13, Demand: 22.0'
# 'Depot -> '
# 'C3 (10.35 km) -> '
# 'C4 (8.32 km) -> '
# 'C1 (4.02 km) -> '
# 'C2 (5.01 km) -> '
# 'Depot (9.07 km)'
# ''
# 'Vehicle 2 (Type A)'
# 'Round Trip Distance: 36.512 km, Cost: RM 43.81, Demand: 24.0'
# 'Depot -> '
# 'C5 (10.48 km) -> '
# 'C6 (2.59 km) -> '
# 'C7 (8.98 km) -> '
# 'C10 (6.02 km) -> '
# 'Depot (8.44 km)'
# ''
# 'Vehicle 3 (Type A)'
# 'Round Trip Distance: 34.661 km, Cost: RM 41.59, Demand: 11.0'
# 'Depot -> '
# 'C9 (11.69 km) -> '
# 'C8 (11.36 km) -> '
# 'Depot (11.61 km)'
# ''
