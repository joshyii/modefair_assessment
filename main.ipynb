# %% [markdown]
# # Import Libraries

# %%
import random
import time
import csv

import numpy as np
import pandas as pd

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.routes = []
        self.rate = None
        self.capacity = None

    def addRoute(self, route):
        self.routes.append(route)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.routes.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
        self.distance = None
    
    # fitness is based on cost, since distance is directly in correlation with cost,
    # taking cost can be a more accurate representation of the efficiency of the route

    # routes = customer
    
    
    def getDistance(self):
        routes = self.vehicle.routes
        distance = 0

        for i in range (0, len(routes)):
            fromCity = routes[i]
            if i+1 < len(routes):
                toCity = routes[i+1]

            # return to depot
            else:
                toCity = routes[0]
            
            distance += fromCity.distance(toCity)

        return distance

    def getCost(self):
        self.distance = self.getDistance()
        return self.distance*(self.vehicle.rate)  
    
    def getDemand(self):
        routes = self.vehicle.routes
        totalDemand = 0

        for route in routes:
            totalDemand += route.demand

        return totalDemand

# %%
# fill in routes - choose vehicle - ensure routes is selected based on demands

# %% [markdown]
# # Generate Population

# %%
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

oriRoutes = []
for i in li:
    oriRoutes.append(Customer(i[0], i[1], i[2], i[3]))

solutions = [] #array of vehicles

for s in range(1000):
    print('iteration'+ str(s+1))
    routes = oriRoutes.copy()

    vehicles = []

    while(len(routes) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(routes):
            selectedRoute = random.choice(routes)
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                routes.remove(selectedRoute)
                print('Route ' + str(selectedRoute.id) + ', demand ' + str(selectedRoute.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# 'iteration1'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration2'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration3'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration4'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration5'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration6'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration7'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration8'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration9'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration10'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration11'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration12'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration13'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration14'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration15'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration16'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration17'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration18'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration19'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration20'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration21'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration22'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration23'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration24'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration25'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration26'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration27'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration28'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'iteration29'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'iteration30'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'iteration31'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration32'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration33'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration34'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration35'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration36'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration37'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration38'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration39'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration40'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration41'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration42'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration43'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration44'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration45'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration46'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration47'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration48'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration49'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration50'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration51'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration52'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration53'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration54'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration55'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration56'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration57'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration58'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration59'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration60'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration61'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration62'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration63'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration64'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration65'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration66'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration67'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration68'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration69'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration70'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration71'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration72'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration73'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration74'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration75'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration76'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration77'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration78'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration79'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration80'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration81'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration82'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration83'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration84'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration85'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration86'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration87'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration88'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration89'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration90'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration91'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration92'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration93'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration94'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration95'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration96'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration97'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration98'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration99'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration100'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration101'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration102'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'iteration103'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration104'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration105'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'iteration106'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'iteration107'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration108'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration109'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration110'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'iteration111'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration112'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'iteration113'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'iteration114'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'iteration115'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration116'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration117'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration118'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration119'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration120'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration121'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'iteration122'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration123'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration124'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration125'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration126'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration127'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration128'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration129'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'iteration130'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration131'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration132'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration133'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration134'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration135'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration136'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration137'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration138'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration139'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration140'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration141'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration142'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration143'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration144'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration145'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration146'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration147'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration148'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration149'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration150'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration151'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration152'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration153'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration154'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration155'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration156'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# ...
#  [<__main__.Vehicle at 0x22cd3c00e30>, <__main__.Vehicle at 0x22cd3c00ef0>],
#  [<__main__.Vehicle at 0x22cd3c00fb0>, <__main__.Vehicle at 0x22cd3c01070>],
#  [<__main__.Vehicle at 0x22cd3c01130>,
#   <__main__.Vehicle at 0x22cd3c011f0>,
#   <__main__.Vehicle at 0x22cd3c012b0>],
#  [<__main__.Vehicle at 0x22cd3c01370>, <__main__.Vehicle at 0x22cd3c01430>],
#  [<__main__.Vehicle at 0x22cd3c014f0>, <__main__.Vehicle at 0x22cd3c015b0>],
#  [<__main__.Vehicle at 0x22cd3c01670>,
#   <__main__.Vehicle at 0x22cd3c01730>,
#   <__main__.Vehicle at 0x22cd3c017f0>],
#  [<__main__.Vehicle at 0x22cd3c018b0>,
#   <__main__.Vehicle at 0x22cd3c01970>,
#   <__main__.Vehicle at 0x22cd3c01a30>],
#  [<__main__.Vehicle at 0x22cd3c01af0>, <__main__.Vehicle at 0x22cd3c01bb0>],
#  [<__main__.Vehicle at 0x22cd3c01c70>,
#   <__main__.Vehicle at 0x22cd3c01d30>,
#   <__main__.Vehicle at 0x22cd3c01df0>],
#  [<__main__.Vehicle at 0x22cd3c01eb0>,
#   <__main__.Vehicle at 0x22cd3c01f70>,
#   <__main__.Vehicle at 0x22cd3c02030>],
#  [<__main__.Vehicle at 0x22cd3c020f0>,
#   <__main__.Vehicle at 0x22cd3c021b0>,
#   <__main__.Vehicle at 0x22cd3c02270>],
#  [<__main__.Vehicle at 0x22cd3c02330>,
#   <__main__.Vehicle at 0x22cd3c023f0>,
#   <__main__.Vehicle at 0x22cd3c024b0>],
#  [<__main__.Vehicle at 0x22cd3c02570>,
#   <__main__.Vehicle at 0x22cd3c02630>,
#   <__main__.Vehicle at 0x22cd3c026f0>],
#  [<__main__.Vehicle at 0x22cd3c027b0>,
#   <__main__.Vehicle at 0x22cd3c02870>,
#   <__main__.Vehicle at 0x22cd3c02930>],
#  [<__main__.Vehicle at 0x22cd3c029f0>,
#   <__main__.Vehicle at 0x22cd3c02ab0>,
#   <__main__.Vehicle at 0x22cd3c02b70>],
#  [<__main__.Vehicle at 0x22cd3c02c30>,
#   <__main__.Vehicle at 0x22cd3c02cf0>,
#   <__main__.Vehicle at 0x22cd3c02db0>],
#  [<__main__.Vehicle at 0x22cd3c02e70>, <__main__.Vehicle at 0x22cd3c02f30>],
#  [<__main__.Vehicle at 0x22cd3c02ff0>,
#   <__main__.Vehicle at 0x22cd3c030b0>,
#   <__main__.Vehicle at 0x22cd3c03170>],
#  [<__main__.Vehicle at 0x22cd3c03230>,
#   <__main__.Vehicle at 0x22cd3c032f0>,
#   <__main__.Vehicle at 0x22cd3c033b0>],
#  [<__main__.Vehicle at 0x22cd3c03470>,
#   <__main__.Vehicle at 0x22cd3c03530>,
#   <__main__.Vehicle at 0x22cd3c035f0>],
#  [<__main__.Vehicle at 0x22cd3c036b0>,
#   <__main__.Vehicle at 0x22cd3c03770>,
#   <__main__.Vehicle at 0x22cd3c03830>],
#  [<__main__.Vehicle at 0x22cd3c038f0>,
#   <__main__.Vehicle at 0x22cd3c039b0>,
#   <__main__.Vehicle at 0x22cd3c03a70>],
#  [<__main__.Vehicle at 0x22cd3c03b30>,
#   <__main__.Vehicle at 0x22cd3c03bf0>,
#   <__main__.Vehicle at 0x22cd3c03cb0>],
#  [<__main__.Vehicle at 0x22cd3c03d70>,
#   <__main__.Vehicle at 0x22cd3c03e30>,
#   <__main__.Vehicle at 0x22cd3c03ef0>],
#  [<__main__.Vehicle at 0x22cd3c03fb0>,
#   <__main__.Vehicle at 0x22cd3c080b0>,
#   <__main__.Vehicle at 0x22cd3c08170>],
#  [<__main__.Vehicle at 0x22cd3c08230>,
#   <__main__.Vehicle at 0x22cd3c082f0>,
#   <__main__.Vehicle at 0x22cd3c083b0>],
#  [<__main__.Vehicle at 0x22cd3c08470>,
#   <__main__.Vehicle at 0x22cd3c08530>,
#   <__main__.Vehicle at 0x22cd3c085f0>],
#  [<__main__.Vehicle at 0x22cd3c086b0>,
#   <__main__.Vehicle at 0x22cd3c08770>,
#   <__main__.Vehicle at 0x22cd3c08830>],
#  [<__main__.Vehicle at 0x22cd3c088f0>,
#   <__main__.Vehicle at 0x22cd3c089b0>,
#   <__main__.Vehicle at 0x22cd3c08a70>],
#  [<__main__.Vehicle at 0x22cd3c08b30>, <__main__.Vehicle at 0x22cd3c08bf0>],
#  [<__main__.Vehicle at 0x22cd3c08cb0>,
#   <__main__.Vehicle at 0x22cd3c08d70>,
#   <__main__.Vehicle at 0x22cd3c08e30>],
#  [<__main__.Vehicle at 0x22cd3c08ef0>,
#   <__main__.Vehicle at 0x22cd3c08fb0>,
#   <__main__.Vehicle at 0x22cd3c09070>],
#  [<__main__.Vehicle at 0x22cd3c09130>,
#   <__main__.Vehicle at 0x22cd3c091f0>,
#   <__main__.Vehicle at 0x22cd3c092b0>],
#  [<__main__.Vehicle at 0x22cd3c09370>,
#   <__main__.Vehicle at 0x22cd3c09430>,
#   <__main__.Vehicle at 0x22cd3c094f0>],
#  [<__main__.Vehicle at 0x22cd3c095b0>,
#   <__main__.Vehicle at 0x22cd3c09670>,
#   <__main__.Vehicle at 0x22cd3c09730>],
#  [<__main__.Vehicle at 0x22cd3c097f0>,
#   <__main__.Vehicle at 0x22cd3c098b0>,
#   <__main__.Vehicle at 0x22cd3c09970>],
#  [<__main__.Vehicle at 0x22cd3c09a30>,
#   <__main__.Vehicle at 0x22cd3c09af0>,
#   <__main__.Vehicle at 0x22cd3c09bb0>],
#  [<__main__.Vehicle at 0x22cd3c09c70>, <__main__.Vehicle at 0x22cd3c09d30>],
#  [<__main__.Vehicle at 0x22cd3c09df0>,
#   <__main__.Vehicle at 0x22cd3c09eb0>,
#   <__main__.Vehicle at 0x22cd3c09f70>],
#  [<__main__.Vehicle at 0x22cd3c0a030>,
#   <__main__.Vehicle at 0x22cd3c0a0f0>,
#   <__main__.Vehicle at 0x22cd3c0a1b0>],
#  [<__main__.Vehicle at 0x22cd3c0a270>,
#   <__main__.Vehicle at 0x22cd3c0a330>,
#   <__main__.Vehicle at 0x22cd3c0a3f0>],
#  [<__main__.Vehicle at 0x22cd3c0a4b0>,
#   <__main__.Vehicle at 0x22cd3c0a570>,
#   <__main__.Vehicle at 0x22cd3c0a630>],
#  [<__main__.Vehicle at 0x22cd3c0a6f0>,
#   <__main__.Vehicle at 0x22cd3c0a7b0>,
#   <__main__.Vehicle at 0x22cd3c0a870>],
#  [<__main__.Vehicle at 0x22cd3c0a930>,
#   <__main__.Vehicle at 0x22cd3c0a9f0>,
#   <__main__.Vehicle at 0x22cd3c0aab0>],
#  [<__main__.Vehicle at 0x22cd3c0ab70>,
#   <__main__.Vehicle at 0x22cd3c0ac30>,
#   <__main__.Vehicle at 0x22cd3c0acf0>],
#  [<__main__.Vehicle at 0x22cd3c0adb0>, <__main__.Vehicle at 0x22cd3c0ae70>],
#  [<__main__.Vehicle at 0x22cd3c0af30>,
#   <__main__.Vehicle at 0x22cd3c0aff0>,
#   <__main__.Vehicle at 0x22cd3c0b0b0>],
#  [<__main__.Vehicle at 0x22cd3c0b170>,
#   <__main__.Vehicle at 0x22cd3c0b230>,
#   <__main__.Vehicle at 0x22cd3c0b2f0>],
#  [<__main__.Vehicle at 0x22cd3c0b3b0>,
#   <__main__.Vehicle at 0x22cd3c0b470>,
#   <__main__.Vehicle at 0x22cd3c0b530>],
#  [<__main__.Vehicle at 0x22cd3c0b5f0>,
#   <__main__.Vehicle at 0x22cd3c0b6b0>,
#   <__main__.Vehicle at 0x22cd3c0b770>],
#  [<__main__.Vehicle at 0x22cd3c0b830>,
#   <__main__.Vehicle at 0x22cd3c0b8f0>,
#   <__main__.Vehicle at 0x22cd3c0b9b0>],
#  [<__main__.Vehicle at 0x22cd3c0ba70>,
#   <__main__.Vehicle at 0x22cd3c0bb30>,
#   <__main__.Vehicle at 0x22cd3c0bbf0>],
#  [<__main__.Vehicle at 0x22cd3c0bcb0>,
#   <__main__.Vehicle at 0x22cd3c0bd70>,
#   <__main__.Vehicle at 0x22cd3c0be30>],
#  [<__main__.Vehicle at 0x22cd3c0bef0>,
#   <__main__.Vehicle at 0x22cd3c0bfb0>,
#   <__main__.Vehicle at 0x22cd3c0c0b0>],
#  [<__main__.Vehicle at 0x22cd3c0c170>,
#   <__main__.Vehicle at 0x22cd3c0c230>,
#   <__main__.Vehicle at 0x22cd3c0c2f0>],
#  [<__main__.Vehicle at 0x22cd3c0c3b0>, <__main__.Vehicle at 0x22cd3c0c470>],
#  [<__main__.Vehicle at 0x22cd3c0c530>,
#   <__main__.Vehicle at 0x22cd3c0c5f0>,
#   <__main__.Vehicle at 0x22cd3c0c6b0>],
#  [<__main__.Vehicle at 0x22cd3c0c770>,
#   <__main__.Vehicle at 0x22cd3c0c830>,
#   <__main__.Vehicle at 0x22cd3c0c8f0>],
#  [<__main__.Vehicle at 0x22cd3c0c9b0>,
#   <__main__.Vehicle at 0x22cd3c0ca70>,
#   <__main__.Vehicle at 0x22cd3c0cb30>],
#  [<__main__.Vehicle at 0x22cd3c0cbf0>,
#   <__main__.Vehicle at 0x22cd3c0ccb0>,
#   <__main__.Vehicle at 0x22cd3c0cd70>],
#  [<__main__.Vehicle at 0x22cd3c0ce30>, <__main__.Vehicle at 0x22cd3c0cef0>],
#  [<__main__.Vehicle at 0x22cd3c0cfb0>,
#   <__main__.Vehicle at 0x22cd3c0d070>,
#   <__main__.Vehicle at 0x22cd3c0d130>],
#  [<__main__.Vehicle at 0x22cd3c0d1f0>,
#   <__main__.Vehicle at 0x22cd3c0d2b0>,
#   <__main__.Vehicle at 0x22cd3c0d370>],
#  [<__main__.Vehicle at 0x22cd3c0d430>, <__main__.Vehicle at 0x22cd3c0d4f0>],
#  [<__main__.Vehicle at 0x22cd3c0d5b0>,
#   <__main__.Vehicle at 0x22cd3c0d670>,
#   <__main__.Vehicle at 0x22cd3c0d730>],
#  [<__main__.Vehicle at 0x22cd3c0d7f0>,
#   <__main__.Vehicle at 0x22cd3c0d8b0>,
#   <__main__.Vehicle at 0x22cd3c0d970>],
#  [<__main__.Vehicle at 0x22cd3c0da30>,
#   <__main__.Vehicle at 0x22cd3c0daf0>,
#   <__main__.Vehicle at 0x22cd3c0dbb0>],
#  [<__main__.Vehicle at 0x22cd3c0dc70>,
#   <__main__.Vehicle at 0x22cd3c0dd30>,
#   <__main__.Vehicle at 0x22cd3c0ddf0>],
#  [<__main__.Vehicle at 0x22cd3c0deb0>,
#   <__main__.Vehicle at 0x22cd3c0df70>,
#   <__main__.Vehicle at 0x22cd3c0e030>],
#  [<__main__.Vehicle at 0x22cd3c0e0f0>, <__main__.Vehicle at 0x22cd3c0e1b0>],
#  [<__main__.Vehicle at 0x22cd3c0e270>, <__main__.Vehicle at 0x22cd3c0e330>],
#  [<__main__.Vehicle at 0x22cd3c0e3f0>,
#   <__main__.Vehicle at 0x22cd3c0e4b0>,
#   <__main__.Vehicle at 0x22cd3c0e570>],
#  [<__main__.Vehicle at 0x22cd3c0e630>,
#   <__main__.Vehicle at 0x22cd3c0e6f0>,
#   <__main__.Vehicle at 0x22cd3c0e7b0>],
#  [<__main__.Vehicle at 0x22cd3c0e870>, <__main__.Vehicle at 0x22cd3c0e930>],
#  [<__main__.Vehicle at 0x22cd3c0e9f0>,
#   <__main__.Vehicle at 0x22cd3c0eab0>,
#   <__main__.Vehicle at 0x22cd3c0eb70>],
#  [<__main__.Vehicle at 0x22cd3c0ec30>,
#   <__main__.Vehicle at 0x22cd3c0ecf0>,
#   <__main__.Vehicle at 0x22cd3c0edb0>],
#  [<__main__.Vehicle at 0x22cd3c0ee70>,
#   <__main__.Vehicle at 0x22cd3c0ef30>,
#   <__main__.Vehicle at 0x22cd3c0eff0>],
#  [<__main__.Vehicle at 0x22cd3c0f0b0>,
#   <__main__.Vehicle at 0x22cd3c0f170>,
#   <__main__.Vehicle at 0x22cd3c0f230>],
#  [<__main__.Vehicle at 0x22cd3c0f2f0>,
#   <__main__.Vehicle at 0x22cd3c0f3b0>,
#   <__main__.Vehicle at 0x22cd3c0f470>],
#  [<__main__.Vehicle at 0x22cd3c0f530>,
#   <__main__.Vehicle at 0x22cd3c0f5f0>,
#   <__main__.Vehicle at 0x22cd3c0f6b0>],
#  [<__main__.Vehicle at 0x22cd3c0f770>,
#   <__main__.Vehicle at 0x22cd3c0f830>,
#   <__main__.Vehicle at 0x22cd3c0f8f0>],
#  [<__main__.Vehicle at 0x22cd3c0f9b0>,
#   <__main__.Vehicle at 0x22cd3c0fa70>,
#   <__main__.Vehicle at 0x22cd3c0fb30>],
#  [<__main__.Vehicle at 0x22cd3c0fbf0>,
#   <__main__.Vehicle at 0x22cd3c0fcb0>,
#   <__main__.Vehicle at 0x22cd3c0fd70>],
#  [<__main__.Vehicle at 0x22cd3c0fe30>,
#   <__main__.Vehicle at 0x22cd3c0fef0>,
#   <__main__.Vehicle at 0x22cd3c0ffb0>],
#  [<__main__.Vehicle at 0x22cd3c140b0>, <__main__.Vehicle at 0x22cd3c14170>],
#  [<__main__.Vehicle at 0x22cd3c14230>,
#   <__main__.Vehicle at 0x22cd3c142f0>,
#   <__main__.Vehicle at 0x22cd3c143b0>],
#  [<__main__.Vehicle at 0x22cd3c14470>,
#   <__main__.Vehicle at 0x22cd3c14530>,
#   <__main__.Vehicle at 0x22cd3c145f0>],
#  [<__main__.Vehicle at 0x22cd3c146b0>,
#   <__main__.Vehicle at 0x22cd3c14770>,
#   <__main__.Vehicle at 0x22cd3c14830>],
#  [<__main__.Vehicle at 0x22cd3c148f0>,
#   <__main__.Vehicle at 0x22cd3c149b0>,
#   <__main__.Vehicle at 0x22cd3c14a70>],
#  [<__main__.Vehicle at 0x22cd3c14b30>,
#   <__main__.Vehicle at 0x22cd3c14bf0>,
#   <__main__.Vehicle at 0x22cd3c14cb0>],
#  [<__main__.Vehicle at 0x22cd3c14d70>,
#   <__main__.Vehicle at 0x22cd3c14e30>,
#   <__main__.Vehicle at 0x22cd3c14ef0>],
#  [<__main__.Vehicle at 0x22cd3c14fb0>,
#   <__main__.Vehicle at 0x22cd3c15070>,
#   <__main__.Vehicle at 0x22cd3c15130>],
#  [<__main__.Vehicle at 0x22cd3c151f0>,
#   <__main__.Vehicle at 0x22cd3c152b0>,
#   <__main__.Vehicle at 0x22cd3c15370>],
#  [<__main__.Vehicle at 0x22cd3c15430>,
#   <__main__.Vehicle at 0x22cd3c154f0>,
#   <__main__.Vehicle at 0x22cd3c155b0>],
#  [<__main__.Vehicle at 0x22cd3c15670>,
#   <__main__.Vehicle at 0x22cd3c15730>,
#   <__main__.Vehicle at 0x22cd3c157f0>],
#  [<__main__.Vehicle at 0x22cd3c158b0>,
#   <__main__.Vehicle at 0x22cd3c15970>,
#   <__main__.Vehicle at 0x22cd3c15a30>],
#  [<__main__.Vehicle at 0x22cd3c15af0>,
#   <__main__.Vehicle at 0x22cd3c15bb0>,
#   <__main__.Vehicle at 0x22cd3c15c70>],
#  [<__main__.Vehicle at 0x22cd3c15d30>,
#   <__main__.Vehicle at 0x22cd3c15df0>,
#   <__main__.Vehicle at 0x22cd3c15eb0>],
#  [<__main__.Vehicle at 0x22cd3c15f70>,
#   <__main__.Vehicle at 0x22cd3c16030>,
#   <__main__.Vehicle at 0x22cd3c160f0>],
#  [<__main__.Vehicle at 0x22cd3c161b0>,
#   <__main__.Vehicle at 0x22cd3c16270>,
#   <__main__.Vehicle at 0x22cd3c16330>],
#  [<__main__.Vehicle at 0x22cd3c163f0>, <__main__.Vehicle at 0x22cd3c164b0>],
#  [<__main__.Vehicle at 0x22cd3c16570>,
#   <__main__.Vehicle at 0x22cd3c16630>,
#   <__main__.Vehicle at 0x22cd3c166f0>],
#  [<__main__.Vehicle at 0x22cd3c167b0>, <__main__.Vehicle at 0x22cd3c16870>],
#  [<__main__.Vehicle at 0x22cd3c16930>,
#   <__main__.Vehicle at 0x22cd3c169f0>,
#   <__main__.Vehicle at 0x22cd3c16ab0>],
#  [<__main__.Vehicle at 0x22cd3c16b70>,
#   <__main__.Vehicle at 0x22cd3c16c30>,
#   <__main__.Vehicle at 0x22cd3c16cf0>],
#  [<__main__.Vehicle at 0x22cd3c16db0>, <__main__.Vehicle at 0x22cd3c16e70>],
#  [<__main__.Vehicle at 0x22cd3c16f30>, <__main__.Vehicle at 0x22cd3c16ff0>],
#  [<__main__.Vehicle at 0x22cd3c170b0>,
#   <__main__.Vehicle at 0x22cd3c17170>,
#   <__main__.Vehicle at 0x22cd3c17230>],
#  [<__main__.Vehicle at 0x22cd3c172f0>,
#   <__main__.Vehicle at 0x22cd3c173b0>,
#   <__main__.Vehicle at 0x22cd3c17470>],
#  [<__main__.Vehicle at 0x22cd3c17530>,
#   <__main__.Vehicle at 0x22cd3c175f0>,
#   <__main__.Vehicle at 0x22cd3c176b0>],
#  [<__main__.Vehicle at 0x22cd3c17770>,
#   <__main__.Vehicle at 0x22cd3c17830>,
#   <__main__.Vehicle at 0x22cd3c178f0>],
#  [<__main__.Vehicle at 0x22cd3c179b0>, <__main__.Vehicle at 0x22cd3c17a70>],
#  [<__main__.Vehicle at 0x22cd3c17b30>,
#   <__main__.Vehicle at 0x22cd3c17bf0>,
#   <__main__.Vehicle at 0x22cd3c17cb0>],
#  [<__main__.Vehicle at 0x22cd3c17d70>,
#   <__main__.Vehicle at 0x22cd3c17e30>,
#   <__main__.Vehicle at 0x22cd3c17ef0>],
#  [<__main__.Vehicle at 0x22cd3c17fb0>,
#   <__main__.Vehicle at 0x22cd3c200b0>,
#   <__main__.Vehicle at 0x22cd3c20170>],
#  [<__main__.Vehicle at 0x22cd3c20230>,
#   <__main__.Vehicle at 0x22cd3c202f0>,
#   <__main__.Vehicle at 0x22cd3c203b0>],
#  [<__main__.Vehicle at 0x22cd3c20470>,
#   <__main__.Vehicle at 0x22cd3c20530>,
#   <__main__.Vehicle at 0x22cd3c205f0>],
#  [<__main__.Vehicle at 0x22cd3c206b0>,
#   <__main__.Vehicle at 0x22cd3c20770>,
#   <__main__.Vehicle at 0x22cd3c20830>],
#  [<__main__.Vehicle at 0x22cd3c208f0>, <__main__.Vehicle at 0x22cd3c209b0>],
#  [<__main__.Vehicle at 0x22cd3c20a70>,
#   <__main__.Vehicle at 0x22cd3c20b30>,
#   <__main__.Vehicle at 0x22cd3c20bf0>],
#  [<__main__.Vehicle at 0x22cd3c20cb0>,
#   <__main__.Vehicle at 0x22cd3c20d70>,
#   <__main__.Vehicle at 0x22cd3c20e30>],
#  [<__main__.Vehicle at 0x22cd3c20ef0>,
#   <__main__.Vehicle at 0x22cd3c20fb0>,
#   <__main__.Vehicle at 0x22cd3c21070>],
#  [<__main__.Vehicle at 0x22cd3c21130>,
#   <__main__.Vehicle at 0x22cd3c211f0>,
#   <__main__.Vehicle at 0x22cd3c212b0>],
#  [<__main__.Vehicle at 0x22cd3c21370>, <__main__.Vehicle at 0x22cd3c21430>],
#  [<__main__.Vehicle at 0x22cd3c214f0>,
#   <__main__.Vehicle at 0x22cd3c215b0>,
#   <__main__.Vehicle at 0x22cd3c21670>],
#  [<__main__.Vehicle at 0x22cd3c21730>, <__main__.Vehicle at 0x22cd3c217f0>],
#  [<__main__.Vehicle at 0x22cd3c218b0>,
#   <__main__.Vehicle at 0x22cd3c21970>,
#   <__main__.Vehicle at 0x22cd3c21a30>],
#  [<__main__.Vehicle at 0x22cd3c21af0>,
#   <__main__.Vehicle at 0x22cd3c21bb0>,
#   <__main__.Vehicle at 0x22cd3c21c70>],
#  [<__main__.Vehicle at 0x22cd3c21d30>,
#   <__main__.Vehicle at 0x22cd3c21df0>,
#   <__main__.Vehicle at 0x22cd3c21eb0>],
#  [<__main__.Vehicle at 0x22cd3c21f70>,
#   <__main__.Vehicle at 0x22cd3c22030>,
#   <__main__.Vehicle at 0x22cd3c220f0>],
#  [<__main__.Vehicle at 0x22cd3c221b0>,
#   <__main__.Vehicle at 0x22cd3c22270>,
#   <__main__.Vehicle at 0x22cd3c22330>],
#  [<__main__.Vehicle at 0x22cd3c223f0>,
#   <__main__.Vehicle at 0x22cd3c224b0>,
#   <__main__.Vehicle at 0x22cd3c22570>],
#  [<__main__.Vehicle at 0x22cd3c22630>,
#   <__main__.Vehicle at 0x22cd3c226f0>,
#   <__main__.Vehicle at 0x22cd3c227b0>],
#  [<__main__.Vehicle at 0x22cd3c22870>,
#   <__main__.Vehicle at 0x22cd3c22930>,
#   <__main__.Vehicle at 0x22cd3c229f0>],
#  [<__main__.Vehicle at 0x22cd3c22ab0>,
#   <__main__.Vehicle at 0x22cd3c22b70>,
#   <__main__.Vehicle at 0x22cd3c22c30>],
#  [<__main__.Vehicle at 0x22cd3c22cf0>, <__main__.Vehicle at 0x22cd3c22db0>],
#  [<__main__.Vehicle at 0x22cd3c22e70>,
#   <__main__.Vehicle at 0x22cd3c22f30>,
#   <__main__.Vehicle at 0x22cd3c22ff0>],
#  [<__main__.Vehicle at 0x22cd3c230b0>,
#   <__main__.Vehicle at 0x22cd3c23170>,
#   <__main__.Vehicle at 0x22cd3c23230>],
#  [<__main__.Vehicle at 0x22cd3c232f0>,
#   <__main__.Vehicle at 0x22cd3c233b0>,
#   <__main__.Vehicle at 0x22cd3c23470>],
#  [<__main__.Vehicle at 0x22cd3c23530>, <__main__.Vehicle at 0x22cd3c235f0>],
#  [<__main__.Vehicle at 0x22cd3c236b0>,
#   <__main__.Vehicle at 0x22cd3c23770>,
#   <__main__.Vehicle at 0x22cd3c23830>],
#  [<__main__.Vehicle at 0x22cd3c238f0>, <__main__.Vehicle at 0x22cd3c239b0>],
#  [<__main__.Vehicle at 0x22cd3c23a70>,
#   <__main__.Vehicle at 0x22cd3c23b30>,
#   <__main__.Vehicle at 0x22cd3c23bf0>],
#  [<__main__.Vehicle at 0x22cd3c23cb0>,
#   <__main__.Vehicle at 0x22cd3c23d70>,
#   <__main__.Vehicle at 0x22cd3c23e30>],
#  [<__main__.Vehicle at 0x22cd3c23ef0>, <__main__.Vehicle at 0x22cd3c23fb0>]]

# %%
# routes do not need to include depot at end, but shoudl include depot at start

# %% [markdown]
# # Tournament Selection

# %%
def fitness(solution):
    solutionCost = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        cost = fitness.getCost()
        solutionCost += cost
    return solutionCost

def distance(solution):
    solutionDistance = 0
    for vehicle in solution:
        fitness = Fitness(vehicle)
        distance = fitness.getDistance()
        solutionDistance += distance
    return solutionDistance

# Randomly choose 20 samples, get one parent
def getParents(population):
    # choices = random.sample(population, 20)
    choices = population.copy()

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = fitness(vehicles)
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minA = choices[minpos]
    chosenSolutionCost.pop(minpos)
    minpos = chosenSolutionCost.index(min(chosenSolutionCost))
    minB = choices[minpos]

    return minA, minB

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

def getDuplicatedElements(li):
    duplicates = []
    for x in li:
        if x not in duplicates and li.count(x) >1:
            duplicates.append(x)
        
    return duplicates

# %%
def getCrossoverOffspring(firstParent, secondParent):
    childVehicles = []

    first = [[],[],[]]
    firstVehicles = []

    for i in range(len(firstParent)):
        #some solutions only have 2 vehicles
        if (firstParent[i].routes):
            firstParent[i].routes.pop(0)
        firstVehicles.append(firstParent[i].type)
        # for every route
        for j in range(len(firstParent[i].routes)):
            first[i].append(firstParent[i].routes[j].id)



    second = [[],[],[]]
    secondVehicles = []


    for i in range(len(secondParent)):
        if (secondParent[i].routes):
            secondParent[i].routes.pop(0)
        secondVehicles.append(secondParent[i].type)
        # for every route
        for j in range(len(secondParent[i].routes)):
            second[i].append(secondParent[i].routes[j].id)


    # Random Choice of 1,2,3,4
    choice = random.randint(1, 4)
    # Case 1 - first parent is  main, two vehicles remain, one vehicle changes
    if (choice == 1 or choice == 2):
        if (choice == 1):
            parent = first.copy()
            secondary = second.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = firstVehicles.copy()

        # Case 2 - second parent is main, two vehicles remain, one vehicle changes
        elif (choice == 2):
            parent = second.copy()
            secondary = first.copy()
            selectedVehicleIdx = random.randint(0, len(parent)-1)
            selectedToSwapVehicle = random.choice(secondary)
            parent[selectedVehicleIdx] = selectedToSwapVehicle
            parent = convertToOneDList(parent)
            childVehicles = secondVehicles.copy()

        missing = findMissing(parent)
        duplicates = getDuplicatedElements(parent)

        child = []
        for i in parent:
            if i not in child:
                child.append(i)
            else:
                if(missing):
                    child.append(missing[0])
                    missing.pop(0)

        if (missing):
            child += missing


    elif (choice == 3 or choice == 4):
        # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
        if (choice == 3):
            child = convertToOneDList(first)
            childVehicles = firstVehicles.copy()
        # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
        elif (choice == 4):
            child = convertToOneDList(second)
            childVehicles = secondVehicles.copy()

    return child, childVehicles

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation
def vehicleMutation(li):
    idx = random.randint(0, len(li)-1)
    if li[idx] == 'A':
        li[idx] = 'B'
    else:
        li[idx] = 'A'
    
    return li

# Routes Mutation - Swap
def routeMutation(li):
    if(len(li) >= 1):
        aIdx = random.randint(0, len(li)-1)
        bIdx = random.randint(0, len(li)-1)

        temp = li[aIdx]
        li[aIdx] = li[bIdx]
        li[bIdx] = temp

    return li

# %%
# print(childVehicles)
# print(vehicleMutation(childVehicles))

# print(child)
# print(routeMutation(child))

def getMutatedOffspring(first, second):

    child, childVehicles = getCrossoverOffspring(first, second)
    mutatedChild = routeMutation(child)
    mutatedVehicles = vehicleMutation(childVehicles)

    return mutatedChild, mutatedVehicles

# %% [markdown]
# # Convert back to class

# %%
# convert routes to Customer class
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()
print(li)

routes = []
for i in li:
    routes.append(Customer(i[0], i[1], i[2], i[3]))
# Out:
# [[1.0, 4.3555, 113.9777, 5.0],
#  [2.0, 4.3976, 114.0049, 8.0],
#  [3.0, 4.3163, 114.0764, 3.0],
#  [4.0, 4.3184, 113.9932, 6.0],
#  [5.0, 4.4024, 113.9896, 5.0],
#  [6.0, 4.4142, 114.0127, 8.0],
#  [7.0, 4.4804, 114.0734, 3.0],
#  [8.0, 4.3818, 114.2034, 6.0],
#  [9.0, 4.4935, 114.1828, 5.0],
#  [10.0, 4.4932, 114.1322, 8.0]]

# %%
def getOffspring(first, second):
    mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    while(len(mutatedChild) != 10):
        mutatedChild, mutatedVehicles = getMutatedOffspring(first, second)
    # print(mutatedChild)
    # print(mutatedVehicles)

    offspring = []
    for i in mutatedVehicles:
        vehicle = Vehicle(i)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        filledCapacity = 0

        while(mutatedChild):
            idx = mutatedChild[0]
            selectedRoute = routes[idx-1]
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                mutatedChild.pop(0)
            else:
                break
        
        offspring.append(vehicle)

    return offspring
    



offspring
# Out:
# [<__main__.Vehicle at 0x22cd32273b0>,
#  <__main__.Vehicle at 0x22cd3227230>,
#  <__main__.Vehicle at 0x22cd3201eb0>]

# %%
# Generate two offspring
parent1, parent2 = getParents(solutions)


noIteration = 100

for i in range(100):
    population = []
    # each parent will produce 1000 offspring, and two best are selected
    for j in range(500):
        offspringA = getOffspring(parent1, parent2)
        offspringB = getOffspring(parent1, parent2)

        population.append(offspringA)
        population.append(offspringB)
    

    parent1, parent2 = getParents(population)

    averageScore = fitness(parent1)

    print('Iteration: ' + str(i+1))
    print('Score: ' + str(averageScore))
# Out:
# 'Iteration: 1'
# 'Score: 143.42708299858427'
# 'Iteration: 2'
# 'Score: 143.42708299858427'
# 'Iteration: 3'
# 'Score: 150.98313686644053'
# 'Iteration: 4'
# 'Score: 143.42708299858427'
# 'Iteration: 5'
# 'Score: 150.98313686644053'
# 'Iteration: 6'
# 'Score: 143.42708299858427'
# 'Iteration: 7'
# 'Score: 150.43946688931496'
# 'Iteration: 8'
# 'Score: 143.42708299858427'
# 'Iteration: 9'
# 'Score: 150.98313686644053'
# 'Iteration: 10'
# 'Score: 143.42708299858427'
# 'Iteration: 11'
# 'Score: 150.98313686644053'
# 'Iteration: 12'
# 'Score: 143.42708299858427'
# 'Iteration: 13'
# 'Score: 150.98313686644053'
# 'Iteration: 14'
# 'Score: 143.42708299858427'
# 'Iteration: 15'
# 'Score: 150.98313686644053'
# 'Iteration: 16'
# 'Score: 143.42708299858427'
# 'Iteration: 17'
# 'Score: 150.98313686644053'
# 'Iteration: 18'
# 'Score: 143.42708299858427'
# 'Iteration: 19'
# 'Score: 150.98313686644053'
# 'Iteration: 20'
# 'Score: 143.42708299858427'
# 'Iteration: 21'
# 'Score: 150.98313686644053'
# 'Iteration: 22'
# 'Score: 143.42708299858427'
# 'Iteration: 23'
# 'Score: 150.98313686644053'
# 'Iteration: 24'
# 'Score: 143.42708299858427'
# 'Iteration: 25'
# 'Score: 150.98313686644053'
# 'Iteration: 26'
# 'Score: 143.42708299858427'
# 'Iteration: 27'
# 'Score: 150.98313686644053'
# 'Iteration: 28'
# 'Score: 143.42708299858427'
# 'Iteration: 29'
# 'Score: 150.98313686644053'
# 'Iteration: 30'
# 'Score: 143.42708299858427'
# 'Iteration: 31'
# 'Score: 150.98313686644053'
# 'Iteration: 32'
# 'Score: 143.42708299858427'
# 'Iteration: 33'
# 'Score: 150.98313686644053'
# 'Iteration: 34'
# 'Score: 143.42708299858427'
# 'Iteration: 35'
# 'Score: 150.98313686644053'
# 'Iteration: 36'
# 'Score: 143.42708299858427'
# 'Iteration: 37'
# 'Score: 150.98313686644053'
# 'Iteration: 38'
# 'Score: 143.42708299858427'
# 'Iteration: 39'
# 'Score: 150.98313686644053'
# 'Iteration: 40'
# 'Score: 143.42708299858427'
# 'Iteration: 41'
# 'Score: 150.98313686644053'
# 'Iteration: 42'
# 'Score: 143.42708299858427'
# 'Iteration: 43'
# 'Score: 150.98313686644053'
# 'Iteration: 44'
# 'Score: 143.42708299858427'
# 'Iteration: 45'
# 'Score: 150.98313686644053'
# 'Iteration: 46'
# 'Score: 143.42708299858427'
# 'Iteration: 47'
# 'Score: 150.98313686644053'
# 'Iteration: 48'
# 'Score: 143.42708299858427'
# 'Iteration: 49'
# 'Score: 150.98313686644053'
# 'Iteration: 50'
# 'Score: 143.42708299858427'
# 'Iteration: 51'
# 'Score: 150.98313686644053'
# 'Iteration: 52'
# 'Score: 143.42708299858427'
# 'Iteration: 53'
# 'Score: 150.98313686644053'
# 'Iteration: 54'
# 'Score: 143.42708299858427'
# 'Iteration: 55'
# 'Score: 150.98313686644053'
# 'Iteration: 56'
# 'Score: 143.42708299858427'
# 'Iteration: 57'
# 'Score: 150.98313686644053'
# 'Iteration: 58'
# 'Score: 143.42708299858427'
# 'Iteration: 59'
# 'Score: 150.98313686644053'
# 'Iteration: 60'
# 'Score: 143.42708299858427'
# 'Iteration: 61'
# 'Score: 150.98313686644053'
# 'Iteration: 62'
# 'Score: 143.42708299858427'
# 'Iteration: 63'
# 'Score: 150.98313686644053'
# 'Iteration: 64'
# 'Score: 143.42708299858427'
# 'Iteration: 65'
# 'Score: 150.98313686644053'
# 'Iteration: 66'
# 'Score: 143.42708299858427'
# 'Iteration: 67'
# 'Score: 151.57183648198318'
# 'Iteration: 68'
# 'Score: 143.42708299858427'
# 'Iteration: 69'
# 'Score: 150.98313686644053'
# 'Iteration: 70'
# 'Score: 143.42708299858427'
# 'Iteration: 71'
# 'Score: 150.98313686644053'
# 'Iteration: 72'
# 'Score: 143.42708299858427'
# 'Iteration: 73'
# 'Score: 150.98313686644053'
# 'Iteration: 74'
# 'Score: 143.42708299858427'
# 'Iteration: 75'
# 'Score: 150.98313686644053'
# 'Iteration: 76'
# 'Score: 143.42708299858427'
# 'Iteration: 77'
# 'Score: 150.98313686644053'
# 'Iteration: 78'
# 'Score: 143.42708299858427'
# 'Iteration: 79'
# 'Score: 150.98313686644053'
# 'Iteration: 80'
# 'Score: 143.42708299858427'
# 'Iteration: 81'
# 'Score: 150.98313686644053'
# 'Iteration: 82'
# 'Score: 143.42708299858427'
# 'Iteration: 83'
# 'Score: 150.98313686644053'
# 'Iteration: 84'
# 'Score: 143.42708299858427'
# 'Iteration: 85'
# 'Score: 150.98313686644053'
# 'Iteration: 86'
# 'Score: 143.42708299858427'
# 'Iteration: 87'
# 'Score: 150.98313686644053'
# 'Iteration: 88'
# 'Score: 143.42708299858427'
# 'Iteration: 89'
# 'Score: 150.98313686644053'
# 'Iteration: 90'
# 'Score: 143.42708299858427'
# 'Iteration: 91'
# 'Score: 150.98313686644053'
# 'Iteration: 92'
# 'Score: 143.42708299858427'
# 'Iteration: 93'
# 'Score: 150.98313686644053'
# 'Iteration: 94'
# 'Score: 143.42708299858427'
# 'Iteration: 95'
# 'Score: 150.98313686644053'
# 'Iteration: 96'
# 'Score: 143.42708299858427'
# 'Iteration: 97'
# 'Score: 150.98313686644053'
# 'Iteration: 98'
# 'Score: 143.42708299858427'
# 'Iteration: 99'
# 'Score: 150.98313686644053'
# 'Iteration: 100'
# 'Score: 143.42708299858427'

# %%
print("Total Distance: " + str(round(distance(parent1), 2)) + " km")
print("Total Cost: RM " + str(round(fitness(parent1), 2)))
print('')


for idx, vehicle in enumerate(parent1):
    print(f"Vehicle {idx+1} (Type {vehicle.type})")
    vehicleFitness = Fitness(vehicle)
    print(f"Round Trip Distance: {round(vehicleFitness.getDistance(),3)} km, Cost: RM {round(vehicleFitness.getCost(),2)}, Demand: {vehicleFitness.getDemand()}")

    for idx, route in enumerate(vehicle.routes):
        
        if (route.id == -1):
            routeName = "Depot"
            print(f"{routeName} -> ")
        else:
            routeName = "C"+str(int(route.id))
            print(f"{routeName} ({round(route.distance(vehicle.routes[idx-1]),2)} km) -> ")

    backToDepotDistance = vehicle.routes[-1].distance(vehicle.routes[0])
    print(f"Depot ({round(backToDepotDistance, 2)} km)")
    print('')
# Out:
# 'Total Distance: 119.52 km'
# 'Total Cost: RM 143.43'
# ''
# 'Vehicle 1 (Type A)'
# 'Round Trip Distance: 44.349 km, Cost: RM 53.22, Demand: 22.0'
# 'Depot -> '
# 'C3 (10.35 km) -> '
# 'C2 (10.83 km) -> '
# 'C1 (5.01 km) -> '
# 'C4 (4.02 km) -> '
# 'Depot (14.14 km)'
# ''
# 'Vehicle 2 (Type A)'
# 'Round Trip Distance: 49.986 km, Cost: RM 59.98, Demand: 22.0'
# 'Depot -> '
# 'C5 (10.48 km) -> '
# 'C6 (2.59 km) -> '
# 'C7 (8.98 km) -> '
# 'C8 (16.32 km) -> '
# 'Depot (11.61 km)'
# ''
# 'Vehicle 3 (Type A)'
# 'Round Trip Distance: 25.187 km, Cost: RM 30.22, Demand: 13.0'
# 'Depot -> '
# 'C9 (11.69 km) -> '
# 'C10 (5.06 km) -> '
# 'Depot (8.44 km)'
# ''
