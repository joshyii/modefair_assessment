# %% [markdown]
# # Import Libraries

# %%
import random
import time
import csv

import numpy as np
import pandas as pd

from pprint import pprint as print

# %% [markdown]
# # Define Classes

# %%
class Customer:
    def __init__(self, id, lat, lon, demand):
        self.id = id
        self.lat = lat
        self.lon = lon
        self.demand = demand
        
    def distance(self, customer):
        latDis = abs(self.lat - customer.lat)
        longDis = abs(self.lon - customer.lon)
        distance = 100 * np.sqrt((latDis ** 2) + (longDis ** 2))
        return distance
    
    def __repr__(self):
        return "(" + str(self.lat) + "," + str(self.lon) + ")"

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
        self.routes = []
        self.rate = None
        self.capacity = None

    def addRoute(self, route):
        self.routes.append(route)

    def setRateCapacity(self):
        if self.type == 'A':
            self.rate = 1.2
            self.capacity = 25
        elif self.type == 'B':
            self.rate = 1.5
            self.capacity = 30
        else:
            self.rate = 0
            self.capacity = 0
    
    def setStartPoint(self):
        self.routes.append(Customer(-1, 4.4184, 114.0932, 0))

# %%
class Fitness:
    def __init__(self, vehicle):
        self.vehicle = vehicle
        self.fitness = None
    
    # fitness is based on cost, since distance is directly in correlation with cost,
    # taking cost can be a more accurate representation of the efficiency of the route

    # routes = customer
    def cost(self):
        routes = self.vehicle.routes
        distance = 0

        for i in range (0, len(routes)):
            fromCity = routes[i]
            if i+1 < len(routes):
                toCity = routes[i+1]

            # return to depot
            else:
                toCity = routes[0]
            
            distance += fromCity.distance(toCity)

        return distance*(self.vehicle.rate)
    
    # def fitness(self):
    #     cost = cost(self)

    #     # give higher ranking for lower cost
    #     return abs(1/cost)

# %%
# fill in routes - choose vehicle - ensure routes is selected based on demands

# %% [markdown]
# # Generate Population

# %%
data = pd.read_csv('data.csv')
data.head()

li = data.values.tolist()

oriRoutes = []
for i in li:
    oriRoutes.append(Customer(i[0], i[1], i[2], i[3]))

solutions = [] #array of vehicles

for s in range(1000):
    print('iteration'+ str(s+1))
    routes = oriRoutes.copy()

    vehicles = []

    while(len(routes) !=0):
        # Randomly choose a vehicle
        type = random.choice(['A', 'B'])
        vehicle = Vehicle(type)
        vehicle.setStartPoint()
        vehicle.setRateCapacity()

        print('Chosen vehicle '+ vehicle.type)

        # Randomly fill in the routes
        filledCapacity = 0

        while(routes):
            selectedRoute = random.choice(routes)
            if((filledCapacity+selectedRoute.demand) <= vehicle.capacity):
                filledCapacity += selectedRoute.demand
                vehicle.addRoute(selectedRoute)
                routes.remove(selectedRoute)
                print('Route ' + str(selectedRoute.id) + ', demand ' + str(selectedRoute.demand))
            else:
                break
            

        vehicles.append(vehicle)

    solutions.append(vehicles)
    
solutions
# Out:
# 'iteration1'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration2'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration3'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration4'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'iteration5'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration6'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration7'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration8'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration9'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration10'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration11'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration12'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'iteration13'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'iteration14'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration15'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration16'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration17'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration18'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration19'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration20'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration21'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration22'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration23'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration24'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration25'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration26'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration27'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration28'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration29'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'iteration30'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration31'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration32'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration33'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration34'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration35'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration36'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration37'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration38'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration39'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration40'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration41'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration42'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'iteration43'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration44'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration45'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration46'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration47'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration48'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'iteration49'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration50'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration51'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration52'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration53'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'iteration54'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'iteration55'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration56'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration57'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration58'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration59'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration60'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration61'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration62'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration63'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration64'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration65'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'iteration66'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration67'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'iteration68'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration69'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration70'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'iteration71'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'iteration72'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration73'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration74'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'iteration75'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration76'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration77'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration78'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration79'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'iteration80'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'iteration81'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'iteration82'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'iteration83'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration84'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration85'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration86'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration87'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration88'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration89'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'iteration90'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration91'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'iteration92'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration93'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration94'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'iteration95'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration96'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration97'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration98'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'iteration99'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration100'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration101'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'iteration102'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration103'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'iteration104'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration105'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration106'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration107'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration108'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'iteration109'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration110'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration111'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration112'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'iteration113'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration114'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration115'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration116'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration117'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'iteration118'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration119'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration120'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'iteration121'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'iteration122'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'iteration123'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'iteration124'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'iteration125'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'iteration126'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration127'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'iteration128'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration129'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'iteration130'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'iteration131'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'iteration132'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration133'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 1.0, demand 5.0'
# 'iteration134'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration135'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration136'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration137'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'iteration138'
# 'Chosen vehicle B'
# 'Route 5.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'iteration139'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'iteration140'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'Route 7.0, demand 3.0'
# 'iteration141'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'iteration142'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'iteration143'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'iteration144'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'iteration145'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration146'
# 'Chosen vehicle B'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'iteration147'
# 'Chosen vehicle B'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'iteration148'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 7.0, demand 3.0'
# 'Route 3.0, demand 3.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 10.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 1.0, demand 5.0'
# 'iteration149'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 1.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 6.0, demand 8.0'
# 'iteration150'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 10.0, demand 8.0'
# 'Route 2.0, demand 8.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 9.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 8.0, demand 6.0'
# 'iteration151'
# 'Chosen vehicle B'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 8.0, demand 6.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration152'
# 'Chosen vehicle A'
# 'Route 10.0, demand 8.0'
# 'Route 4.0, demand 6.0'
# 'Route 1.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Chosen vehicle A'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 9.0, demand 5.0'
# 'Chosen vehicle A'
# 'Route 2.0, demand 8.0'
# 'iteration153'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 5.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 8.0, demand 6.0'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 2.0, demand 8.0'
# 'Route 10.0, demand 8.0'
# 'iteration154'
# 'Chosen vehicle A'
# 'Route 3.0, demand 3.0'
# 'Route 7.0, demand 3.0'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 9.0, demand 5.0'
# 'Route 4.0, demand 6.0'
# 'Route 2.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Chosen vehicle B'
# 'Route 10.0, demand 8.0'
# 'iteration155'
# 'Chosen vehicle A'
# 'Route 5.0, demand 5.0'
# 'Route 10.0, demand 8.0'
# 'Route 9.0, demand 5.0'
# 'Route 3.0, demand 3.0'
# 'Chosen vehicle B'
# 'Route 1.0, demand 5.0'
# 'Route 8.0, demand 6.0'
# 'Route 4.0, demand 6.0'
# 'Route 6.0, demand 8.0'
# 'Chosen vehicle A'
# 'Route 7.0, demand 3.0'
# 'Route 2.0, demand 8.0'
# 'iteration156'
# 'Chosen vehicle B'
# 'Route 6.0, demand 8.0'
# 'Route 5.0, demand 5.0'
# 'Route 7.0, demand 3.0'
# ...
#  [<__main__.Vehicle at 0x209ec035fa0>,
#   <__main__.Vehicle at 0x209ec036060>,
#   <__main__.Vehicle at 0x209ec036120>],
#  [<__main__.Vehicle at 0x209ec0361e0>,
#   <__main__.Vehicle at 0x209ec0362a0>,
#   <__main__.Vehicle at 0x209ec036360>],
#  [<__main__.Vehicle at 0x209ec036420>,
#   <__main__.Vehicle at 0x209ec0364e0>,
#   <__main__.Vehicle at 0x209ec0365a0>],
#  [<__main__.Vehicle at 0x209ec036660>,
#   <__main__.Vehicle at 0x209ec036720>,
#   <__main__.Vehicle at 0x209ec0367e0>],
#  [<__main__.Vehicle at 0x209ec0368a0>,
#   <__main__.Vehicle at 0x209ec036960>,
#   <__main__.Vehicle at 0x209ec036a20>],
#  [<__main__.Vehicle at 0x209ec036ae0>,
#   <__main__.Vehicle at 0x209ec036ba0>,
#   <__main__.Vehicle at 0x209ec036c60>],
#  [<__main__.Vehicle at 0x209ec036d20>, <__main__.Vehicle at 0x209ec036de0>],
#  [<__main__.Vehicle at 0x209ec036ea0>,
#   <__main__.Vehicle at 0x209ec036f60>,
#   <__main__.Vehicle at 0x209ec037020>],
#  [<__main__.Vehicle at 0x209ec0370e0>,
#   <__main__.Vehicle at 0x209ec0371a0>,
#   <__main__.Vehicle at 0x209ec037260>],
#  [<__main__.Vehicle at 0x209ec037320>,
#   <__main__.Vehicle at 0x209ec0373e0>,
#   <__main__.Vehicle at 0x209ec0374a0>],
#  [<__main__.Vehicle at 0x209ec037560>,
#   <__main__.Vehicle at 0x209ec037620>,
#   <__main__.Vehicle at 0x209ec0376e0>],
#  [<__main__.Vehicle at 0x209ec0377a0>,
#   <__main__.Vehicle at 0x209ec037860>,
#   <__main__.Vehicle at 0x209ec037920>],
#  [<__main__.Vehicle at 0x209ec0379e0>,
#   <__main__.Vehicle at 0x209ec037aa0>,
#   <__main__.Vehicle at 0x209ec037b60>],
#  [<__main__.Vehicle at 0x209ec037c20>,
#   <__main__.Vehicle at 0x209ec037ce0>,
#   <__main__.Vehicle at 0x209ec037da0>],
#  [<__main__.Vehicle at 0x209ec037e60>,
#   <__main__.Vehicle at 0x209ec037f20>,
#   <__main__.Vehicle at 0x209ec037fe0>],
#  [<__main__.Vehicle at 0x209ec0400e0>,
#   <__main__.Vehicle at 0x209ec0401a0>,
#   <__main__.Vehicle at 0x209ec040260>],
#  [<__main__.Vehicle at 0x209ec040320>,
#   <__main__.Vehicle at 0x209ec0403e0>,
#   <__main__.Vehicle at 0x209ec0404a0>],
#  [<__main__.Vehicle at 0x209ec040560>, <__main__.Vehicle at 0x209ec040620>],
#  [<__main__.Vehicle at 0x209ec0406e0>,
#   <__main__.Vehicle at 0x209ec0407a0>,
#   <__main__.Vehicle at 0x209ec040860>],
#  [<__main__.Vehicle at 0x209ec040920>,
#   <__main__.Vehicle at 0x209ec0409e0>,
#   <__main__.Vehicle at 0x209ec040aa0>],
#  [<__main__.Vehicle at 0x209ec040b60>,
#   <__main__.Vehicle at 0x209ec040c20>,
#   <__main__.Vehicle at 0x209ec040ce0>],
#  [<__main__.Vehicle at 0x209ec040da0>, <__main__.Vehicle at 0x209ec040e60>],
#  [<__main__.Vehicle at 0x209ec040f20>,
#   <__main__.Vehicle at 0x209ec040fe0>,
#   <__main__.Vehicle at 0x209ec0410a0>],
#  [<__main__.Vehicle at 0x209ec041160>,
#   <__main__.Vehicle at 0x209ec041220>,
#   <__main__.Vehicle at 0x209ec0412e0>],
#  [<__main__.Vehicle at 0x209ec0413a0>,
#   <__main__.Vehicle at 0x209ec041460>,
#   <__main__.Vehicle at 0x209ec041520>],
#  [<__main__.Vehicle at 0x209ec0415e0>,
#   <__main__.Vehicle at 0x209ec0416a0>,
#   <__main__.Vehicle at 0x209ec041760>],
#  [<__main__.Vehicle at 0x209ec041820>,
#   <__main__.Vehicle at 0x209ec0418e0>,
#   <__main__.Vehicle at 0x209ec0419a0>],
#  [<__main__.Vehicle at 0x209ec041a60>, <__main__.Vehicle at 0x209ec041b20>],
#  [<__main__.Vehicle at 0x209ec041be0>, <__main__.Vehicle at 0x209ec041ca0>],
#  [<__main__.Vehicle at 0x209ec041d60>,
#   <__main__.Vehicle at 0x209ec041e20>,
#   <__main__.Vehicle at 0x209ec041ee0>],
#  [<__main__.Vehicle at 0x209ec041fa0>,
#   <__main__.Vehicle at 0x209ec042060>,
#   <__main__.Vehicle at 0x209ec042120>],
#  [<__main__.Vehicle at 0x209ec0421e0>, <__main__.Vehicle at 0x209ec0422a0>],
#  [<__main__.Vehicle at 0x209ec042360>,
#   <__main__.Vehicle at 0x209ec042420>,
#   <__main__.Vehicle at 0x209ec0424e0>],
#  [<__main__.Vehicle at 0x209ec0425a0>,
#   <__main__.Vehicle at 0x209ec042660>,
#   <__main__.Vehicle at 0x209ec042720>],
#  [<__main__.Vehicle at 0x209ec0427e0>,
#   <__main__.Vehicle at 0x209ec0428a0>,
#   <__main__.Vehicle at 0x209ec042960>],
#  [<__main__.Vehicle at 0x209ec042a20>,
#   <__main__.Vehicle at 0x209ec042ae0>,
#   <__main__.Vehicle at 0x209ec042ba0>],
#  [<__main__.Vehicle at 0x209ec042c60>,
#   <__main__.Vehicle at 0x209ec042d20>,
#   <__main__.Vehicle at 0x209ec042de0>],
#  [<__main__.Vehicle at 0x209ec042ea0>,
#   <__main__.Vehicle at 0x209ec042f60>,
#   <__main__.Vehicle at 0x209ec043020>],
#  [<__main__.Vehicle at 0x209ec0430e0>,
#   <__main__.Vehicle at 0x209ec0431a0>,
#   <__main__.Vehicle at 0x209ec043260>],
#  [<__main__.Vehicle at 0x209ec043320>, <__main__.Vehicle at 0x209ec0433e0>],
#  [<__main__.Vehicle at 0x209ec0434a0>,
#   <__main__.Vehicle at 0x209ec043560>,
#   <__main__.Vehicle at 0x209ec043620>],
#  [<__main__.Vehicle at 0x209ec0436e0>,
#   <__main__.Vehicle at 0x209ec0437a0>,
#   <__main__.Vehicle at 0x209ec043860>],
#  [<__main__.Vehicle at 0x209ec043920>,
#   <__main__.Vehicle at 0x209ec0439e0>,
#   <__main__.Vehicle at 0x209ec043aa0>],
#  [<__main__.Vehicle at 0x209ec043b60>,
#   <__main__.Vehicle at 0x209ec043c20>,
#   <__main__.Vehicle at 0x209ec043ce0>],
#  [<__main__.Vehicle at 0x209ec043da0>,
#   <__main__.Vehicle at 0x209ec043e60>,
#   <__main__.Vehicle at 0x209ec043f20>],
#  [<__main__.Vehicle at 0x209ec043fe0>,
#   <__main__.Vehicle at 0x209ec0480e0>,
#   <__main__.Vehicle at 0x209ec0481a0>],
#  [<__main__.Vehicle at 0x209ec048260>, <__main__.Vehicle at 0x209ec048320>],
#  [<__main__.Vehicle at 0x209ec0483e0>,
#   <__main__.Vehicle at 0x209ec0484a0>,
#   <__main__.Vehicle at 0x209ec048560>],
#  [<__main__.Vehicle at 0x209ec048620>,
#   <__main__.Vehicle at 0x209ec0486e0>,
#   <__main__.Vehicle at 0x209ec0487a0>],
#  [<__main__.Vehicle at 0x209ec048860>,
#   <__main__.Vehicle at 0x209ec048920>,
#   <__main__.Vehicle at 0x209ec0489e0>],
#  [<__main__.Vehicle at 0x209ec048aa0>,
#   <__main__.Vehicle at 0x209ec048b60>,
#   <__main__.Vehicle at 0x209ec048c20>],
#  [<__main__.Vehicle at 0x209ec048ce0>,
#   <__main__.Vehicle at 0x209ec048da0>,
#   <__main__.Vehicle at 0x209ec048e60>],
#  [<__main__.Vehicle at 0x209ec048f20>,
#   <__main__.Vehicle at 0x209ec048fe0>,
#   <__main__.Vehicle at 0x209ec0490a0>],
#  [<__main__.Vehicle at 0x209ec049160>,
#   <__main__.Vehicle at 0x209ec049220>,
#   <__main__.Vehicle at 0x209ec0492e0>],
#  [<__main__.Vehicle at 0x209ec0493a0>,
#   <__main__.Vehicle at 0x209ec049460>,
#   <__main__.Vehicle at 0x209ec049520>],
#  [<__main__.Vehicle at 0x209ec0495e0>,
#   <__main__.Vehicle at 0x209ec0496a0>,
#   <__main__.Vehicle at 0x209ec049760>],
#  [<__main__.Vehicle at 0x209ec049820>, <__main__.Vehicle at 0x209ec0498e0>],
#  [<__main__.Vehicle at 0x209ec0499a0>,
#   <__main__.Vehicle at 0x209ec049a60>,
#   <__main__.Vehicle at 0x209ec049b20>],
#  [<__main__.Vehicle at 0x209ec049be0>, <__main__.Vehicle at 0x209ec049ca0>],
#  [<__main__.Vehicle at 0x209ec049d60>,
#   <__main__.Vehicle at 0x209ec049e20>,
#   <__main__.Vehicle at 0x209ec049ee0>],
#  [<__main__.Vehicle at 0x209ec049fa0>,
#   <__main__.Vehicle at 0x209ec04a060>,
#   <__main__.Vehicle at 0x209ec04a120>],
#  [<__main__.Vehicle at 0x209ec04a1e0>,
#   <__main__.Vehicle at 0x209ec04a2a0>,
#   <__main__.Vehicle at 0x209ec04a360>],
#  [<__main__.Vehicle at 0x209ec04a420>,
#   <__main__.Vehicle at 0x209ec04a4e0>,
#   <__main__.Vehicle at 0x209ec04a5a0>],
#  [<__main__.Vehicle at 0x209ec04a660>,
#   <__main__.Vehicle at 0x209ec04a720>,
#   <__main__.Vehicle at 0x209ec04a7e0>],
#  [<__main__.Vehicle at 0x209ec04a8a0>,
#   <__main__.Vehicle at 0x209ec04a960>,
#   <__main__.Vehicle at 0x209ec04aa20>],
#  [<__main__.Vehicle at 0x209ec04aae0>, <__main__.Vehicle at 0x209ec04aba0>],
#  [<__main__.Vehicle at 0x209ec04ac60>,
#   <__main__.Vehicle at 0x209ec04ad20>,
#   <__main__.Vehicle at 0x209ec04ade0>],
#  [<__main__.Vehicle at 0x209ec04aea0>,
#   <__main__.Vehicle at 0x209ec04af60>,
#   <__main__.Vehicle at 0x209ec04b020>],
#  [<__main__.Vehicle at 0x209ec04b0e0>,
#   <__main__.Vehicle at 0x209ec04b1a0>,
#   <__main__.Vehicle at 0x209ec04b260>],
#  [<__main__.Vehicle at 0x209ec04b320>,
#   <__main__.Vehicle at 0x209ec04b3e0>,
#   <__main__.Vehicle at 0x209ec04b4a0>],
#  [<__main__.Vehicle at 0x209ec04b560>,
#   <__main__.Vehicle at 0x209ec04b620>,
#   <__main__.Vehicle at 0x209ec04b6e0>],
#  [<__main__.Vehicle at 0x209ec04b7a0>,
#   <__main__.Vehicle at 0x209ec04b860>,
#   <__main__.Vehicle at 0x209ec04b920>],
#  [<__main__.Vehicle at 0x209ec04b9e0>, <__main__.Vehicle at 0x209ec04baa0>],
#  [<__main__.Vehicle at 0x209ec04bb60>,
#   <__main__.Vehicle at 0x209ec04bc20>,
#   <__main__.Vehicle at 0x209ec04bce0>],
#  [<__main__.Vehicle at 0x209ec04bda0>, <__main__.Vehicle at 0x209ec04be60>],
#  [<__main__.Vehicle at 0x209ec04bf20>, <__main__.Vehicle at 0x209ec04bfe0>],
#  [<__main__.Vehicle at 0x209ec04c0e0>,
#   <__main__.Vehicle at 0x209ec04c1a0>,
#   <__main__.Vehicle at 0x209ec04c260>],
#  [<__main__.Vehicle at 0x209ec04c320>,
#   <__main__.Vehicle at 0x209ec04c3e0>,
#   <__main__.Vehicle at 0x209ec04c4a0>],
#  [<__main__.Vehicle at 0x209ec04c560>,
#   <__main__.Vehicle at 0x209ec04c620>,
#   <__main__.Vehicle at 0x209ec04c6e0>],
#  [<__main__.Vehicle at 0x209ec04c7a0>,
#   <__main__.Vehicle at 0x209ec04c860>,
#   <__main__.Vehicle at 0x209ec04c920>],
#  [<__main__.Vehicle at 0x209ec04c9e0>,
#   <__main__.Vehicle at 0x209ec04caa0>,
#   <__main__.Vehicle at 0x209ec04cb60>],
#  [<__main__.Vehicle at 0x209ec04cc20>,
#   <__main__.Vehicle at 0x209ec04cce0>,
#   <__main__.Vehicle at 0x209ec04cda0>],
#  [<__main__.Vehicle at 0x209ec04ce60>,
#   <__main__.Vehicle at 0x209ec04cf20>,
#   <__main__.Vehicle at 0x209ec04cfe0>],
#  [<__main__.Vehicle at 0x209ec04d0a0>, <__main__.Vehicle at 0x209ec04d160>],
#  [<__main__.Vehicle at 0x209ec04d220>, <__main__.Vehicle at 0x209ec04d2e0>],
#  [<__main__.Vehicle at 0x209ec04d3a0>,
#   <__main__.Vehicle at 0x209ec04d460>,
#   <__main__.Vehicle at 0x209ec04d520>],
#  [<__main__.Vehicle at 0x209ec04d5e0>,
#   <__main__.Vehicle at 0x209ec04d6a0>,
#   <__main__.Vehicle at 0x209ec04d760>],
#  [<__main__.Vehicle at 0x209ec04d820>,
#   <__main__.Vehicle at 0x209ec04d8e0>,
#   <__main__.Vehicle at 0x209ec04d9a0>],
#  [<__main__.Vehicle at 0x209ec04da60>,
#   <__main__.Vehicle at 0x209ec04db20>,
#   <__main__.Vehicle at 0x209ec04dbe0>],
#  [<__main__.Vehicle at 0x209ec04dca0>, <__main__.Vehicle at 0x209ec04dd60>],
#  [<__main__.Vehicle at 0x209ec04de20>, <__main__.Vehicle at 0x209ec04dee0>],
#  [<__main__.Vehicle at 0x209ec04dfa0>,
#   <__main__.Vehicle at 0x209ec04e060>,
#   <__main__.Vehicle at 0x209ec04e120>],
#  [<__main__.Vehicle at 0x209ec04e1e0>,
#   <__main__.Vehicle at 0x209ec04e2a0>,
#   <__main__.Vehicle at 0x209ec04e360>],
#  [<__main__.Vehicle at 0x209ec04e420>,
#   <__main__.Vehicle at 0x209ec04e4e0>,
#   <__main__.Vehicle at 0x209ec04e5a0>],
#  [<__main__.Vehicle at 0x209ec04e660>,
#   <__main__.Vehicle at 0x209ec04e720>,
#   <__main__.Vehicle at 0x209ec04e7e0>],
#  [<__main__.Vehicle at 0x209ec04e8a0>, <__main__.Vehicle at 0x209ec04e960>],
#  [<__main__.Vehicle at 0x209ec04ea20>,
#   <__main__.Vehicle at 0x209ec04eae0>,
#   <__main__.Vehicle at 0x209ec04eba0>],
#  [<__main__.Vehicle at 0x209ec04ec60>,
#   <__main__.Vehicle at 0x209ec04ed20>,
#   <__main__.Vehicle at 0x209ec04ede0>],
#  [<__main__.Vehicle at 0x209ec04eea0>,
#   <__main__.Vehicle at 0x209ec04ef60>,
#   <__main__.Vehicle at 0x209ec04f020>],
#  [<__main__.Vehicle at 0x209ec04f0e0>,
#   <__main__.Vehicle at 0x209ec04f1a0>,
#   <__main__.Vehicle at 0x209ec04f260>],
#  [<__main__.Vehicle at 0x209ec04f320>,
#   <__main__.Vehicle at 0x209ec04f3e0>,
#   <__main__.Vehicle at 0x209ec04f4a0>],
#  [<__main__.Vehicle at 0x209ec04f560>,
#   <__main__.Vehicle at 0x209ec04f620>,
#   <__main__.Vehicle at 0x209ec04f6e0>],
#  [<__main__.Vehicle at 0x209ec04f7a0>,
#   <__main__.Vehicle at 0x209ec04f860>,
#   <__main__.Vehicle at 0x209ec04f920>],
#  [<__main__.Vehicle at 0x209ec04f9e0>,
#   <__main__.Vehicle at 0x209ec04faa0>,
#   <__main__.Vehicle at 0x209ec04fb60>],
#  [<__main__.Vehicle at 0x209ec04fc20>,
#   <__main__.Vehicle at 0x209ec04fce0>,
#   <__main__.Vehicle at 0x209ec04fda0>],
#  [<__main__.Vehicle at 0x209ec04fe60>,
#   <__main__.Vehicle at 0x209ec04ff20>,
#   <__main__.Vehicle at 0x209ec04ffe0>],
#  [<__main__.Vehicle at 0x209ec0540e0>,
#   <__main__.Vehicle at 0x209ec0541a0>,
#   <__main__.Vehicle at 0x209ec054260>],
#  [<__main__.Vehicle at 0x209ec054320>,
#   <__main__.Vehicle at 0x209ec0543e0>,
#   <__main__.Vehicle at 0x209ec0544a0>],
#  [<__main__.Vehicle at 0x209ec054560>,
#   <__main__.Vehicle at 0x209ec054620>,
#   <__main__.Vehicle at 0x209ec0546e0>],
#  [<__main__.Vehicle at 0x209ec0547a0>,
#   <__main__.Vehicle at 0x209ec054860>,
#   <__main__.Vehicle at 0x209ec054920>],
#  [<__main__.Vehicle at 0x209ec0549e0>,
#   <__main__.Vehicle at 0x209ec054aa0>,
#   <__main__.Vehicle at 0x209ec054b60>],
#  [<__main__.Vehicle at 0x209ec054c20>,
#   <__main__.Vehicle at 0x209ec054ce0>,
#   <__main__.Vehicle at 0x209ec054da0>],
#  [<__main__.Vehicle at 0x209ec054e60>,
#   <__main__.Vehicle at 0x209ec054f20>,
#   <__main__.Vehicle at 0x209ec054fe0>],
#  [<__main__.Vehicle at 0x209ec0550a0>,
#   <__main__.Vehicle at 0x209ec055160>,
#   <__main__.Vehicle at 0x209ec055220>],
#  [<__main__.Vehicle at 0x209ec0552e0>,
#   <__main__.Vehicle at 0x209ec0553a0>,
#   <__main__.Vehicle at 0x209ec055460>],
#  [<__main__.Vehicle at 0x209ec055520>,
#   <__main__.Vehicle at 0x209ec0555e0>,
#   <__main__.Vehicle at 0x209ec0556a0>],
#  [<__main__.Vehicle at 0x209ec055760>, <__main__.Vehicle at 0x209ec055820>],
#  [<__main__.Vehicle at 0x209ec0558e0>,
#   <__main__.Vehicle at 0x209ec0559a0>,
#   <__main__.Vehicle at 0x209ec055a60>],
#  [<__main__.Vehicle at 0x209ec055b20>,
#   <__main__.Vehicle at 0x209ec055be0>,
#   <__main__.Vehicle at 0x209ec055ca0>],
#  [<__main__.Vehicle at 0x209ec055d60>,
#   <__main__.Vehicle at 0x209ec055e20>,
#   <__main__.Vehicle at 0x209ec055ee0>],
#  [<__main__.Vehicle at 0x209ec055fa0>,
#   <__main__.Vehicle at 0x209ec056060>,
#   <__main__.Vehicle at 0x209ec056120>],
#  [<__main__.Vehicle at 0x209ec0561e0>,
#   <__main__.Vehicle at 0x209ec0562a0>,
#   <__main__.Vehicle at 0x209ec056360>],
#  [<__main__.Vehicle at 0x209ec056420>,
#   <__main__.Vehicle at 0x209ec0564e0>,
#   <__main__.Vehicle at 0x209ec0565a0>],
#  [<__main__.Vehicle at 0x209ec056660>,
#   <__main__.Vehicle at 0x209ec056720>,
#   <__main__.Vehicle at 0x209ec0567e0>],
#  [<__main__.Vehicle at 0x209ec0568a0>,
#   <__main__.Vehicle at 0x209ec056960>,
#   <__main__.Vehicle at 0x209ec056a20>],
#  [<__main__.Vehicle at 0x209ec056ae0>,
#   <__main__.Vehicle at 0x209ec056ba0>,
#   <__main__.Vehicle at 0x209ec056c60>],
#  [<__main__.Vehicle at 0x209ec056d20>, <__main__.Vehicle at 0x209ec056de0>],
#  [<__main__.Vehicle at 0x209ec056ea0>,
#   <__main__.Vehicle at 0x209ec056f60>,
#   <__main__.Vehicle at 0x209ec057020>],
#  [<__main__.Vehicle at 0x209ec0570e0>,
#   <__main__.Vehicle at 0x209ec0571a0>,
#   <__main__.Vehicle at 0x209ec057260>],
#  [<__main__.Vehicle at 0x209ec057320>,
#   <__main__.Vehicle at 0x209ec0573e0>,
#   <__main__.Vehicle at 0x209ec0574a0>],
#  [<__main__.Vehicle at 0x209ec057560>, <__main__.Vehicle at 0x209ec057620>],
#  [<__main__.Vehicle at 0x209ec0576e0>,
#   <__main__.Vehicle at 0x209ec0577a0>,
#   <__main__.Vehicle at 0x209ec057860>],
#  [<__main__.Vehicle at 0x209ec057920>,
#   <__main__.Vehicle at 0x209ec0579e0>,
#   <__main__.Vehicle at 0x209ec057aa0>],
#  [<__main__.Vehicle at 0x209ec057b60>,
#   <__main__.Vehicle at 0x209ec057c20>,
#   <__main__.Vehicle at 0x209ec057ce0>],
#  [<__main__.Vehicle at 0x209ec057da0>,
#   <__main__.Vehicle at 0x209ec057e60>,
#   <__main__.Vehicle at 0x209ec057f20>],
#  [<__main__.Vehicle at 0x209ec057fe0>, <__main__.Vehicle at 0x209ec05c0e0>],
#  [<__main__.Vehicle at 0x209ec05c1a0>,
#   <__main__.Vehicle at 0x209ec05c260>,
#   <__main__.Vehicle at 0x209ec05c320>],
#  [<__main__.Vehicle at 0x209ec05c3e0>,
#   <__main__.Vehicle at 0x209ec05c4a0>,
#   <__main__.Vehicle at 0x209ec05c560>],
#  [<__main__.Vehicle at 0x209ec05c620>, <__main__.Vehicle at 0x209ec05c6e0>],
#  [<__main__.Vehicle at 0x209ec05c7a0>, <__main__.Vehicle at 0x209ec05c860>],
#  [<__main__.Vehicle at 0x209ec05c920>,
#   <__main__.Vehicle at 0x209ec05c9e0>,
#   <__main__.Vehicle at 0x209ec05caa0>],
#  [<__main__.Vehicle at 0x209ec05cb60>,
#   <__main__.Vehicle at 0x209ec05cc20>,
#   <__main__.Vehicle at 0x209ec05cce0>],
#  [<__main__.Vehicle at 0x209ec05cda0>,
#   <__main__.Vehicle at 0x209ec05ce60>,
#   <__main__.Vehicle at 0x209ec05cf20>],
#  [<__main__.Vehicle at 0x209ec05cfe0>,
#   <__main__.Vehicle at 0x209ec05d0a0>,
#   <__main__.Vehicle at 0x209ec05d160>]]

# %%
# routes do not need to include depot at end, but shoudl include depot at start

# %% [markdown]
# # Tournament Selection

# %%
# Randomly choose 20 samples, get one parent
def getParent():
    choices = random.sample(solutions, 20)

    chosenSolutionCost = []
    for vehicles in choices:
        solutionCost = 0
        for vehicle in vehicles:
            fitness = Fitness(vehicle)
            cost = fitness.cost()
            solutionCost += cost
        chosenSolutionCost.append(solutionCost)


    minpos = chosenSolutionCost.index(min(chosenSolutionCost))

    return choices[minpos]

firstParent = getParent()
secondParent = getParent()

print(firstParent)
secondParent
# Out:
# [<__main__.Vehicle object at 0x00000209EBF75E20>,
#  <__main__.Vehicle object at 0x00000209EBF75EE0>,
#  <__main__.Vehicle object at 0x00000209EBF75FA0>]
# [<__main__.Vehicle at 0x209ec0239e0>,
#  <__main__.Vehicle at 0x209ec023aa0>,
#  <__main__.Vehicle at 0x209ec023b60>]

# %% [markdown]
# # Crossover

# %%
def findMissing(li):
    return sorted(set(range(1, 11)).difference(li))


def convertToOneDList(li):
    convertedList = []
    for i in range(len(li)):
        for j in range(len(li[i])):
            convertedList.append(int(li[i][j]))
    return convertedList

def getDuplicatedElements(li):
    duplicates = []
    for x in li:
        if x not in duplicates and li.count(x) >1:
            duplicates.append(x)
        
    return duplicates

# %%
# drop start point when crossing over

first = [[3.0, 4.0, 2.0, 6.0], [7.0, 1.0, 5.0, 9.0], [8.0, 10.0]]
firstVehicles = ['B', 'A', 'B']
second = [[4.0, 6.0, 5.0], [3.0, 1.0, 2.0, 7.0, 10.0], [8.0, 9.0]]
secondVehicles = ['A', 'B', 'A']


selectedVehicleIdx = 1
selectedToSwapVehicle = [3.0, 1.0, 2.0, 7.0, 10.0]
selectedToSwapVehicle2 = [7.0, 1.0, 5.0, 9.0]
# first = [[],[],[]]
# firstVehicles = []

# for i in range(len(firstParent)):
#     firstParent[i].routes.pop(0)
#     firstVehicles.append(firstParent[i].type)
#     # for every route
#     for j in range(len(firstParent[i].routes)):
#         first[i].append(firstParent[i].routes[j].id)



# second = [[],[],[]]
# secondVehicles = []


# for i in range(len(secondParent)):
#     secondParent[i].routes.pop(0)
#     secondVehicles.append(secondParent[i].type)
#     # for every route
#     for j in range(len(secondParent[i].routes)):
#         second[i].append(secondParent[i].routes[j].id)


# selectedFirstVehicle = random.choice(first)
# selectedFirstVehicleIdx = first.index(selectedFirstVehicle)

# selectedSecondVehicle = random.choice(second)
# selectedSecondVehicleIdx = second.index(selectedSecondVehicle)



# Random Choice of 1,2,3,4
choice = random.randint(1, 4)
# Case 1 - first parent is  main, two vehicles remain, one vehicle changes
print(choice)
if (choice == 1 or choice == 2):
    if (choice == 1):
        parent = first.copy()
        # selectedVehicleIdx = random.randInt(0, len(parent)-1)
        # selectedToSwapVehicle = random.choice(secondary)
        parent[selectedVehicleIdx] = selectedToSwapVehicle
        parent = convertToOneDList(parent)

    # Case 2 - second parent is main, two vehicles remain, one vehicle changes
    elif (choice == 2):
        parent = second.copy()
        # selectedVehicleIdx = random.randInt(0, len(parent)-1)
        # selectedToSwapVehicle = random.choice(secondary)
        parent[selectedVehicleIdx] = selectedToSwapVehicle2
        parent = convertToOneDList(parent)

    print(parent)
    missing = findMissing(parent)
    duplicates = getDuplicatedElements(parent)

    child = []
    for i in parent:
        if i not in child:
            child.append(i)
        else:
            if(missing):
                child.append(missing[0])
                missing.pop(0)

    if (missing):
        child += missing


elif (choice == 3 or choice == 4):
    # Case 3 - take first parent as a whole, no crossover, direcly sent to mutation
    if (choice == 3):
        child = convertToOneDList(first)
    # Case 4 - take second parent as a whole, no crossover, direcly sent to mutation
    elif (choice == 4):
        child = convertToOneDList(second)

print(child)
# Out:
# 2
# [4, 6, 5, 7, 1, 5, 9, 8, 9]
# [4, 6, 5, 7, 1, 2, 9, 8, 3, 10]

# %% [markdown]
# # Mutation

# %%
# Vehicle Mutation
def vehicleMutation(li):
    idx = random.randint(0, len(li)-1)
    if li[idx] == 'A':
        li[idx] = 'B'
    else:
        li[idx] = 'A'
    
    return li

# Routes Mutation - Swap
def routeMutation(li):
    aIdx = random.randint(0, len(li)-1)
    bIdx = random.randint(0, len(li)-1)

    temp = li[aIdx]
    li[aIdx] = li[bIdx]
    li[bIdx] = temp

    return li

# %%
print(firstVehicles)
print(vehicleMutation(firstVehicles))
print(firstVehicles)

print(first)
print(routeMutation(first))
# Out:
# ['B', 'B', 'B']
# ['B', 'A', 'B']
# ['B', 'A', 'B']
# [3, 4, 7, 6, 5, 1, 9, 2, 10, 8]
# [3, 4, 7, 6, 5, 1, 9, 2, 10, 8]
